# %% [markdown]
# # PROJECT 1: Linear and Discrete Models
# ## ENERGY PRODUCTION OPTIMIZATION PROBLEM
#
# ### Authors:
# 1. Ángela María Durán Pinto // 100472766
# 2. Diego Hernández Suárez // 100472809
#
# ### Subject: Optimization and Analytics

# %% [markdown]
# # 1) Introduction
#
# During this assigment our main objectives will be:
#
# - Find and describe a realistic problem where the decision making process requires of the formulation of a linear optimization model
# - The problem must have at least 20 decision variables and more than 3 non-trivial constraints
# - The bigger the problem, the better
#
# For these reasons, we started to consider and analyze different realistic problem in order to create a linear optimization model. However, we wanted to achieve a problem that could be realistic and significantly original compared to previous labs and works done during the course.

# %% [markdown]
# ## 1.1) Problem description

# %% [markdown]
# There exist some places nowadays that are currently facing several challenges about supplying enough energy to the population of the country, for instance, Malaysia.There are several important points when producing energy such as environmental impact, the cost of production, the availability of each type of energy due to the infrastructure or resources available related to that energy in the region or the most important, reaching the demand in each of the regions.
#
# It is for this reason that we decided to create an optimization problem that will try to analyze and solve this significant issue taking a country splitted in 25 regions, where we are going to study the optimal production of energy for different type of energies (where some of them will be renewable energies and others non-renewable) with the purpose of fulfilling the demand for each region. Furthermore, there are several constraints that must be taken into account in order to have a stable, ecological, realistic, and at the same time efficient production of the energy. It is for these reasons that we must add certain restrictions such as enviromental impact, energy cost production or availability among others in order to obtain an optimal model for the production of each energy.
#
# In addition to this, we are interested in not only studying the energy production for each region in the country, we would also like to study through the different 4 seasons of the year which we will call it "time period", in this way, we can solve a interesting problem which is significantly big and takes several aspects into account to produce the best possible model, where each time period will modify the amount of demand, for instance, in time period 1 (winter) the demand will increase a 12% meanwhile in time period 3 (summer) the demand will decrease a 15%, in the data set this seasonal multipliers will be explained for all the seasons.
#
# We want to take into consideration that the goverment of the country, for this specific task wants to have a minimum of nuclear energy production due to the investment done time ago eventhough the nuclear energy is a expensive and not too efficient energy, but after the huge invesment, they want to take advatange of it. For this reason that they demand that the production of nuclear energy should be at least 10% of the total demand.
# The government is also intered in having a transition to renewable energies in order to avoid the depletion of non-renewable energy reserves such as fossil fuels, it is for this reason that at least 45% of the production must be generated by renewable energies.
#
# Furthermore, it is important to mention that energies such as the fossil energy, are commonly more cheaper and have a higher availability compared to renewable energies such as the solar energy, but it is also true that fossil energy has a bigger environmental impact compared to the other one. All this aspects will be taken into account in our model in order to optimize it and generate the most realistic data set a possible and finally, a relevant result.
#
# In this way, we are facing a challenging problem that is quite often in countries where the regions struggles to produce enough energy to offset the demand taking a lot of other aspects into consideration which are issues in the world nowadays.

# %% [markdown]
# # 2) Explaining and solving the linear optimization problem

# %% [markdown]
# ## 2.1) Libraries

# %% [markdown]
# Here we are going to write all the libraries that were used during the assigment. However, the essential one is the pyomo library, which is the one used in order to create and optimize the model.

# %%
from pyomo.environ import * 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2.2) Generate dataset

# %% [markdown]
# In order to create a realistic data set to simulate a real problem, we did different researches in order to obtain a data set that could have reliable data or at least, the most realistic one, it is for this reason that we went to several resources in order to obtain real data such as: <br>
#
# - International Energy Agency (IEA): https://www.iea.org/ <br>
# - Global Energy Observatory: https://globalenergyobservatory.org/ <br>
# - World Energy Database: https://www.worldenergy.org/transition-toolkit <br>
# - World Energy Outlook (IEA): https://www.iea.org/reports/world-energy-outlook-2021 <br>
#
# We decided to generate a random data set taking into consideration the previous aspect because we considered the most convenient way to achieve our goal and having a full understanding of the problem and resolution of it. <br>
#
# Our data set is produced thanks to a function called "generate_sample_dataset", which takes two arguments, the number of regions and the number of time periods. We established a seed in order to always obtain the same results in order to comment these results obtained, otherwise it would not be possible to comment them.
# We created a base demand variable, which depending on the the season, it gets a modification by a multiplier, as it can be seen, for time period 1, the demand will increase a 12%, for spring, the base demand will also have an increase of a 5%, for summer as it is the time period with the less energy demand usually, the base demand will decrease a 15% and for autumn the demand will decrease a 5%, we consider it is very useful and interesting to have changes in the demand depending on the time period because it gets closer to what a real problem is and gives a huge importance of the energy production depending on the season.
# We also created other variables like the availability of each energy, the environmetal impact for each of them and the cost of production of the different energies. We also added other variables like the environmetal limit for each region or a penalty parameter for using an energy. <br>
#
# We returned all this information using a list, which in the list it contains a dictionaries for the different variables that we are going to take into account during the work, the first dictionary contains the demand for a specific region and time period, the second one for availability, third one for environmetal impact, fourth one is used to store the cost production and for the binary apart, we added one for the penalty parameter of using each energy.<br>
#
# We consider this is the most efficient way to generate our data set in order to obtain a list with different dictionaries where each one contains all the information in respect to a certain aspect (cost, demand, availability, etc...). After that we established the number of regions, in our case 25 and time periods which is 4 corresponding to the seasons of the year and call the previously mentioned function to create the data set.

# %%
def generate_sample_dataset(num_regions, num_time_periods):
    
    # Set a seed for reproducibility to always generate the same data set
    np.random.seed(123)  
    
    # Generate random base demand values for each region
    demand_base = np.random.randint(1800, 2000, size=(num_regions, 1))

    # Create a seasonality adjustment factor that increases or decreases the demand depending on the time period
    seasonal_factors = np.array([1.12, 1.05, 0.85, 0.95])  # 1 (Winter): +12%, 2 (Spring): +5%, 3 (Summer): -15%, 4 (Autumn): -5%

    # Apply the seasonality adjustment to demand 
    demand = np.round(demand_base * seasonal_factors.reshape(1, num_time_periods)).astype(int)
    
    
    # Values for availability
    wind_availability = np.random.uniform(300, 400, size=(num_regions, num_time_periods))
    solar_availability = np.random.uniform(100, 300, size=(num_regions, num_time_periods))
    fossil_availability = np.random.uniform(700, 1050, size=(num_regions, num_time_periods))
    nuclear_availability = np.random.uniform(500, 750, size=(num_regions, num_time_periods))
    hydro_availability = np.random.uniform(200, 400, size=(num_regions, num_time_periods))  
    geothermal_availability = np.random.uniform(300, 600, size=(num_regions, num_time_periods))  

    # Values for environmental impact
    environmental_impact_wind = np.random.uniform(0.1, 0.25, size=num_regions)
    environmental_impact_solar = np.random.uniform(0.25, 0.35, size=num_regions)
    environmental_impact_fossil = np.random.uniform(0.6, 0.8, size=num_regions)
    environmental_impact_nuclear = np.random.uniform(0.3, 0.45, size=num_regions)
    environmental_impact_hydro = np.random.uniform(0.05, 0.2, size=num_regions)  
    environmental_impact_geothermal = np.random.uniform(0.15, 0.3, size=num_regions)  

    # Values for costs
    cost_wind = np.random.randint(15, 25, size=num_regions)
    cost_solar = np.random.randint(10, 25, size=num_regions)
    cost_fossil = np.random.randint(25, 40, size=num_regions)
    cost_nuclear = np.random.randint(40, 60, size=num_regions)
    cost_hydro = np.random.randint(25, 35, size=num_regions)  
    cost_geothermal = np.random.randint(20, 40, size=num_regions) 
    
    #Treshold for the enviromental impact limit in the whole country
    total_env_limit = 1250
    # Treshold for the environmental impact limit per region
    environmental_limit = total_env_limit/25
    
    # Penalty parameters
    penalty = [1100, 50,2000, 10,430,750]

    # return a list of 5 dictionaries:
        # 1º demand,  2º availabilities,  3º environmental_impact  4º cost   5º penalty for Y (binary variables)
    return [
        {"demand": demand}, 
        {"wind": wind_availability, "solar":solar_availability,"fossil":fossil_availability,
        "nuclear":nuclear_availability,"hydro":hydro_availability,"geothermal":geothermal_availability},
        {"wind": environmental_impact_wind, "solar":environmental_impact_solar,"fossil":environmental_impact_fossil,
         "nuclear":environmental_impact_nuclear,"hydro":environmental_impact_hydro,"geothermal":environmental_impact_geothermal},
        {"wind": cost_wind, "solar":cost_solar,"fossil":cost_fossil,
         "nuclear":cost_nuclear,"hydro":cost_hydro,"geothermal":cost_geothermal} ,
        {"wind":penalty[0], "solar":penalty[1],"fossil":penalty[2], "nuclear":penalty[3],"hydro":penalty[4],
         "geothermal":penalty[5]}
           ]


# Generate the sample dataset

num_regions = 25
num_time_periods = 4
sample_dataset = generate_sample_dataset(num_regions, num_time_periods)


#Treshold for the enviromental impact limit in the whole country
total_env_limit = 1250
# Treshold for the environmental impact limit per region
environmental_limit = total_env_limit/25 #  total environmetal limit for the whole country divided by each region

# %% [markdown]
# Now that we already have the data set to work with, we can initialize the model with the ConcreteModel() class, this will create a container in order to define and solve the mathematical optimization problem.

# %%
# Create Pyomo model
model = ConcreteModel()

# %% [markdown]
# ## 2.3) Sets:
#
# A set is a Pyomo component used to define and represent sets of index values. These index values are often used to describe the domains of decision variables, parameters, and indices for constraints. <br>
#
# We decided to create three sets in order to study the energies, regions and the time periods. <br>
# - *e*: Energy sources including wind, solar, fossil, nuclear, hydro, and geothermal. <br>
# - *r* : Regions. Indexed from 1 to 25. Lets assume this country has 25 different regions where each region has their own energy production management. <br>
# - *t* : Time periods. Indexed from 1 to 4. They correspond to the seasons of the year in order to simulate a realistic problem which depending of this time period will affect the demand by increasing or decreasing it.
#
#
# For the energies set we just created a list with the name of each energy that can be produced. For the regions and time periods we created a list with values between 1 to 25, that is why we are adding a 1 to num_regions and num_time__periods, this will make us the task easier to plot results and make it more visually appeling.

# %%
regions = list(range(1, num_regions + 1))
time_periods = list(range(1, num_time_periods + 1))
energies = ["wind", "solar","fossil", "nuclear","hydro","geothermal"]

# Initialize each set with the corresponding values previously declared
model.e = Set(initialize = energies, doc = 'energies')
model.r = Set(initialize = regions, doc = 'regions')
model.t = Set(initialize = time_periods, doc = 'time')

# %% [markdown]
# ## 2.4) Parameters:
#
# A parameter is a modeling component in Pyomo that is used to represent constant values in a mathematical optimization model. Parameters are typically used to input data, coefficients, or fixed values into a model that are used in the objective function with a certain purpose or to create constraints among other goals. In other words, they are essential weights in order to quantify the impact of various factors and constraints on the objective function and decision variables within an optimization model. <br>
#
# These are the parameters that were used during this assigment: <br>
#
# $d_{r,t}$ : Electricity demand in region *r* at time *t*
#
# $A_{e, r,t}$: Availability of energy type *e* in region *r* at time period *t*
#
# $E_{e,r}$ : Environmental impact of a certain type of energy *e* at region *r*
#
# $C_{e,r}$: Cost of energy production for energy *e* in region *r*
#
#
# - It is important to mention that the enviromental limit is an essential treshold.
#
# $Environmental Limit$: Maximum allowed of environmental impact for any region

# %%
# Electricity demand in region 'r' at time 't'  
model.d  = Param(model.r, model.t, within=PositiveReals,
                 initialize=lambda model, r, t: sample_dataset[0]["demand"][r - 1, t - 1], mutable=True)


# Availability for energy e in region r at time t
model.A = Param(model.e, model.r, model.t, within=NonNegativeReals,
                initialize=lambda model, e, r, t: sample_dataset[1][e][r - 1, t - 1], mutable=True)



# Environmental impact for a certain energy e in region r
model.E = Param(model.e, model.r, within=NonNegativeReals,
                initialize=lambda model, e
                , r: sample_dataset[2][e][r - 1], mutable=True)



# Cost of energy production of energy type e in region r
model.C = Param(model.e, model.r, within=NonNegativeReals,
                initialize=lambda model, e, r: sample_dataset[3][e][r - 1], mutable=True)

# %% [markdown]
# ## 2.5) Variables
#
# Decision variables represent the quantities or values that the optimization algorithm seeks to determine in order to optimize the objective function while satisfying any given constraints, in our case, the variable X defines the amount of energy produced for a given energy type *e* at a certain region *r* in a specific time period *t*. For instance, the code: value(X["wind", 16, 2]) after the model has been developed and solved, will return the optimal energy production for energy "wind" in region 16 at time period 2. <br>
#
# This is the mathematical notation for our variables: <br>
# - **$X_{e,r,t}$** : Amount of energy produced of type *e* produced in region *r* at time period *t*

# %%
model.X = Var(model.e, model.r, model.t, within=NonNegativeReals)

# %% [markdown]
# ## 2.6) Objective Function
#
# Our main goal is to minimize the total cost of energy production.
#
# It is for this reason that our objective function would be the summatory of the variable X multiplied with the cost of producing 1 unit (kwH) of that type of energy with respect to the type of energy *e* in region *r* at time period *t*. It is important to mention that to sum through the set energies, there is an already existing list called "energies" that contains all the possible energies that can be produced, for the sets region (*r*) and time period (*t*) we could iterate by summing from 1 to 25 and from 1 to 4 respectively as the regions and time periods are considered numbers (Region 1 = 1, Time period 2= 2). <br>
#
# In mathematical notation would be:

# %% [markdown]
# \begin{align}
# min \sum_{e\ \in \ energies}\sum_{r=1}^{25}\sum_{t=1}^4 ( C_{e,r}*X_{e,r,t})
# \end{align}

# %% [markdown]
# Now we must translate this mathematical notation to Pyomo in order to declare the objective function, so we must use the sum() function where we have to multiply between the cost of producing a certain type of energy *e* at a certain region *r* by the total production of a certain type of energy *e* in region *r* at time period *t*. It is necessary to iterate through the sets *e*, *r* and *t* to make the summation. The sense for this objective function is to minimize it, as we want to fulfill all the constraints like fulfilling the demand but at the same time investing the least amount of money as possible.

# %%
# Objective function
model.obj = Objective(
    expr=sum(
        model.C[e,r] * model.X[e,r,t]
        for e in model.e for r in model.r for t in model.t
    ),
    sense=minimize,
)

# %% [markdown]
# ## 2.7) Constraints
#
#
# Constraints are essential conditions that must be met to be sure about the validity of a solution in an optimization problem. They serve a critical role in marking the feasible region of the optimization problem, directing the optimization algorithm to explore solutions that align with predefined limitations previously established. <br>
#
# They act as guiding principles, shaping the space within which the optimization algorithm searches for the most optimal solution but getting limited by these constraints to ensure reliable and useful results.

# %% [markdown]
# **1) Electricity demand constraint:** <br>
#
# This constraints ensures that the demand is equalized or surpassed by the total amount of energy produced for any region and time period, no matters which type of energy is produced. It is for this reason that the total production of energy (the summatory of all energies) is equal or greater to the demand at a specific region and a certain time period.
#
# \begin{align}
# \sum_{e\ \in \ energies}(X_{e,r,t}) ≥ d_{r,t},  \qquad        {r\ \in \ regions}, {t\ \in \ time periods}
# \end{align}

# %%
#Demand constraint

# The production of energy must be at least equal or greater to the demand for a certain region and time period
def demand_constraint(model, r, t):
    # The production of all the energies must be at least equal to the demand for the region in that period of time
    value = sum(model.X[e, r, t] for e in model.e)
    return value >= model.d[r, t]

model.demand_constraint = Constraint(model.r, model.t, rule=demand_constraint)

# %% [markdown]
# **2) Availability constraint:**<br>
#
# We must ensure that the production energy does not surpass the potential availability for each energy for any type of energy in any region and time period. Due to the limited capacity of obtaining an energy due to several factors such as infrastructure, disponibility, workforce or energetic reserves among other factors, it is imposible that we can have unlimited availability for every type of energy.
#
#
# <br>
# \begin{align}
# X_{e,r,t} ≤ A_{e, r,t}  \qquad        {e\ \in \ energies},  {r\ \in \ regions},  {t\ \in \ time periods}
# \end{align}
# <br>

# %%
# Availability constraint

# The production of energy must be less or equal to the availability of the energy at any region and time period
def availability_constraint(model,e,r,t):
    return model.X[e,r, t] <= model.A[e,r, t]

model.availability_constraint = Constraint(model.e, model.r, model.t, rule = availability_constraint)

# %% [markdown]
# **3) Environmental impact constraint:**
#
# The government has established an environmetal limit in order restrict the production of energies in a uncontrolled way, the reason for this is mainly to preserve the natural resources and the environment. It is for these reasons that the total environmetal impact produced from the production of energies at a region *r* at time period *t* must be lower to the environmetal treshold established. So we must establish a constraint that ensures the total production for a given energy in a region at a certain time period multiplied by the environmetal impact that produces the production of 1 unit of that energy at a specific region, must be lower of equal to the environmetal limit.<br>
#
#
# \begin{align}
# \sum_{e\ \in \ energies}(X_{e,r,t}*E_{e,r}) ≤ Environmental  Limit,  \qquad        {r\ \in \ regions}, {t\ \in \ time periods}
# \end{align}
#
# <br>

# %%
# Environmetal impact constraint

# Ensure that the ecological impact from the production of energy does not surpass the limit established.
def environmental_constraint(model, r, t):
    # The summatory of the product between the environmental impact for each energy and the production of 
    # that energy must be at most equal to the environmental limit established by the government
    #value = sum([model.E[e, r] * model.X[e, r, t] for e in model.e])
    
    value = model.E["wind", r] * model.X["wind", r, t] 
    + model.E["solar", r] * model.X["solar", r, t]  
    + model.E["fossil", r] * model.X["fossil", r, t]
    + model.E["nuclear", r] * model.X["nuclear", r, t]  
    + model.E["hydro", r] * model.X["hydro", r, t]  
    + model.E["geothermal", r] * model.X["geothermal", r, t]
    return value <= environmental_limit

model.environmental_constraint = Constraint(model.r, model.t, rule=environmental_constraint)

# %% [markdown]
# **4) Minimum production of nuclear energy (at least a 10% of total demand) constraints:** <br>
#
# As is it explained in the problem description, due to high investments done by the goverment years ago, the country has a big infrastructure related to production of nuclear power, for this reason, it is a requirement that the model fulfills at least the 10% of the total demand in nuclear energy eventhough is not the most ideal option to reduce de objective function.
#
# \begin{align}
# X_{nuclear,r,t} ≥ 0.10 * d_{r,t},  \qquad        {r\ \in \ regions}, {t\ \in \ time periods}
# \end{align}
# <br>

# %%
# Minimum nuclear production constraint

# Nuclear production should be at least 10% of the total demand imposed by the government
def min_nuclear_constraint(model, r, t):
    
    return model.X["nuclear", r, t] >= 0.10 * model.d[r,t]

model.min_nuclear_constraint = Constraint(model.r, model.t, rule = min_nuclear_constraint)

# %% [markdown]
# **5) Minimum production of renewable energy (at least a 45%) constraints:**
#
# The government is interested in having a transition to renewable energies in order to avoid the depletion of non-renewable energy reserves such as fossil fuels, it is for this reason that at least 45% of the production must be generated by renewable energies, so we must sum the different types of renewable energies that we are considering for this problem and ensure it is greater or equal to the 45% of the total demand.
#
#
# \begin{align}
# (X_{wind,r,t}  + X_{solar,r,t}  +   X_{hydro,r,t}  + X_{geothermal,r,t}) ≥ 0.45 * d_{r, t},  \qquad        {r\ \in \ regions}, {t\ \in \ time periods}
# \end{align}
# <br>
#
#
# Another way to show the mathematical notation in a more compact way could be:
#
# \begin{align}
# \sum_{i\ \in \ RenE}(X_{i,r,t}) ≥ 0.45 * d_{r, t},  \qquad        {r\ \in \ regions}, {t\ \in \ time periods} \\ where \ RenE = ["wind", "solar", "hydro", "geothermal"]
# \end{align}
# <br>

# %%
# Minimum renewable energies production constraint

def min_renewable_constraint(model,r,t):
    value =  model.X["wind",r, t] +  model.X["solar",r, t]  + model.X["hydro",r, t] + model.X["geothermal",r, t]
    return value >= 0.45 * model.d[r,t]

model.min_renewable_constraint = Constraint(model.r, model.t, rule = min_renewable_constraint)

# %% [markdown]
# We have finally declared all the constraints that we want to take into consideration in our model in order to obtain the most optimal results. The model will prioritize our objective function in order to minimize the costs of production of energies meanwhile satisfying the constraints previously imposed. Now it is turn to solve the model and study the results given by the model.

# %% [markdown]
# ## 2.8) Solve the model
#
# Now we are going to solve the model in order to see the output,  this allows for the verification of the obtained solution, enabling a quick check to ensure that the solver found a feasible and meaningful outcome that fulfills all the constraints imposed and trying to optimize to the limit the objective function.

# %%
# Solve and display the model
solver = SolverFactory('glpk')  
solver.solve(model)
model.display()
# Out:
# Model unknown
#
#   Variables:
#     X : Size=600, Index=X_index
#         Key                   : Lower : Value            : Upper : Fixed : Stale : Domain
#              ('fossil', 1, 1) :     0 : 647.767858851764 :  None : False : False : NonNegativeReals
#              ('fossil', 1, 2) :     0 : 629.124843438796 :  None : False : False : NonNegativeReals
#              ('fossil', 1, 3) :     0 : 152.593935743034 :  None : False : False : NonNegativeReals
#              ('fossil', 1, 4) :     0 : 563.628802826827 :  None : False : False : NonNegativeReals
#              ('fossil', 2, 1) :     0 : 738.204768643991 :  None : False : False : NonNegativeReals
#              ('fossil', 2, 2) :     0 : 652.204122817596 :  None : False : False : NonNegativeReals
#              ('fossil', 2, 3) :     0 : 324.202601270764 :  None : False : False : NonNegativeReals
#              ('fossil', 2, 4) :     0 : 404.877354156557 :  None : False : False : NonNegativeReals
#              ('fossil', 3, 1) :     0 : 885.438823938025 :  None : False : False : NonNegativeReals
#              ('fossil', 3, 2) :     0 :           881.55 :  None : False : False : NonNegativeReals
#              ('fossil', 3, 3) :     0 :            713.7 :  None : False : False : NonNegativeReals
#              ('fossil', 3, 4) :     0 :           797.85 :  None : False : False : NonNegativeReals
#              ('fossil', 4, 1) :     0 :            956.7 :  None : False : False : NonNegativeReals
#              ('fossil', 4, 2) :     0 : 746.417159472331 :  None : False : False : NonNegativeReals
#              ('fossil', 4, 3) :     0 :           725.85 :  None : False : False : NonNegativeReals
#              ('fossil', 4, 4) :     0 :           811.35 :  None : False : False : NonNegativeReals
#              ('fossil', 5, 1) :     0 :  714.32694779878 :  None : False : False : NonNegativeReals
#              ('fossil', 5, 2) :     0 : 805.180848115999 :  None : False : False : NonNegativeReals
#              ('fossil', 5, 3) :     0 :            694.8 :  None : False : False : NonNegativeReals
#              ('fossil', 5, 4) :     0 :            776.7 :  None : False : False : NonNegativeReals
#              ('fossil', 6, 1) :     0 : 711.381290829756 :  None : False : False : NonNegativeReals
#              ('fossil', 6, 2) :     0 : 534.126488884472 :  None : False : False : NonNegativeReals
#              ('fossil', 6, 3) :     0 : 129.366668505864 :  None : False : False : NonNegativeReals
#              ('fossil', 6, 4) :     0 : 430.671706145866 :  None : False : False : NonNegativeReals
#              ('fossil', 7, 1) :     0 : 741.022393254327 :  None : False : False : NonNegativeReals
#              ('fossil', 7, 2) :     0 : 819.424870344189 :  None : False : False : NonNegativeReals
#              ('fossil', 7, 3) :     0 : 642.238762323717 :  None : False : False : NonNegativeReals
#              ('fossil', 7, 4) :     0 : 727.027954786743 :  None : False : False : NonNegativeReals
#              ('fossil', 8, 1) :     0 : 763.634035450727 :  None : False : False : NonNegativeReals
#              ('fossil', 8, 2) :     0 : 882.353806399193 :  None : False : False : NonNegativeReals
#              ('fossil', 8, 3) :     0 : 568.717233004778 :  None : False : False : NonNegativeReals
#              ('fossil', 8, 4) :     0 : 809.739871916346 :  None : False : False : NonNegativeReals
#              ('fossil', 9, 1) :     0 : 724.881849172099 :  None : False : False : NonNegativeReals
#              ('fossil', 9, 2) :     0 : 610.611161697004 :  None : False : False : NonNegativeReals
#              ('fossil', 9, 3) :     0 : 92.2305593320464 :  None : False : False : NonNegativeReals
#              ('fossil', 9, 4) :     0 : 447.875552452239 :  None : False : False : NonNegativeReals
#             ('fossil', 10, 1) :     0 : 806.789776263251 :  None : False : False : NonNegativeReals
#             ('fossil', 10, 2) :     0 :           895.95 :  None : False : False : NonNegativeReals
#             ('fossil', 10, 3) :     0 :            725.4 :  None : False : False : NonNegativeReals
#             ('fossil', 10, 4) :     0 :           810.45 :  None : False : False : NonNegativeReals
#             ('fossil', 11, 1) :     0 : 718.751027218055 :  None : False : False : NonNegativeReals
#             ('fossil', 11, 2) :     0 : 693.382785617075 :  None : False : False : NonNegativeReals
#             ('fossil', 11, 3) :     0 : 86.2933429146881 :  None : False : False : NonNegativeReals
#             ('fossil', 11, 4) :     0 : 586.024593881955 :  None : False : False : NonNegativeReals
#             ('fossil', 12, 1) :     0 : 640.472684517946 :  None : False : False : NonNegativeReals
#             ('fossil', 12, 2) :     0 : 393.027971681982 :  None : False : False : NonNegativeReals
#             ('fossil', 12, 3) :     0 : 230.205594379244 :  None : False : False : NonNegativeReals
#             ('fossil', 12, 4) :     0 : 359.435423770709 :  None : False : False : NonNegativeReals
#             ('fossil', 13, 1) :     0 : 812.898711673201 :  None : False : False : NonNegativeReals
#             ('fossil', 13, 2) :     0 :           872.55 :  None : False : False : NonNegativeReals
#             ('fossil', 13, 3) :     0 : 648.680740797485 :  None : False : False : NonNegativeReals
#             ('fossil', 13, 4) :     0 :           789.75 :  None : False : False : NonNegativeReals
#             ('fossil', 14, 1) :     0 : 840.354296729377 :  None : False : False : NonNegativeReals
#             ('fossil', 14, 2) :     0 :           885.15 :  None : False : False : NonNegativeReals
#             ('fossil', 14, 3) :     0 :            716.4 :  None : False : False : NonNegativeReals
#             ('fossil', 14, 4) :     0 :           800.55 :  None : False : False : NonNegativeReals
#             ('fossil', 15, 1) :     0 : 416.938398692808 :  None : False : False : NonNegativeReals
#             ('fossil', 15, 2) :     0 : 377.291604068415 :  None : False : False : NonNegativeReals
#             ('fossil', 15, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#             ('fossil', 15, 4) :     0 : 250.180545094252 :  None : False : False : NonNegativeReals
#             ('fossil', 16, 1) :     0 : 852.637568880643 :  None : False : False : NonNegativeReals
#             ('fossil', 16, 2) :     0 : 803.855954268706 :  None : False : False : NonNegativeReals
#             ('fossil', 16, 3) :     0 :            755.1 :  None : False : False : NonNegativeReals
#             ('fossil', 16, 4) :     0 : 643.738648018111 :  None : False : False : NonNegativeReals
#             ('fossil', 17, 1) :     0 : 880.449052421351 :  None : False : False : NonNegativeReals
#             ('fossil', 17, 2) :     0 : 581.144134574875 :  None : False : False : NonNegativeReals
#             ('fossil', 17, 3) :     0 : 169.812752818975 :  None : False : False : NonNegativeReals
#             ('fossil', 17, 4) :     0 : 325.289740952257 :  None : False : False : NonNegativeReals
#             ('fossil', 18, 1) :     0 : 977.272723979127 :  None : False : False : NonNegativeReals
#             ('fossil', 18, 2) :     0 : 792.875133379297 :  None : False : False : NonNegativeReals
#             ('fossil', 18, 3) :     0 : 625.894945443674 :  None : False : False : NonNegativeReals
#             ('fossil', 18, 4) :     0 :           834.75 :  None : False : False : NonNegativeReals
#             ('fossil', 19, 1) :     0 : 823.547329645443 :  None : False : False : NonNegativeReals
#             ('fossil', 19, 2) :     0 :           889.65 :  None : False : False : NonNegativeReals
#             ('fossil', 19, 3) :     0 :           720.45 :  None : False : False : NonNegativeReals
#             ('fossil', 19, 4) :     0 :           805.05 :  None : False : False : NonNegativeReals
#             ('fossil', 20, 1) :     0 : 829.943848099427 :  None : False : False : NonNegativeReals
#             ('fossil', 20, 2) :     0 : 723.207427050955 :  None : False : False : NonNegativeReals
#             ('fossil', 20, 3) :     0 : 417.821749068612 :  None : False : False : NonNegativeReals
#             ('fossil', 20, 4) :     0 :  593.26235887001 :  None : False : False : NonNegativeReals
#             ('fossil', 21, 1) :     0 : 721.362962242774 :  None : False : False : NonNegativeReals
#             ('fossil', 21, 2) :     0 : 683.270302040154 :  None : False : False : NonNegativeReals
#             ('fossil', 21, 3) :     0 : 244.263685190678 :  None : False : False : NonNegativeReals
#             ('fossil', 21, 4) :     0 : 268.327592722684 :  None : False : False : NonNegativeReals
#             ('fossil', 22, 1) :     0 : 888.807839918245 :  None : False : False : NonNegativeReals
#             ('fossil', 22, 2) :     0 : 728.151470442922 :  None : False : False : NonNegativeReals
#             ('fossil', 22, 3) :     0 :            725.4 :  None : False : False : NonNegativeReals
#             ('fossil', 22, 4) :     0 :           810.45 :  None : False : False : NonNegativeReals
#             ('fossil', 23, 1) :     0 : 656.456613929632 :  None : False : False : NonNegativeReals
#             ('fossil', 23, 2) :     0 : 182.631191012626 :  None : False : False : NonNegativeReals
#             ('fossil', 23, 3) :     0 : 57.3421989772976 :  None : False : False : NonNegativeReals
#             ('fossil', 23, 4) :     0 : 313.380557500052 :  None : False : False : NonNegativeReals
#             ('fossil', 24, 1) :     0 :  919.89852174306 :  None : False : False : NonNegativeReals
#             ('fossil', 24, 2) :     0 :           873.45 :  None : False : False : NonNegativeReals
#             ('fossil', 24, 3) :     0 :            707.4 :  None : False : False : NonNegativeReals
#             ('fossil', 24, 4) :     0 : 786.238266187801 :  None : False : False : NonNegativeReals
#             ('fossil', 25, 1) :     0 : 727.131424073274 :  None : False : False : NonNegativeReals
#             ('fossil', 25, 2) :     0 :            876.6 :  None : False : False : NonNegativeReals
#             ('fossil', 25, 3) :     0 :           709.65 :  None : False : False : NonNegativeReals
#             ('fossil', 25, 4) :     0 :            792.9 :  None : False : False : NonNegativeReals
#          ('geothermal', 1, 1) :     0 : 531.880339830017 :  None : False : False : NonNegativeReals
#          ('geothermal', 1, 2) :     0 : 392.996302390614 :  None : False : False : NonNegativeReals
#          ('geothermal', 1, 3) :     0 : 523.416371221344 :  None : False : False : NonNegativeReals
#          ('geothermal', 1, 4) :     0 : 342.358449735908 :  None : False : False : NonNegativeReals
#          ('geothermal', 2, 1) :     0 : 467.647930394276 :  None : False : False : NonNegativeReals
#          ('geothermal', 2, 2) :     0 : 371.785280836698 :  None : False : False : NonNegativeReals
#          ('geothermal', 2, 3) :     0 : 527.658415806706 :  None : False : False : NonNegativeReals
#          ('geothermal', 2, 4) :     0 : 547.016591326751 :  None : False : False : NonNegativeReals
#          ('geothermal', 3, 1) :     0 :  331.60339442489 :  None : False : False : NonNegativeReals
#          ('geothermal', 3, 2) :     0 : 467.377027712706 :  None : False : False : NonNegativeReals
#          ('geothermal', 3, 3) :     0 : 269.184968418099 :  None : False : False : NonNegativeReals
#          ('geothermal', 3, 4) :     0 : 392.849488820934 :  None : False : False : NonNegativeReals
#          ('geothermal', 4, 1) :     0 : 234.643481728979 :  None : False : False : NonNegativeReals
#          ('geothermal', 4, 2) :     0 : 261.147791306701 :  None : False : False : NonNegativeReals
#          ('geothermal', 4, 3) :     0 : 10.5376661578816 :  None : False : False : NonNegativeReals
#          ('geothermal', 4, 4) :     0 : 171.439934000491 :  None : False : False : NonNegativeReals
#          ('geothermal', 5, 1) :     0 : 169.003200774044 :  None : False : False : NonNegativeReals
#          ('geothermal', 5, 2) :     0 : 210.937616174975 :  None : False : False : NonNegativeReals
#          ('geothermal', 5, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          ('geothermal', 5, 4) :     0 : 154.948421358933 :  None : False : False : NonNegativeReals
#          ('geothermal', 6, 1) :     0 : 507.118840285386 :  None : False : False : NonNegativeReals
#          ('geothermal', 6, 2) :     0 : 303.892378644079 :  None : False : False : NonNegativeReals
#          ('geothermal', 6, 3) :     0 : 309.272836158708 :  None : False : False : NonNegativeReals
#          ('geothermal', 6, 4) :     0 : 315.700315492257 :  None : False : False : NonNegativeReals
#          ('geothermal', 7, 1) :     0 : 333.879926483779 :  None : False : False : NonNegativeReals
#          ('geothermal', 7, 2) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          ('geothermal', 7, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          ('geothermal', 7, 4) :     0 : 205.590995407188 :  None : False : False : NonNegativeReals
#          ('geothermal', 8, 1) :     0 : 450.515425054444 :  None : False : False : NonNegativeReals
#          ('geothermal', 8, 2) :     0 : 115.956717671279 :  None : False : False : NonNegativeReals
#          ('geothermal', 8, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          ('geothermal', 8, 4) :     0 :  100.09600127035 :  None : False : False : NonNegativeReals
#          ('geothermal', 9, 1) :     0 : 506.426207412583 :  None : False : False : NonNegativeReals
#          ('geothermal', 9, 2) :     0 : 355.371403472664 :  None : False : False : NonNegativeReals
#          ('geothermal', 9, 3) :     0 : 470.901757871721 :  None : False : False : NonNegativeReals
#          ('geothermal', 9, 4) :     0 : 392.293284484095 :  None : False : False : NonNegativeReals
#         ('geothermal', 10, 1) :     0 : 296.944702410232 :  None : False : False : NonNegativeReals
#         ('geothermal', 10, 2) :     0 : 3.29068803462525 :  None : False : False : NonNegativeReals
#         ('geothermal', 10, 3) :     0 : 69.9943260219099 :  None : False : False : NonNegativeReals
#         ('geothermal', 10, 4) :     0 : 186.938447606937 :  None : False : False : NonNegativeReals
#         ('geothermal', 11, 1) :     0 : 407.585204096309 :  None : False : False : NonNegativeReals
#         ('geothermal', 11, 2) :     0 : 409.034957853876 :  None : False : False : NonNegativeReals
#         ('geothermal', 11, 3) :     0 : 541.039241661035 :  None : False : False : NonNegativeReals
#         ('geothermal', 11, 4) :     0 : 360.652315573616 :  None : False : False : NonNegativeReals
#         ('geothermal', 12, 1) :     0 : 578.808747315538 :  None : False : False : NonNegativeReals
#         ('geothermal', 12, 2) :     0 : 565.369706064565 :  None : False : False : NonNegativeReals
#         ('geothermal', 12, 3) :     0 : 407.117739752547 :  None : False : False : NonNegativeReals
#         ('geothermal', 12, 4) :     0 : 396.538819840039 :  None : False : False : NonNegativeReals
#         ('geothermal', 13, 1) :     0 : 265.477325886574 :  None : False : False : NonNegativeReals
#         ('geothermal', 13, 2) :     0 : 65.0918473877192 :  None : False : False : NonNegativeReals
#         ('geothermal', 13, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         ('geothermal', 13, 4) :     0 : 6.26535926254326 :  None : False : False : NonNegativeReals
#         ('geothermal', 14, 1) :     0 : 382.123934832162 :  None : False : False : NonNegativeReals
#         ('geothermal', 14, 2) :     0 : 70.7197314124726 :  None : False : False : NonNegativeReals
#         ('geothermal', 14, 3) :     0 : 27.1468051988802 :  None : False : False : NonNegativeReals
#         ('geothermal', 14, 4) :     0 : 34.7611624185463 :  None : False : False : NonNegativeReals
#         ('geothermal', 15, 1) :     0 : 568.690737260624 :  None : False : False : NonNegativeReals
#         ('geothermal', 15, 2) :     0 : 410.601837410709 :  None : False : False : NonNegativeReals
#         ('geothermal', 15, 3) :     0 : 561.429637411243 :  None : False : False : NonNegativeReals
#         ('geothermal', 15, 4) :     0 :  477.22516279257 :  None : False : False : NonNegativeReals
#         ('geothermal', 16, 1) :     0 : 531.018934827509 :  None : False : False : NonNegativeReals
#         ('geothermal', 16, 2) :     0 : 400.571491984538 :  None : False : False : NonNegativeReals
#         ('geothermal', 16, 3) :     0 : 340.259668878418 :  None : False : False : NonNegativeReals
#         ('geothermal', 16, 4) :     0 :  488.70198212104 :  None : False : False : NonNegativeReals
#         ('geothermal', 17, 1) :     0 : 365.525592428588 :  None : False : False : NonNegativeReals
#         ('geothermal', 17, 2) :     0 : 542.038387953776 :  None : False : False : NonNegativeReals
#         ('geothermal', 17, 3) :     0 : 436.306843769312 :  None : False : False : NonNegativeReals
#         ('geothermal', 17, 4) :     0 : 553.581419700431 :  None : False : False : NonNegativeReals
#         ('geothermal', 18, 1) :     0 : 219.903195150006 :  None : False : False : NonNegativeReals
#         ('geothermal', 18, 2) :     0 : 225.771447371721 :  None : False : False : NonNegativeReals
#         ('geothermal', 18, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         ('geothermal', 18, 4) :     0 : 146.938545848309 :  None : False : False : NonNegativeReals
#         ('geothermal', 19, 1) :     0 : 519.844754583304 :  None : False : False : NonNegativeReals
#         ('geothermal', 19, 2) :     0 : 351.854015922147 :  None : False : False : NonNegativeReals
#         ('geothermal', 19, 3) :     0 : 209.794726407632 :  None : False : False : NonNegativeReals
#         ('geothermal', 19, 4) :     0 : 351.840391866947 :  None : False : False : NonNegativeReals
#         ('geothermal', 20, 1) :     0 : 518.664785746871 :  None : False : False : NonNegativeReals
#         ('geothermal', 20, 2) :     0 :  479.26046518768 :  None : False : False : NonNegativeReals
#         ('geothermal', 20, 3) :     0 : 495.797244711775 :  None : False : False : NonNegativeReals
#         ('geothermal', 20, 4) :     0 : 513.089404247834 :  None : False : False : NonNegativeReals
#         ('geothermal', 21, 1) :     0 : 496.038122958123 :  None : False : False : NonNegativeReals
#         ('geothermal', 21, 2) :     0 :  444.99333283501 :  None : False : False : NonNegativeReals
#         ('geothermal', 21, 3) :     0 : 432.112750482376 :  None : False : False : NonNegativeReals
#         ('geothermal', 21, 4) :     0 : 533.632834333241 :  None : False : False : NonNegativeReals
#         ('geothermal', 22, 1) :     0 : 300.959785374063 :  None : False : False : NonNegativeReals
#         ('geothermal', 22, 2) :     0 : 332.620623618228 :  None : False : False : NonNegativeReals
#         ('geothermal', 22, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         ('geothermal', 22, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         ('geothermal', 23, 1) :     0 : 337.545958815306 :  None : False : False : NonNegativeReals
#         ('geothermal', 23, 2) :     0 :   581.6366481569 :  None : False : False : NonNegativeReals
#         ('geothermal', 23, 3) :     0 : 532.352248332529 :  None : False : False : NonNegativeReals
#         ('geothermal', 23, 4) :     0 : 405.508829750144 :  None : False : False : NonNegativeReals
#         ('geothermal', 24, 1) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         ('geothermal', 24, 2) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         ('geothermal', 24, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         ('geothermal', 24, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         ('geothermal', 25, 1) :     0 : 236.333656369565 :  None : False : False : NonNegativeReals
#         ('geothermal', 25, 2) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         ('geothermal', 25, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         ('geothermal', 25, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#               ('hydro', 1, 1) :     0 : 293.870559580723 :  None : False : False : NonNegativeReals
#               ('hydro', 1, 2) :     0 : 385.084216835823 :  None : False : False : NonNegativeReals
#               ('hydro', 1, 3) :     0 : 266.158330236902 :  None : False : False : NonNegativeReals
#               ('hydro', 1, 4) :     0 :  260.98840908617 :  None : False : False : NonNegativeReals
#               ('hydro', 2, 1) :     0 : 296.844500745686 :  None : False : False : NonNegativeReals
#               ('hydro', 2, 2) :     0 : 384.981337115544 :  None : False : False : NonNegativeReals
#               ('hydro', 2, 3) :     0 : 229.017853462646 :  None : False : False : NonNegativeReals
#               ('hydro', 2, 4) :     0 : 336.031412069461 :  None : False : False : NonNegativeReals
#               ('hydro', 3, 1) :     0 : 303.305700828317 :  None : False : False : NonNegativeReals
#               ('hydro', 3, 2) :     0 :              0.0 :  None : False : False : NonNegativeReals
#               ('hydro', 3, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#               ('hydro', 3, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#               ('hydro', 4, 1) :     0 : 322.480266400655 :  None : False : False : NonNegativeReals
#               ('hydro', 4, 2) :     0 : 330.411391343695 :  None : False : False : NonNegativeReals
#               ('hydro', 4, 3) :     0 : 211.520643655438 :  None : False : False : NonNegativeReals
#               ('hydro', 4, 4) :     0 : 277.164490913764 :  None : False : False : NonNegativeReals
#               ('hydro', 5, 1) :     0 : 346.645805644214 :  None : False : False : NonNegativeReals
#               ('hydro', 5, 2) :     0 : 227.170168457387 :  None : False : False : NonNegativeReals
#               ('hydro', 5, 3) :     0 : 125.530593166818 :  None : False : False : NonNegativeReals
#               ('hydro', 5, 4) :     0 : 204.630888929693 :  None : False : False : NonNegativeReals
#               ('hydro', 6, 1) :     0 : 203.491340730905 :  None : False : False : NonNegativeReals
#               ('hydro', 6, 2) :     0 : 294.551878609074 :  None : False : False : NonNegativeReals
#               ('hydro', 6, 3) :     0 : 368.820530834343 :  None : False : False : NonNegativeReals
#               ('hydro', 6, 4) :     0 : 377.419618403193 :  None : False : False : NonNegativeReals
#               ('hydro', 7, 1) :     0 : 260.126206833112 :  None : False : False : NonNegativeReals
#               ('hydro', 7, 2) :     0 : 387.753200334779 :  None : False : False : NonNegativeReals
#               ('hydro', 7, 3) :     0 :  317.66483527493 :  None : False : False : NonNegativeReals
#               ('hydro', 7, 4) :     0 : 219.742953807974 :  None : False : False : NonNegativeReals
#               ('hydro', 8, 1) :     0 : 219.268505153205 :  None : False : False : NonNegativeReals
#               ('hydro', 8, 2) :     0 : 313.122209704638 :  None : False : False : NonNegativeReals
#               ('hydro', 8, 3) :     0 : 351.347735936793 :  None : False : False : NonNegativeReals
#               ('hydro', 8, 4) :     0 :  227.82150584979 :  None : False : False : NonNegativeReals
#               ('hydro', 9, 1) :     0 : 274.494835896921 :  None : False : False : NonNegativeReals
#               ('hydro', 9, 2) :     0 :  397.68649204586 :  None : False : False : NonNegativeReals
#               ('hydro', 9, 3) :     0 : 380.562273915807 :  None : False : False : NonNegativeReals
#               ('hydro', 9, 4) :     0 : 270.194814220467 :  None : False : False : NonNegativeReals
#              ('hydro', 10, 1) :     0 : 297.686428817684 :  None : False : False : NonNegativeReals
#              ('hydro', 10, 2) :     0 : 321.194866214991 :  None : False : False : NonNegativeReals
#              ('hydro', 10, 3) :     0 : 201.426917679802 :  None : False : False : NonNegativeReals
#              ('hydro', 10, 4) :     0 : 212.535087783873 :  None : False : False : NonNegativeReals
#              ('hydro', 11, 1) :     0 : 331.344544923527 :  None : False : False : NonNegativeReals
#              ('hydro', 11, 2) :     0 : 231.824001236835 :  None : False : False : NonNegativeReals
#              ('hydro', 11, 3) :     0 : 382.012125737297 :  None : False : False : NonNegativeReals
#              ('hydro', 11, 4) :     0 :   279.0196798255 :  None : False : False : NonNegativeReals
#              ('hydro', 12, 1) :     0 : 293.881452642544 :  None : False : False : NonNegativeReals
#              ('hydro', 12, 2) :     0 : 321.932897780628 :  None : False : False : NonNegativeReals
#              ('hydro', 12, 3) :     0 : 364.263269094999 :  None : False : False : NonNegativeReals
#              ('hydro', 12, 4) :     0 : 296.225201565256 :  None : False : False : NonNegativeReals
#              ('hydro', 13, 1) :     0 : 249.377473045856 :  None : False : False : NonNegativeReals
#              ('hydro', 13, 2) :     0 : 280.469411275655 :  None : False : False : NonNegativeReals
#              ('hydro', 13, 3) :     0 : 240.905344686826 :  None : False : False : NonNegativeReals
#              ('hydro', 13, 4) :     0 : 354.127012439907 :  None : False : False : NonNegativeReals
#              ('hydro', 14, 1) :     0 : 223.790870029751 :  None : False : False : NonNegativeReals
#              ('hydro', 14, 2) :     0 : 396.895209310626 :  None : False : False : NonNegativeReals
#              ('hydro', 14, 3) :     0 : 251.313042200772 :  None : False : False : NonNegativeReals
#              ('hydro', 14, 4) :     0 : 279.208654686091 :  None : False : False : NonNegativeReals
#              ('hydro', 15, 1) :     0 : 328.090839501357 :  None : False : False : NonNegativeReals
#              ('hydro', 15, 2) :     0 : 320.990826187906 :  None : False : False : NonNegativeReals
#              ('hydro', 15, 3) :     0 : 207.271284580452 :  None : False : False : NonNegativeReals
#              ('hydro', 15, 4) :     0 : 391.680290767286 :  None : False : False : NonNegativeReals
#              ('hydro', 16, 1) :     0 : 127.925233870701 :  None : False : False : NonNegativeReals
#              ('hydro', 16, 2) :     0 : 140.320930312429 :  None : False : False : NonNegativeReals
#              ('hydro', 16, 3) :     0 :  17.287737322255 :  None : False : False : NonNegativeReals
#              ('hydro', 16, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#              ('hydro', 17, 1) :     0 : 220.090144348815 :  None : False : False : NonNegativeReals
#              ('hydro', 17, 2) :     0 : 210.937389332952 :  None : False : False : NonNegativeReals
#              ('hydro', 17, 3) :     0 : 383.018233892464 :  None : False : False : NonNegativeReals
#              ('hydro', 17, 4) :     0 : 307.170347946735 :  None : False : False : NonNegativeReals
#              ('hydro', 18, 1) :     0 : 241.080283067088 :  None : False : False : NonNegativeReals
#              ('hydro', 18, 2) :     0 : 313.379710094762 :  None : False : False : NonNegativeReals
#              ('hydro', 18, 3) :     0 : 391.381805072879 :  None : False : False : NonNegativeReals
#              ('hydro', 18, 4) :     0 : 249.656378940513 :  None : False : False : NonNegativeReals
#              ('hydro', 19, 1) :     0 : 3.68818195297763 :  None : False : False : NonNegativeReals
#              ('hydro', 19, 2) :     0 :              0.0 :  None : False : False : NonNegativeReals
#              ('hydro', 19, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#              ('hydro', 19, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#              ('hydro', 20, 1) :     0 :              0.0 :  None : False : False : NonNegativeReals
#              ('hydro', 20, 2) :     0 :              0.0 :  None : False : False : NonNegativeReals
#              ('hydro', 20, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#              ('hydro', 20, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#              ('hydro', 21, 1) :     0 : 256.436158596683 :  None : False : False : NonNegativeReals
#              ('hydro', 21, 2) :     0 : 277.809735261654 :  None : False : False : NonNegativeReals
#              ('hydro', 21, 3) :     0 : 313.871931649171 :  None : False : False : NonNegativeReals
#              ('hydro', 21, 4) :     0 : 312.869285364198 :  None : False : False : NonNegativeReals
#              ('hydro', 22, 1) :     0 : 236.957289863086 :  None : False : False : NonNegativeReals
#              ('hydro', 22, 2) :     0 : 221.207050757927 :  None : False : False : NonNegativeReals
#              ('hydro', 22, 3) :     0 : 183.771765819887 :  None : False : False : NonNegativeReals
#              ('hydro', 22, 4) :     0 : 233.404749160432 :  None : False : False : NonNegativeReals
#              ('hydro', 23, 1) :     0 : 362.776804710191 :  None : False : False : NonNegativeReals
#              ('hydro', 23, 2) :     0 : 397.214890161299 :  None : False : False : NonNegativeReals
#              ('hydro', 23, 3) :     0 : 354.955588736603 :  None : False : False : NonNegativeReals
#              ('hydro', 23, 4) :     0 : 356.252921993805 :  None : False : False : NonNegativeReals
#              ('hydro', 24, 1) :     0 : 292.180672228222 :  None : False : False : NonNegativeReals
#              ('hydro', 24, 2) :     0 :  340.95580154256 :  None : False : False : NonNegativeReals
#              ('hydro', 24, 3) :     0 : 188.573897242771 :  None : False : False : NonNegativeReals
#              ('hydro', 24, 4) :     0 : 247.158696723971 :  None : False : False : NonNegativeReals
#              ('hydro', 25, 1) :     0 :  396.11328885463 :  None : False : False : NonNegativeReals
#              ('hydro', 25, 2) :     0 : 334.800126765811 :  None : False : False : NonNegativeReals
#              ('hydro', 25, 3) :     0 : 251.041100351198 :  None : False : False : NonNegativeReals
#              ('hydro', 25, 4) :     0 : 179.463304855072 :  None : False : False : NonNegativeReals
#             ('nuclear', 1, 1) :     0 :            213.8 :  None : False : False : NonNegativeReals
#             ('nuclear', 1, 2) :     0 :            200.4 :  None : False : False : NonNegativeReals
#             ('nuclear', 1, 3) :     0 :            162.3 :  None : False : False : NonNegativeReals
#             ('nuclear', 1, 4) :     0 :            181.4 :  None : False : False : NonNegativeReals
#             ('nuclear', 2, 1) :     0 : 281.844072909736 :  None : False : False : NonNegativeReals
#             ('nuclear', 2, 2) :     0 :            202.2 :  None : False : False : NonNegativeReals
#             ('nuclear', 2, 3) :     0 :            163.7 :  None : False : False : NonNegativeReals
#             ('nuclear', 2, 4) :     0 :            183.0 :  None : False : False : NonNegativeReals
#             ('nuclear', 3, 1) :     0 :            209.0 :  None : False : False : NonNegativeReals
#             ('nuclear', 3, 2) :     0 :            195.9 :  None : False : False : NonNegativeReals
#             ('nuclear', 3, 3) :     0 :            158.6 :  None : False : False : NonNegativeReals
#             ('nuclear', 3, 4) :     0 :            177.3 :  None : False : False : NonNegativeReals
#             ('nuclear', 4, 1) :     0 :            212.6 :  None : False : False : NonNegativeReals
#             ('nuclear', 4, 2) :     0 :            199.3 :  None : False : False : NonNegativeReals
#             ('nuclear', 4, 3) :     0 :            161.3 :  None : False : False : NonNegativeReals
#             ('nuclear', 4, 4) :     0 :            180.3 :  None : False : False : NonNegativeReals
#             ('nuclear', 5, 1) :     0 :            203.5 :  None : False : False : NonNegativeReals
#             ('nuclear', 5, 2) :     0 :            190.8 :  None : False : False : NonNegativeReals
#             ('nuclear', 5, 3) :     0 :            154.4 :  None : False : False : NonNegativeReals
#             ('nuclear', 5, 4) :     0 :            172.6 :  None : False : False : NonNegativeReals
#             ('nuclear', 6, 1) :     0 :            210.9 :  None : False : False : NonNegativeReals
#             ('nuclear', 6, 2) :     0 :            197.7 :  None : False : False : NonNegativeReals
#             ('nuclear', 6, 3) :     0 :            160.1 :  None : False : False : NonNegativeReals
#             ('nuclear', 6, 4) :     0 :            178.9 :  None : False : False : NonNegativeReals
#             ('nuclear', 7, 1) :     0 :  337.61812714852 :  None : False : False : NonNegativeReals
#             ('nuclear', 7, 2) :     0 :            200.1 :  None : False : False : NonNegativeReals
#             ('nuclear', 7, 3) :     0 :            162.0 :  None : False : False : NonNegativeReals
#             ('nuclear', 7, 4) :     0 :            181.1 :  None : False : False : NonNegativeReals
#             ('nuclear', 8, 1) :     0 :            215.4 :  None : False : False : NonNegativeReals
#             ('nuclear', 8, 2) :     0 :            201.9 :  None : False : False : NonNegativeReals
#             ('nuclear', 8, 3) :     0 :            163.5 :  None : False : False : NonNegativeReals
#             ('nuclear', 8, 4) :     0 :            182.7 :  None : False : False : NonNegativeReals
#             ('nuclear', 9, 1) :     0 :            208.0 :  None : False : False : NonNegativeReals
#             ('nuclear', 9, 2) :     0 :            195.0 :  None : False : False : NonNegativeReals
#             ('nuclear', 9, 3) :     0 :            157.8 :  None : False : False : NonNegativeReals
#             ('nuclear', 9, 4) :     0 :            176.4 :  None : False : False : NonNegativeReals
#            ('nuclear', 10, 1) :     0 :            212.4 :  None : False : False : NonNegativeReals
#            ('nuclear', 10, 2) :     0 :            199.1 :  None : False : False : NonNegativeReals
#            ('nuclear', 10, 3) :     0 :            161.2 :  None : False : False : NonNegativeReals
#            ('nuclear', 10, 4) :     0 :            180.1 :  None : False : False : NonNegativeReals
#            ('nuclear', 11, 1) :     0 :            214.3 :  None : False : False : NonNegativeReals
#            ('nuclear', 11, 2) :     0 :            200.9 :  None : False : False : NonNegativeReals
#            ('nuclear', 11, 3) :     0 :            162.6 :  None : False : False : NonNegativeReals
#            ('nuclear', 11, 4) :     0 :            181.7 :  None : False : False : NonNegativeReals
#            ('nuclear', 12, 1) :     0 :            215.7 :  None : False : False : NonNegativeReals
#            ('nuclear', 12, 2) :     0 :            202.2 :  None : False : False : NonNegativeReals
#            ('nuclear', 12, 3) :     0 :            163.7 :  None : False : False : NonNegativeReals
#            ('nuclear', 12, 4) :     0 :            183.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 13, 1) :     0 :            206.9 :  None : False : False : NonNegativeReals
#            ('nuclear', 13, 2) :     0 :            193.9 :  None : False : False : NonNegativeReals
#            ('nuclear', 13, 3) :     0 :            157.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 13, 4) :     0 :            175.5 :  None : False : False : NonNegativeReals
#            ('nuclear', 14, 1) :     0 : 270.512293806977 :  None : False : False : NonNegativeReals
#            ('nuclear', 14, 2) :     0 :            196.7 :  None : False : False : NonNegativeReals
#            ('nuclear', 14, 3) :     0 :            159.2 :  None : False : False : NonNegativeReals
#            ('nuclear', 14, 4) :     0 :            177.9 :  None : False : False : NonNegativeReals
#            ('nuclear', 15, 1) :     0 :            205.2 :  None : False : False : NonNegativeReals
#            ('nuclear', 15, 2) :     0 :            192.4 :  None : False : False : NonNegativeReals
#            ('nuclear', 15, 3) :     0 :            155.7 :  None : False : False : NonNegativeReals
#            ('nuclear', 15, 4) :     0 :            174.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 16, 1) :     0 :            221.1 :  None : False : False : NonNegativeReals
#            ('nuclear', 16, 2) :     0 :            207.3 :  None : False : False : NonNegativeReals
#            ('nuclear', 16, 3) :     0 :            167.8 :  None : False : False : NonNegativeReals
#            ('nuclear', 16, 4) :     0 :            187.5 :  None : False : False : NonNegativeReals
#            ('nuclear', 17, 1) :     0 :            214.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 17, 2) :     0 :            200.7 :  None : False : False : NonNegativeReals
#            ('nuclear', 17, 3) :     0 :            162.4 :  None : False : False : NonNegativeReals
#            ('nuclear', 17, 4) :     0 :            181.5 :  None : False : False : NonNegativeReals
#            ('nuclear', 18, 1) :     0 :            218.7 :  None : False : False : NonNegativeReals
#            ('nuclear', 18, 2) :     0 :            205.1 :  None : False : False : NonNegativeReals
#            ('nuclear', 18, 3) :     0 :            166.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 18, 4) :     0 :            185.5 :  None : False : False : NonNegativeReals
#            ('nuclear', 19, 1) :     0 :            210.9 :  None : False : False : NonNegativeReals
#            ('nuclear', 19, 2) :     0 :            197.7 :  None : False : False : NonNegativeReals
#            ('nuclear', 19, 3) :     0 :            160.1 :  None : False : False : NonNegativeReals
#            ('nuclear', 19, 4) :     0 :            178.9 :  None : False : False : NonNegativeReals
#            ('nuclear', 20, 1) :     0 :            210.3 :  None : False : False : NonNegativeReals
#            ('nuclear', 20, 2) :     0 :            197.2 :  None : False : False : NonNegativeReals
#            ('nuclear', 20, 3) :     0 :            159.6 :  None : False : False : NonNegativeReals
#            ('nuclear', 20, 4) :     0 :            178.4 :  None : False : False : NonNegativeReals
#            ('nuclear', 21, 1) :     0 :            220.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 21, 2) :     0 :            206.2 :  None : False : False : NonNegativeReals
#            ('nuclear', 21, 3) :     0 :            166.9 :  None : False : False : NonNegativeReals
#            ('nuclear', 21, 4) :     0 :            186.6 :  None : False : False : NonNegativeReals
#            ('nuclear', 22, 1) :     0 : 276.230736068137 :  None : False : False : NonNegativeReals
#            ('nuclear', 22, 2) :     0 : 270.585328261034 :  None : False : False : NonNegativeReals
#            ('nuclear', 22, 3) :     0 :            161.2 :  None : False : False : NonNegativeReals
#            ('nuclear', 22, 4) :     0 :            180.1 :  None : False : False : NonNegativeReals
#            ('nuclear', 23, 1) :     0 :            209.2 :  None : False : False : NonNegativeReals
#            ('nuclear', 23, 2) :     0 :            196.1 :  None : False : False : NonNegativeReals
#            ('nuclear', 23, 3) :     0 :            158.8 :  None : False : False : NonNegativeReals
#            ('nuclear', 23, 4) :     0 :            177.5 :  None : False : False : NonNegativeReals
#            ('nuclear', 24, 1) :     0 :            207.1 :  None : False : False : NonNegativeReals
#            ('nuclear', 24, 2) :     0 :            194.1 :  None : False : False : NonNegativeReals
#            ('nuclear', 24, 3) :     0 :            157.2 :  None : False : False : NonNegativeReals
#            ('nuclear', 24, 4) :     0 :            175.7 :  None : False : False : NonNegativeReals
#            ('nuclear', 25, 1) :     0 :            207.8 :  None : False : False : NonNegativeReals
#            ('nuclear', 25, 2) :     0 :            194.8 :  None : False : False : NonNegativeReals
#            ('nuclear', 25, 3) :     0 :            157.7 :  None : False : False : NonNegativeReals
#            ('nuclear', 25, 4) :     0 :            176.2 :  None : False : False : NonNegativeReals
#               ('solar', 1, 1) :     0 : 216.126403989692 :  None : False : False : NonNegativeReals
#               ('solar', 1, 2) :     0 : 161.839799586964 :  None : False : False : NonNegativeReals
#               ('solar', 1, 3) :     0 : 283.976525050916 :  None : False : False : NonNegativeReals
#               ('solar', 1, 4) :     0 : 231.069500603291 :  None : False : False : NonNegativeReals
#               ('solar', 2, 1) :     0 : 169.848276984149 :  None : False : False : NonNegativeReals
#               ('solar', 2, 2) :     0 :    208.218808908 :  None : False : False : NonNegativeReals
#               ('solar', 2, 3) :     0 : 189.810679137722 :  None : False : False : NonNegativeReals
#               ('solar', 2, 4) :     0 : 156.464192125069 :  None : False : False : NonNegativeReals
#               ('solar', 3, 1) :     0 : 159.175305044101 :  None : False : False : NonNegativeReals
#               ('solar', 3, 2) :     0 : 212.696196522626 :  None : False : False : NonNegativeReals
#               ('solar', 3, 3) :     0 : 243.038255817233 :  None : False : False : NonNegativeReals
#               ('solar', 3, 4) :     0 : 203.523735414399 :  None : False : False : NonNegativeReals
#               ('solar', 4, 1) :     0 : 170.408365718082 :  None : False : False : NonNegativeReals
#               ('solar', 4, 2) :     0 : 226.555771724989 :  None : False : False : NonNegativeReals
#               ('solar', 4, 3) :     0 : 274.623804034396 :  None : False : False : NonNegativeReals
#               ('solar', 4, 4) :     0 :  133.57768893346 :  None : False : False : NonNegativeReals
#               ('solar', 5, 1) :     0 : 297.495664456285 :  None : False : False : NonNegativeReals
#               ('solar', 5, 2) :     0 : 169.882985924962 :  None : False : False : NonNegativeReals
#               ('solar', 5, 3) :     0 : 265.241025506505 :  None : False : False : NonNegativeReals
#               ('solar', 5, 4) :     0 : 113.092308384698 :  None : False : False : NonNegativeReals
#               ('solar', 6, 1) :     0 : 101.070657677267 :  None : False : False : NonNegativeReals
#               ('solar', 6, 2) :     0 : 277.388929502124 :  None : False : False : NonNegativeReals
#               ('solar', 6, 3) :     0 : 282.263626974469 :  None : False : False : NonNegativeReals
#               ('solar', 6, 4) :     0 : 139.881554385016 :  None : False : False : NonNegativeReals
#               ('solar', 7, 1) :     0 : 105.510276998372 :  None : False : False : NonNegativeReals
#               ('solar', 7, 2) :     0 : 263.466983925677 :  None : False : False : NonNegativeReals
#               ('solar', 7, 3) :     0 : 148.365523768967 :  None : False : False : NonNegativeReals
#               ('solar', 7, 4) :     0 :  111.21660241099 :  None : False : False : NonNegativeReals
#               ('solar', 8, 1) :     0 : 113.512166967282 :  None : False : False : NonNegativeReals
#               ('solar', 8, 2) :     0 : 194.774371000919 :  None : False : False : NonNegativeReals
#               ('solar', 8, 3) :     0 : 201.885852290063 :  None : False : False : NonNegativeReals
#               ('solar', 8, 4) :     0 : 183.359027964916 :  None : False : False : NonNegativeReals
#               ('solar', 9, 1) :     0 : 151.168586074178 :  None : False : False : NonNegativeReals
#               ('solar', 9, 2) :     0 : 176.302421340254 :  None : False : False : NonNegativeReals
#               ('solar', 9, 3) :     0 : 261.476887436208 :  None : False : False : NonNegativeReals
#               ('solar', 9, 4) :     0 : 262.207827398981 :  None : False : False : NonNegativeReals
#              ('solar', 10, 1) :     0 : 237.237371960982 :  None : False : False : NonNegativeReals
#              ('solar', 10, 2) :     0 : 298.522725202533 :  None : False : False : NonNegativeReals
#              ('solar', 10, 3) :     0 : 181.037035750437 :  None : False : False : NonNegativeReals
#              ('solar', 10, 4) :     0 :  138.03474406134 :  None : False : False : NonNegativeReals
#              ('solar', 11, 1) :     0 : 197.634897959019 :  None : False : False : NonNegativeReals
#              ('solar', 11, 2) :     0 : 200.473929489123 :  None : False : False : NonNegativeReals
#              ('solar', 11, 3) :     0 : 180.670963883889 :  None : False : False : NonNegativeReals
#              ('solar', 11, 4) :     0 : 136.219084915838 :  None : False : False : NonNegativeReals
#              ('solar', 12, 1) :     0 :  109.60596019789 :  None : False : False : NonNegativeReals
#              ('solar', 12, 2) :     0 : 220.938269146743 :  None : False : False : NonNegativeReals
#              ('solar', 12, 3) :     0 : 153.182241447127 :  None : False : False : NonNegativeReals
#              ('solar', 12, 4) :     0 : 276.269399497913 :  None : False : False : NonNegativeReals
#              ('solar', 13, 1) :     0 : 216.809223316377 :  None : False : False : NonNegativeReals
#              ('solar', 13, 2) :     0 : 195.492096747557 :  None : False : False : NonNegativeReals
#              ('solar', 13, 3) :     0 : 134.303004931773 :  None : False : False : NonNegativeReals
#              ('solar', 13, 4) :     0 : 111.323999987121 :  None : False : False : NonNegativeReals
#              ('solar', 14, 1) :     0 :  131.40704568336 :  None : False : False : NonNegativeReals
#              ('solar', 14, 2) :     0 : 167.723500358528 :  None : False : False : NonNegativeReals
#              ('solar', 14, 3) :     0 : 188.128593681975 :  None : False : False : NonNegativeReals
#              ('solar', 14, 4) :     0 : 236.768623976989 :  None : False : False : NonNegativeReals
#              ('solar', 15, 1) :     0 : 141.174344452477 :  None : False : False : NonNegativeReals
#              ('solar', 15, 2) :     0 : 223.286740347552 :  None : False : False : NonNegativeReals
#              ('solar', 15, 3) :     0 : 284.894322050558 :  None : False : False : NonNegativeReals
#              ('solar', 15, 4) :     0 : 115.925650420457 :  None : False : False : NonNegativeReals
#              ('solar', 16, 1) :     0 : 197.079365161681 :  None : False : False : NonNegativeReals
#              ('solar', 16, 2) :     0 : 239.712726174859 :  None : False : False : NonNegativeReals
#              ('solar', 16, 3) :     0 : 116.313696539859 :  None : False : False : NonNegativeReals
#              ('solar', 16, 4) :     0 : 273.820472601381 :  None : False : False : NonNegativeReals
#              ('solar', 17, 1) :     0 : 186.621135655408 :  None : False : False : NonNegativeReals
#              ('solar', 17, 2) :     0 :  198.86601299256 :  None : False : False : NonNegativeReals
#              ('solar', 17, 3) :     0 : 199.148094373411 :  None : False : False : NonNegativeReals
#              ('solar', 17, 4) :     0 :  174.14441625474 :  None : False : False : NonNegativeReals
#              ('solar', 18, 1) :     0 : 284.425732207206 :  None : False : False : NonNegativeReals
#              ('solar', 18, 2) :     0 : 268.255643557647 :  None : False : False : NonNegativeReals
#              ('solar', 18, 3) :     0 : 231.105183886875 :  None : False : False : NonNegativeReals
#              ('solar', 18, 4) :     0 : 192.537009614605 :  None : False : False : NonNegativeReals
#              ('solar', 19, 1) :     0 : 213.002262386941 :  None : False : False : NonNegativeReals
#              ('solar', 19, 2) :     0 : 184.783101388955 :  None : False : False : NonNegativeReals
#              ('solar', 19, 3) :     0 : 157.642390903469 :  None : False : False : NonNegativeReals
#              ('solar', 19, 4) :     0 : 152.796143858114 :  None : False : False : NonNegativeReals
#              ('solar', 20, 1) :     0 :  238.14764569459 :  None : False : False : NonNegativeReals
#              ('solar', 20, 2) :     0 : 266.567306264221 :  None : False : False : NonNegativeReals
# ...
#         (12, 3) :  None :  49.99999999999993 :  50.0
#         (12, 4) :  None :  49.99999999999993 :  50.0
#         (13, 1) :  None :  33.15597730246062 :  50.0
#         (13, 2) :  None : 34.613560038453706 :  50.0
#         (13, 3) :  None : 40.629412243964325 :  50.0
#         (13, 4) :  None : 33.207805470901285 :  50.0
#         (14, 1) :  None :  49.99999999999992 :  50.0
#         (14, 2) :  None :  49.99999999999992 :  50.0
#         (14, 3) :  None :  49.99999999999992 :  50.0
#         (14, 4) :  None :  49.99999999999992 :  50.0
#         (15, 1) :  None : 48.649516363167926 :  50.0
#         (15, 2) :  None :  49.58342853545819 :  50.0
#         (15, 3) :  None : 43.162600272889726 :  50.0
#         (15, 4) :  None :  41.08749633471684 :  50.0
#         (16, 1) :  None : 50.000000000000085 :  50.0
#         (16, 2) :  None : 50.000000000000085 :  50.0
#         (16, 3) :  None : 50.000000000000085 :  50.0
#         (16, 4) :  None : 50.000000000000085 :  50.0
#         (17, 1) :  None :  50.00000000000007 :  50.0
#         (17, 2) :  None :  50.00000000000007 :  50.0
#         (17, 3) :  None :  50.00000000000007 :  50.0
#         (17, 4) :  None :  50.00000000000007 :  50.0
#         (18, 1) :  None : 50.000000000000036 :  50.0
#         (18, 2) :  None : 50.000000000000036 :  50.0
#         (18, 3) :  None : 50.000000000000036 :  50.0
#         (18, 4) :  None : 50.000000000000036 :  50.0
#         (19, 1) :  None :  47.87608158329171 :  50.0
#         (19, 2) :  None :  50.00000000000004 :  50.0
#         (19, 3) :  None :  50.00000000000004 :  50.0
#         (19, 4) :  None : 42.549929337803476 :  50.0
#         (20, 1) :  None :  49.99999999999998 :  50.0
#         (20, 2) :  None : 49.970759497580204 :  50.0
#         (20, 3) :  None : 49.731808555649465 :  50.0
#         (20, 4) :  None :  49.99999999999998 :  50.0
#         (21, 1) :  None :   49.9999999999999 :  50.0
#         (21, 2) :  None :   49.9999999999999 :  50.0
#         (21, 3) :  None :   49.9999999999999 :  50.0
#         (21, 4) :  None :   49.9999999999999 :  50.0
#         (22, 1) :  None :  46.34832319635689 :  50.0
#         (22, 2) :  None : 50.000000000000064 :  50.0
#         (22, 3) :  None : 49.573797446545925 :  50.0
#         (22, 4) :  None : 50.000000000000064 :  50.0
#         (23, 1) :  None : 50.000000000000064 :  50.0
#         (23, 2) :  None :  49.31428366961713 :  50.0
#         (23, 3) :  None : 50.000000000000064 :  50.0
#         (23, 4) :  None : 50.000000000000064 :  50.0
#         (24, 1) :  None : 44.077101954989814 :  50.0
#         (24, 2) :  None :  45.54371959511088 :  50.0
#         (24, 3) :  None :   47.1683833157841 :  50.0
#         (24, 4) :  None :  47.90449614860876 :  50.0
#         (25, 1) :  None :  45.50690094299955 :  50.0
#         (25, 2) :  None :  40.72647830877914 :  50.0
#         (25, 3) :  None : 46.311948132438495 :  50.0
#         (25, 4) :  None : 46.880458459708585 :  50.0
#     min_nuclear_constraint : Size=100
#         Key     : Lower              : Body             : Upper
#          (1, 1) :              213.8 :            213.8 :  None
#          (1, 2) :              200.4 :            200.4 :  None
#          (1, 3) :              162.3 :            162.3 :  None
#          (1, 4) :              181.4 :            181.4 :  None
#          (2, 1) : 215.70000000000002 : 281.844072909736 :  None
#          (2, 2) : 202.20000000000002 :            202.2 :  None
#          (2, 3) : 163.70000000000002 :            163.7 :  None
#          (2, 4) :              183.0 :            183.0 :  None
#          (3, 1) :              209.0 :            209.0 :  None
#          (3, 2) :              195.9 :            195.9 :  None
#          (3, 3) : 158.60000000000002 :            158.6 :  None
#          (3, 4) :              177.3 :            177.3 :  None
#          (4, 1) : 212.60000000000002 :            212.6 :  None
#          (4, 2) :              199.3 :            199.3 :  None
#          (4, 3) :              161.3 :            161.3 :  None
#          (4, 4) :              180.3 :            180.3 :  None
#          (5, 1) :              203.5 :            203.5 :  None
#          (5, 2) :              190.8 :            190.8 :  None
#          (5, 3) :              154.4 :            154.4 :  None
#          (5, 4) : 172.60000000000002 :            172.6 :  None
#          (6, 1) :              210.9 :            210.9 :  None
#          (6, 2) : 197.70000000000002 :            197.7 :  None
#          (6, 3) : 160.10000000000002 :            160.1 :  None
#          (6, 4) :              178.9 :            178.9 :  None
#          (7, 1) :              213.5 :  337.61812714852 :  None
#          (7, 2) : 200.10000000000002 :            200.1 :  None
#          (7, 3) :              162.0 :            162.0 :  None
#          (7, 4) : 181.10000000000002 :            181.1 :  None
#          (8, 1) :              215.4 :            215.4 :  None
#          (8, 2) :              201.9 :            201.9 :  None
#          (8, 3) :              163.5 :            163.5 :  None
#          (8, 4) : 182.70000000000002 :            182.7 :  None
#          (9, 1) :              208.0 :            208.0 :  None
#          (9, 2) :              195.0 :            195.0 :  None
#          (9, 3) :              157.8 :            157.8 :  None
#          (9, 4) :              176.4 :            176.4 :  None
#         (10, 1) :              212.4 :            212.4 :  None
#         (10, 2) : 199.10000000000002 :            199.1 :  None
#         (10, 3) : 161.20000000000002 :            161.2 :  None
#         (10, 4) : 180.10000000000002 :            180.1 :  None
#         (11, 1) :              214.3 :            214.3 :  None
#         (11, 2) :              200.9 :            200.9 :  None
#         (11, 3) : 162.60000000000002 :            162.6 :  None
#         (11, 4) : 181.70000000000002 :            181.7 :  None
#         (12, 1) : 215.70000000000002 :            215.7 :  None
#         (12, 2) : 202.20000000000002 :            202.2 :  None
#         (12, 3) : 163.70000000000002 :            163.7 :  None
#         (12, 4) :              183.0 :            183.0 :  None
#         (13, 1) :              206.9 :            206.9 :  None
#         (13, 2) :              193.9 :            193.9 :  None
#         (13, 3) :              157.0 :            157.0 :  None
#         (13, 4) :              175.5 :            175.5 :  None
#         (14, 1) :              209.8 : 270.512293806977 :  None
#         (14, 2) : 196.70000000000002 :            196.7 :  None
#         (14, 3) : 159.20000000000002 :            159.2 :  None
#         (14, 4) :              177.9 :            177.9 :  None
#         (15, 1) : 205.20000000000002 :            205.2 :  None
#         (15, 2) :              192.4 :            192.4 :  None
#         (15, 3) : 155.70000000000002 :            155.7 :  None
#         (15, 4) :              174.0 :            174.0 :  None
#         (16, 1) : 221.10000000000002 :            221.1 :  None
#         (16, 2) :              207.3 :            207.3 :  None
#         (16, 3) :              167.8 :            167.8 :  None
#         (16, 4) :              187.5 :            187.5 :  None
#         (17, 1) :              214.0 :            214.0 :  None
#         (17, 2) : 200.70000000000002 :            200.7 :  None
#         (17, 3) :              162.4 :            162.4 :  None
#         (17, 4) :              181.5 :            181.5 :  None
#         (18, 1) : 218.70000000000002 :            218.7 :  None
#         (18, 2) : 205.10000000000002 :            205.1 :  None
#         (18, 3) :              166.0 :            166.0 :  None
#         (18, 4) :              185.5 :            185.5 :  None
#         (19, 1) :              210.9 :            210.9 :  None
#         (19, 2) : 197.70000000000002 :            197.7 :  None
#         (19, 3) : 160.10000000000002 :            160.1 :  None
#         (19, 4) :              178.9 :            178.9 :  None
#         (20, 1) :              210.3 :            210.3 :  None
#         (20, 2) : 197.20000000000002 :            197.2 :  None
#         (20, 3) : 159.60000000000002 :            159.6 :  None
#         (20, 4) :              178.4 :            178.4 :  None
#         (21, 1) :              220.0 :            220.0 :  None
#         (21, 2) : 206.20000000000002 :            206.2 :  None
#         (21, 3) :              166.9 :            166.9 :  None
#         (21, 4) : 186.60000000000002 :            186.6 :  None
#         (22, 1) :              212.4 : 276.230736068137 :  None
#         (22, 2) : 199.10000000000002 : 270.585328261034 :  None
#         (22, 3) : 161.20000000000002 :            161.2 :  None
#         (22, 4) : 180.10000000000002 :            180.1 :  None
#         (23, 1) : 209.20000000000002 :            209.2 :  None
#         (23, 2) : 196.10000000000002 :            196.1 :  None
#         (23, 3) :              158.8 :            158.8 :  None
#         (23, 4) :              177.5 :            177.5 :  None
#         (24, 1) : 207.10000000000002 :            207.1 :  None
#         (24, 2) : 194.10000000000002 :            194.1 :  None
#         (24, 3) : 157.20000000000002 :            157.2 :  None
#         (24, 4) : 175.70000000000002 :            175.7 :  None
#         (25, 1) :              207.8 :            207.8 :  None
#         (25, 2) :              194.8 :            194.8 :  None
#         (25, 3) : 157.70000000000002 :            157.7 :  None
#         (25, 4) : 176.20000000000002 :            176.2 :  None
#     min_renewable_constraint : Size=100
#         Key     : Lower             : Body               : Upper
#          (1, 1) :             962.1 :  1276.432141148236 :  None
#          (1, 2) : 901.8000000000001 :  1174.475156561205 :  None
#          (1, 3) :            730.35 :  1308.106064256966 :  None
#          (1, 4) : 816.3000000000001 : 1068.9711971731729 :  None
#          (2, 1) :            970.65 :  1136.951158446274 :  None
#          (2, 2) :             909.9 : 1167.5958771824048 :  None
#          (2, 3) :            736.65 : 1149.0973987292368 :  None
#          (2, 4) :             823.5 :  1242.122645843444 :  None
#          (3, 1) :             940.5 :  995.5611760619761 :  None
#          (3, 2) : 881.5500000000001 :             881.55 :  None
#          (3, 3) :             713.7 :              713.7 :  None
#          (3, 4) :            797.85 :   797.850000000001 :  None
#          (4, 1) :             956.7 :   956.700000000001 :  None
#          (4, 2) :            896.85 :   1047.28284052767 :  None
#          (4, 3) :            725.85 :  725.8500000000006 :  None
#          (4, 4) :            811.35 :             811.35 :  None
#          (5, 1) :            915.75 : 1117.1730522012201 :  None
#          (5, 2) :             858.6 :   912.019151884001 :  None
#          (5, 3) : 694.8000000000001 :  694.8000000000001 :  None
#          (5, 4) :             776.7 :   776.700000000001 :  None
#          (6, 1) : 949.0500000000001 :  1186.718709170243 :  None
#          (6, 2) :            889.65 : 1245.1735111155278 :  None
#          (6, 3) :            720.45 :  1311.533331494137 :  None
#          (6, 4) : 805.0500000000001 :  1179.428293854133 :  None
#          (7, 1) :            960.75 :  1056.359479597153 :  None
#          (7, 2) :            900.45 :  981.4751296558111 :  None
#          (7, 3) :             729.0 :  815.7612376762829 :  None
#          (7, 4) :            814.95 :  902.8720452132569 :  None
#          (8, 1) : 969.3000000000001 :  1174.965964549273 :  None
#          (8, 2) : 908.5500000000001 :  934.7461936008069 :  None
#          (8, 3) :            735.75 :   902.782766995222 :  None
#          (8, 4) :            822.15 :   834.560128083654 :  None
#          (9, 1) :             936.0 :    1147.1181508279 :  None
#          (9, 2) :             877.5 :  1144.388838302996 :  None
#          (9, 3) :             710.1 :  1327.969440667954 :  None
#          (9, 4) : 793.8000000000001 :  1139.724447547761 :  None
#         (10, 1) : 955.8000000000001 : 1104.8102237367489 :  None
#         (10, 2) :            895.95 :  895.9500000000004 :  None
#         (10, 3) :             725.4 :  725.3999999999999 :  None
#         (10, 4) :            810.45 :   810.450000000001 :  None
#         (11, 1) :            964.35 :  1209.948972781946 :  None
#         (11, 2) : 904.0500000000001 :  1114.717214382925 :  None
#         (11, 3) :             731.7 :  1377.106657085312 :  None
#         (11, 4) :            817.65 :  1049.275406118045 :  None
#         (12, 1) :            970.65 :  1300.827315482054 :  None
#         (12, 2) :             909.9 :  1426.772028318018 :  None
#         (12, 3) :            736.65 :  1243.094405620755 :  None
#         (12, 4) :             823.5 :   1287.56457622929 :  None
#         (13, 1) : 931.0500000000001 :  1049.201288326799 :  None
#         (13, 2) : 872.5500000000001 :  872.5500000000001 :  None
#         (13, 3) :             706.5 :  764.3192592025149 :  None
#         (13, 4) :            789.75 :  789.7500000000002 :  None
#         (14, 1) :             944.1 :  987.1334094636459 :  None
#         (14, 2) :            885.15 :  885.1499999999996 :  None
#         (14, 3) :             716.4 :  716.4000000000002 :  None
#         (14, 4) : 800.5500000000001 :  800.5499999999993 :  None
#         (15, 1) :             923.4 :  1429.861601307192 :  None
#         (15, 2) : 865.8000000000001 :  1354.308395931584 :  None
#         (15, 3) :            700.65 :  1401.299999999999 :  None
#         (15, 4) :             783.0 :  1315.819454905748 :  None
#         (16, 1) :            994.95 :  1137.262431119359 :  None
#         (16, 2) :            932.85 :  1061.844045731294 :  None
#         (16, 3) :             755.1 :  755.0999999999999 :  None
#         (16, 4) :            843.75 :  1043.761351981889 :  None
#         (17, 1) :             963.0 :  1045.550947578649 :  None
#         (17, 2) :            903.15 :  1225.155865425126 :  None
#         (17, 3) : 730.8000000000001 : 1291.7872471810251 :  None
#         (17, 4) :            816.75 : 1308.2102590477439 :  None
#         (18, 1) :            984.15 :  991.0272760208729 :  None
#         (18, 2) :            922.95 :  1053.024866620703 :  None
#         (18, 3) :             747.0 :   868.105054556327 :  None
#         (18, 4) :            834.75 :             834.75 :  None
#         (19, 1) : 949.0500000000001 : 1074.5526703545565 :  None
#         (19, 2) :            889.65 :   889.650000000001 :  None
#         (19, 3) :            720.45 :             720.45 :  None
#         (19, 4) : 805.0500000000001 :             805.05 :  None
#         (20, 1) :            946.35 :  1062.756151900573 :  None
#         (20, 2) :             887.4 :  1051.592572949045 :  None
#         (20, 3) :             718.2 : 1018.5782509313881 :  None
#         (20, 4) : 802.8000000000001 : 1012.3376411299889 :  None
#         (21, 1) :             990.0 :  1258.637037757225 :  None
#         (21, 2) :             927.9 :  1172.529697959845 :  None
#         (21, 3) : 751.0500000000001 :  1257.836314809321 :  None
#         (21, 4) :             839.7 :  1411.072407277316 :  None
#         (22, 1) : 955.8000000000001 :  958.9614240136181 :  None
#         (22, 2) :            895.95 :  992.2632012960449 :  None
#         (22, 3) :             725.4 :              725.4 :  None
#         (22, 4) :            810.45 :             810.45 :  None
#         (23, 1) :             941.4 :  1226.343386070368 :  None
#         (23, 2) :            882.45 :  1582.268808987374 :  None
#         (23, 3) :             714.6 :  1371.857801022702 :  None
#         (23, 4) :            798.75 :  1284.119442499949 :  None
#         (24, 1) :            931.95 :  944.0014782569399 :  None
#         (24, 2) :            873.45 :  873.4499999999989 :  None
#         (24, 3) :             707.4 :   707.399999999999 :  None
#         (24, 4) :            790.65 :   795.061733812199 :  None
#         (25, 1) :             935.1 :  1143.068575926726 :  None
#         (25, 2) :             876.6 :   876.600000000001 :  None
#         (25, 3) :            709.65 :             709.65 :  None
#         (25, 4) :             792.9 :  792.9000000000001 :  None

# %% [markdown]
# Lets compute the results in a more visual way in order to understand more deeply what we obtained and how we must produce the different type of energies for each region at a certain time period.
#
# Now we display the results of all the energies that must be produced for its respective region and time period. We decided to round the energy production to 3 decimals in order to have a significant number of decimals but be able to see the whole result in a single row, we also decided to plot the result following the order of the previously declared list of energies. Futhermore, we are going to print the objective value obtained and round it to 5 decimals, from which we can also obtain some insights.

# %%
print("Objective Value:", value(model.obj()))
print("\nDecision Variables:")
for i in model.r:
    for j in model.t:
        print(
            f"Region {i}, Time Period {j}: "
            f"Wind={round(value(model.X['wind', i, j]), 3)}, "
            f"Solar={round(value(model.X['solar', i, j]), 3)}, "
            f"Fossil={round(value(model.X['fossil', i, j]), 3)}, "
            f"Nuclear={round(value(model.X['nuclear', i, j]), 3)}, "
            f"Hydro={round(value(model.X['hydro', i, j]), 3)}, "
            f"Geothermal={round(value(model.X['geothermal', i, j]), 3)}"
        )
# Out:
# Objective Value: 5471213.7318010265
#
# Decision Variables:
# Region 1, Time Period 1: Wind=234.555, Solar=216.126, Fossil=647.768, Nuclear=213.8, Hydro=293.871, Geothermal=531.88
# Region 1, Time Period 2: Wind=234.555, Solar=161.84, Fossil=629.125, Nuclear=200.4, Hydro=385.084, Geothermal=392.996
# Region 1, Time Period 3: Wind=234.555, Solar=283.977, Fossil=152.594, Nuclear=162.3, Hydro=266.158, Geothermal=523.416
# Region 1, Time Period 4: Wind=234.555, Solar=231.07, Fossil=563.629, Nuclear=181.4, Hydro=260.988, Geothermal=342.358
# Region 2, Time Period 1: Wind=202.61, Solar=169.848, Fossil=738.205, Nuclear=281.844, Hydro=296.845, Geothermal=467.648
# Region 2, Time Period 2: Wind=202.61, Solar=208.219, Fossil=652.204, Nuclear=202.2, Hydro=384.981, Geothermal=371.785
# Region 2, Time Period 3: Wind=202.61, Solar=189.811, Fossil=324.203, Nuclear=163.7, Hydro=229.018, Geothermal=527.658
# Region 2, Time Period 4: Wind=202.61, Solar=156.464, Fossil=404.877, Nuclear=183.0, Hydro=336.031, Geothermal=547.017
# Region 3, Time Period 1: Wind=201.477, Solar=159.175, Fossil=885.439, Nuclear=209.0, Hydro=303.306, Geothermal=331.603
# Region 3, Time Period 2: Wind=201.477, Solar=212.696, Fossil=881.55, Nuclear=195.9, Hydro=0.0, Geothermal=467.377
# Region 3, Time Period 3: Wind=201.477, Solar=243.038, Fossil=713.7, Nuclear=158.6, Hydro=0.0, Geothermal=269.185
# Region 3, Time Period 4: Wind=201.477, Solar=203.524, Fossil=797.85, Nuclear=177.3, Hydro=0.0, Geothermal=392.849
# Region 4, Time Period 1: Wind=229.168, Solar=170.408, Fossil=956.7, Nuclear=212.6, Hydro=322.48, Geothermal=234.643
# Region 4, Time Period 2: Wind=229.168, Solar=226.556, Fossil=746.417, Nuclear=199.3, Hydro=330.411, Geothermal=261.148
# Region 4, Time Period 3: Wind=229.168, Solar=274.624, Fossil=725.85, Nuclear=161.3, Hydro=211.521, Geothermal=10.538
# Region 4, Time Period 4: Wind=229.168, Solar=133.578, Fossil=811.35, Nuclear=180.3, Hydro=277.164, Geothermal=171.44
# Region 5, Time Period 1: Wind=304.028, Solar=297.496, Fossil=714.327, Nuclear=203.5, Hydro=346.646, Geothermal=169.003
# Region 5, Time Period 2: Wind=304.028, Solar=169.883, Fossil=805.181, Nuclear=190.8, Hydro=227.17, Geothermal=210.938
# Region 5, Time Period 3: Wind=304.028, Solar=265.241, Fossil=694.8, Nuclear=154.4, Hydro=125.531, Geothermal=0.0
# Region 5, Time Period 4: Wind=304.028, Solar=113.092, Fossil=776.7, Nuclear=172.6, Hydro=204.631, Geothermal=154.948
# Region 6, Time Period 1: Wind=375.038, Solar=101.071, Fossil=711.381, Nuclear=210.9, Hydro=203.491, Geothermal=507.119
# Region 6, Time Period 2: Wind=369.34, Solar=277.389, Fossil=534.126, Nuclear=197.7, Hydro=294.552, Geothermal=303.892
# Region 6, Time Period 3: Wind=351.176, Solar=282.264, Fossil=129.367, Nuclear=160.1, Hydro=368.821, Geothermal=309.273
# Region 6, Time Period 4: Wind=346.427, Solar=139.882, Fossil=430.672, Nuclear=178.9, Hydro=377.42, Geothermal=315.7
# Region 7, Time Period 1: Wind=356.843, Solar=105.51, Fossil=741.022, Nuclear=337.618, Hydro=260.126, Geothermal=333.88
# Region 7, Time Period 2: Wind=330.255, Solar=263.467, Fossil=819.425, Nuclear=200.1, Hydro=387.753, Geothermal=0.0
# Region 7, Time Period 3: Wind=349.731, Solar=148.366, Fossil=642.239, Nuclear=162.0, Hydro=317.665, Geothermal=0.0
# Region 7, Time Period 4: Wind=366.321, Solar=111.217, Fossil=727.028, Nuclear=181.1, Hydro=219.743, Geothermal=205.591
# Region 8, Time Period 1: Wind=391.67, Solar=113.512, Fossil=763.634, Nuclear=215.4, Hydro=219.269, Geothermal=450.515
# Region 8, Time Period 2: Wind=310.893, Solar=194.774, Fossil=882.354, Nuclear=201.9, Hydro=313.122, Geothermal=115.957
# Region 8, Time Period 3: Wind=349.549, Solar=201.886, Fossil=568.717, Nuclear=163.5, Hydro=351.348, Geothermal=0.0
# Region 8, Time Period 4: Wind=323.284, Solar=183.359, Fossil=809.74, Nuclear=182.7, Hydro=227.822, Geothermal=100.096
# Region 9, Time Period 1: Wind=215.029, Solar=151.169, Fossil=724.882, Nuclear=208.0, Hydro=274.495, Geothermal=506.426
# Region 9, Time Period 2: Wind=215.029, Solar=176.302, Fossil=610.611, Nuclear=195.0, Hydro=397.686, Geothermal=355.371
# Region 9, Time Period 3: Wind=215.029, Solar=261.477, Fossil=92.231, Nuclear=157.8, Hydro=380.562, Geothermal=470.902
# Region 9, Time Period 4: Wind=215.029, Solar=262.208, Fossil=447.876, Nuclear=176.4, Hydro=270.195, Geothermal=392.293
# Region 10, Time Period 1: Wind=272.942, Solar=237.237, Fossil=806.79, Nuclear=212.4, Hydro=297.686, Geothermal=296.945
# Region 10, Time Period 2: Wind=272.942, Solar=298.523, Fossil=895.95, Nuclear=199.1, Hydro=321.195, Geothermal=3.291
# Region 10, Time Period 3: Wind=272.942, Solar=181.037, Fossil=725.4, Nuclear=161.2, Hydro=201.427, Geothermal=69.994
# Region 10, Time Period 4: Wind=272.942, Solar=138.035, Fossil=810.45, Nuclear=180.1, Hydro=212.535, Geothermal=186.938
# Region 11, Time Period 1: Wind=273.384, Solar=197.635, Fossil=718.751, Nuclear=214.3, Hydro=331.345, Geothermal=407.585
# Region 11, Time Period 2: Wind=273.384, Solar=200.474, Fossil=693.383, Nuclear=200.9, Hydro=231.824, Geothermal=409.035
# Region 11, Time Period 3: Wind=273.384, Solar=180.671, Fossil=86.293, Nuclear=162.6, Hydro=382.012, Geothermal=541.039
# Region 11, Time Period 4: Wind=273.384, Solar=136.219, Fossil=586.025, Nuclear=181.7, Hydro=279.02, Geothermal=360.652
# Region 12, Time Period 1: Wind=318.531, Solar=109.606, Fossil=640.473, Nuclear=215.7, Hydro=293.881, Geothermal=578.809
# Region 12, Time Period 2: Wind=318.531, Solar=220.938, Fossil=393.028, Nuclear=202.2, Hydro=321.933, Geothermal=565.37
# Region 12, Time Period 3: Wind=318.531, Solar=153.182, Fossil=230.206, Nuclear=163.7, Hydro=364.263, Geothermal=407.118
# Region 12, Time Period 4: Wind=318.531, Solar=276.269, Fossil=359.435, Nuclear=183.0, Hydro=296.225, Geothermal=396.539
# Region 13, Time Period 1: Wind=317.537, Solar=216.809, Fossil=812.899, Nuclear=206.9, Hydro=249.377, Geothermal=265.477
# Region 13, Time Period 2: Wind=331.497, Solar=195.492, Fossil=872.55, Nuclear=193.9, Hydro=280.469, Geothermal=65.092
# Region 13, Time Period 3: Wind=389.111, Solar=134.303, Fossil=648.681, Nuclear=157.0, Hydro=240.905, Geothermal=0.0
# Region 13, Time Period 4: Wind=318.034, Solar=111.324, Fossil=789.75, Nuclear=175.5, Hydro=354.127, Geothermal=6.265
# Region 14, Time Period 1: Wind=249.812, Solar=131.407, Fossil=840.354, Nuclear=270.512, Hydro=223.791, Geothermal=382.124
# Region 14, Time Period 2: Wind=249.812, Solar=167.724, Fossil=885.15, Nuclear=196.7, Hydro=396.895, Geothermal=70.72
# Region 14, Time Period 3: Wind=249.812, Solar=188.129, Fossil=716.4, Nuclear=159.2, Hydro=251.313, Geothermal=27.147
# Region 14, Time Period 4: Wind=249.812, Solar=236.769, Fossil=800.55, Nuclear=177.9, Hydro=279.209, Geothermal=34.761
# Region 15, Time Period 1: Wind=391.906, Solar=141.174, Fossil=416.938, Nuclear=205.2, Hydro=328.091, Geothermal=568.691
# Region 15, Time Period 2: Wind=399.429, Solar=223.287, Fossil=377.292, Nuclear=192.4, Hydro=320.991, Geothermal=410.602
# Region 15, Time Period 3: Wind=347.705, Solar=284.894, Fossil=0.0, Nuclear=155.7, Hydro=207.271, Geothermal=561.43
# Region 15, Time Period 4: Wind=330.988, Solar=115.926, Fossil=250.181, Nuclear=174.0, Hydro=391.68, Geothermal=477.225
# Region 16, Time Period 1: Wind=281.239, Solar=197.079, Fossil=852.638, Nuclear=221.1, Hydro=127.925, Geothermal=531.019
# Region 16, Time Period 2: Wind=281.239, Solar=239.713, Fossil=803.856, Nuclear=207.3, Hydro=140.321, Geothermal=400.571
# Region 16, Time Period 3: Wind=281.239, Solar=116.314, Fossil=755.1, Nuclear=167.8, Hydro=17.288, Geothermal=340.26
# Region 16, Time Period 4: Wind=281.239, Solar=273.82, Fossil=643.739, Nuclear=187.5, Hydro=0.0, Geothermal=488.702
# Region 17, Time Period 1: Wind=273.314, Solar=186.621, Fossil=880.449, Nuclear=214.0, Hydro=220.09, Geothermal=365.526
# Region 17, Time Period 2: Wind=273.314, Solar=198.866, Fossil=581.144, Nuclear=200.7, Hydro=210.937, Geothermal=542.038
# Region 17, Time Period 3: Wind=273.314, Solar=199.148, Fossil=169.813, Nuclear=162.4, Hydro=383.018, Geothermal=436.307
# Region 17, Time Period 4: Wind=273.314, Solar=174.144, Fossil=325.29, Nuclear=181.5, Hydro=307.17, Geothermal=553.581
# Region 18, Time Period 1: Wind=245.618, Solar=284.426, Fossil=977.273, Nuclear=218.7, Hydro=241.08, Geothermal=219.903
# Region 18, Time Period 2: Wind=245.618, Solar=268.256, Fossil=792.875, Nuclear=205.1, Hydro=313.38, Geothermal=225.771
# Region 18, Time Period 3: Wind=245.618, Solar=231.105, Fossil=625.895, Nuclear=166.0, Hydro=391.382, Geothermal=0.0
# Region 18, Time Period 4: Wind=245.618, Solar=192.537, Fossil=834.75, Nuclear=185.5, Hydro=249.656, Geothermal=146.939
# Region 19, Time Period 1: Wind=338.017, Solar=213.002, Fossil=823.547, Nuclear=210.9, Hydro=3.688, Geothermal=519.845
# Region 19, Time Period 2: Wind=353.013, Solar=184.783, Fossil=889.65, Nuclear=197.7, Hydro=0.0, Geothermal=351.854
# Region 19, Time Period 3: Wind=353.013, Solar=157.642, Fossil=720.45, Nuclear=160.1, Hydro=0.0, Geothermal=209.795
# Region 19, Time Period 4: Wind=300.413, Solar=152.796, Fossil=805.05, Nuclear=178.9, Hydro=0.0, Geothermal=351.84
# Region 20, Time Period 1: Wind=305.944, Solar=238.148, Fossil=829.944, Nuclear=210.3, Hydro=0.0, Geothermal=518.665
# Region 20, Time Period 2: Wind=305.765, Solar=266.567, Fossil=723.207, Nuclear=197.2, Hydro=0.0, Geothermal=479.26
# Region 20, Time Period 3: Wind=304.303, Solar=218.478, Fossil=417.822, Nuclear=159.6, Hydro=0.0, Geothermal=495.797
# Region 20, Time Period 4: Wind=305.944, Solar=193.305, Fossil=593.262, Nuclear=178.4, Hydro=0.0, Geothermal=513.089
# Region 21, Time Period 1: Wind=271.431, Solar=234.732, Fossil=721.363, Nuclear=220.0, Hydro=256.436, Geothermal=496.038
# Region 21, Time Period 2: Wind=271.431, Solar=178.296, Fossil=683.27, Nuclear=206.2, Hydro=277.81, Geothermal=444.993
# Region 21, Time Period 3: Wind=271.431, Solar=240.421, Fossil=244.264, Nuclear=166.9, Hydro=313.872, Geothermal=432.113
# Region 21, Time Period 4: Wind=271.431, Solar=293.14, Fossil=268.328, Nuclear=186.6, Hydro=312.869, Geothermal=533.633
# Region 22, Time Period 1: Wind=302.942, Solar=118.102, Fossil=888.808, Nuclear=276.231, Hydro=236.957, Geothermal=300.96
# Region 22, Time Period 2: Wind=326.81, Solar=111.625, Fossil=728.151, Nuclear=270.585, Hydro=221.207, Geothermal=332.621
# Region 22, Time Period 3: Wind=324.025, Solar=217.603, Fossil=725.4, Nuclear=161.2, Hydro=183.772, Geothermal=0.0
# Region 22, Time Period 4: Wind=326.81, Solar=250.235, Fossil=810.45, Nuclear=180.1, Hydro=233.405, Geothermal=0.0
# Region 23, Time Period 1: Wind=323.757, Solar=202.263, Fossil=656.457, Nuclear=209.2, Hydro=362.777, Geothermal=337.546
# Region 23, Time Period 2: Wind=319.317, Solar=284.1, Fossil=182.631, Nuclear=196.1, Hydro=397.215, Geothermal=581.637
# Region 23, Time Period 3: Wind=323.757, Solar=160.793, Fossil=57.342, Nuclear=158.8, Hydro=354.956, Geothermal=532.352
# Region 23, Time Period 4: Wind=323.757, Solar=198.601, Fossil=313.381, Nuclear=177.5, Hydro=356.253, Geothermal=405.509
# Region 24, Time Period 1: Wind=355.949, Solar=295.872, Fossil=919.899, Nuclear=207.1, Hydro=292.181, Geothermal=0.0
# Region 24, Time Period 2: Wind=367.793, Solar=164.702, Fossil=873.45, Nuclear=194.1, Hydro=340.956, Geothermal=0.0
# Region 24, Time Period 3: Wind=380.913, Solar=137.913, Fossil=707.4, Nuclear=157.2, Hydro=188.574, Geothermal=0.0
# Region 24, Time Period 4: Wind=386.857, Solar=161.046, Fossil=786.238, Nuclear=175.7, Hydro=247.159, Geothermal=0.0
# Region 25, Time Period 1: Wind=341.799, Solar=168.822, Fossil=727.131, Nuclear=207.8, Hydro=396.113, Geothermal=236.334
# Region 25, Time Period 2: Wind=305.894, Solar=235.906, Fossil=876.6, Nuclear=194.8, Hydro=334.8, Geothermal=0.0
# Region 25, Time Period 3: Wind=347.846, Solar=110.763, Fossil=709.65, Nuclear=157.7, Hydro=251.041, Geothermal=0.0
# Region 25, Time Period 4: Wind=352.116, Solar=261.321, Fossil=792.9, Nuclear=176.2, Hydro=179.463, Geothermal=0.0

# %% [markdown]
# After displaying the model and printing the results in a more eye-catching way, we can obtain some conclusions, however it is true that having this huge amount of decision variables makes difficult to obtain clear conclusions, for this reason, we are going to plot some graphs in order to have a visual representation of the model and comment those graphs to finally interpret the results obtained and give the most important insights.

# %% [markdown]
# ## 2.9) Visual representation
#
# We considered a good way to understand our results and see the impact of the different decision variables or constraints could be by giving a visual representation of it, so we decided to create different graphs that could give us more hints about the model and its results

# %% [markdown]
# If we want to see the average energy for all the regions at each period of time in a visual way, we could create a graph which computes the mean energy production and plot it, where the x - axis is the time period and the y-axis the total energy production. In each bar we separated the different energies in order to see the importance of each energy for all the regions.

# %%
bar_width = 0.75
index = np.arange(len(time_periods))

# Initialize an array to store energy production for each energy source and time period
energy_by_source = np.zeros((len(model.e), len(time_periods)))

# Count the number of regions for normalization
num_regions = len(regions)

# Calculate energy production for each energy source and time period
for i, e in enumerate(model.e):
    for t in time_periods:
        for r in regions:
            energy_by_source[i, t - 1] += model.X[e, r, t]()

# Calculate average energy production for each energy source and time period
average_energy_by_source = energy_by_source / num_regions

# Define a custom color palette
colors = ['skyblue', 'gold', 'lightcoral', 'lightgreen', 'lightseagreen', 'thistle']

# Plot the stacked bar graph with the custom color palette
plt.figure(figsize=(10, 6))
bottom = np.zeros(len(time_periods))

for i, e in enumerate(model.e):
    plt.bar(index, average_energy_by_source[i, :], width=bar_width, label=e, bottom=bottom, color=colors[i])
    bottom += average_energy_by_source[i, :]

plt.xlabel("Time Period")
plt.ylabel("Average Energy Production")
plt.title("Average Energy Production by Source Across Time Periods")
plt.xticks(index, ['1 (Winter)', '2 (Spring)', '3 (Summer)', '4 (Autumn)'])
plt.legend()
plt.show()

# %% [markdown]
# As we can see in the bar graph, it explains in the y-axis the average energy production in all the regions depending on the time period. As we can see there is any significant different between time periods but we can clearly see from the graph, that the renewable energies tend to be the most optimal to be produced, specially the solar. For this reason, the other energies such as nuclear or fossil, the model decided that was most optimal to produce less quantity.
#
# From this graph we can conclude that the model took into consideration the enviromental impact constraint where it tries to do not surpass the environmetal limit meanwhile taking into account other aspects such as the cost or the availability in order to obtain an efficient sytem. It is also important to mention that there is a clear impact depending on the time period, where the average production of energy must be higher or lower depending on the season, where in winter the demand is the highest meanwhile in summer is the lowest.

# %% [markdown]
# We could also study another graphical ways to plot the information obtained after displaying the results of the model, for instance, a heat map could be a great idea in order to see the impact of each energy for each one of the 25 regions, in this way, we obtain in a simple way all the outputs (100) obtained from the model.

# %%
# Create a DataFrame for energy production values with regions and energy sources
energy_production_all_df = pd.DataFrame({
    'Wind': [model.X['wind', r, t]() for r in regions for t in time_periods],
    'Solar': [model.X['solar', r, t]() for r in regions for t in time_periods],
    'Fossil': [model.X['fossil', r, t]() for r in regions for t in time_periods],
    'Nuclear': [model.X['nuclear', r, t]() for r in regions for t in time_periods],
    'Hydro': [model.X['hydro', r, t]() for r in regions for t in time_periods],
    'Geothermal': [model.X['geothermal', r, t]() for r in regions for t in time_periods],
    'Region': np.repeat(regions, len(time_periods)),
    'Time Period': np.tile(time_periods, len(regions))
})

# Pivot the DataFrame for heatmap
heatmap_data_selected = energy_production_all_df.pivot_table(index='Region', columns='Time Period', values=['Wind', 'Solar', 'Fossil', 'Nuclear', 'Hydro', 'Geothermal'])

# Create a heat map using Seaborn
plt.figure(figsize=(16, 8))
heat_map_selected = sns.heatmap(data=heatmap_data_selected.T, cmap='YlGnBu', annot=False, fmt=".2f", linewidths=.5)
plt.title("Energy Production for Selected Energies Across Regions and Time Periods (Heat Map)")
plt.xlabel('Region')
plt.ylabel('Time Period')
plt.show()

# %% [markdown]
# We can see in the heat map graph that depending on the intensity of the color, that region produces on total more or less energy, so by examining the heat map we can clearly understand which energies are more predominant in each region and at each time period, this is explained in the right of the graph where it shows the amount of energy produced depending on the color.
#
# In this heap map we can extract some interesting conclusions, for instance, we could start by looking at the nuclear energy, which is almost the same for every region, probably the reason is because is not an optimal energy to produce, but due to the constraint that the production of nuclear energy must be at least 10% of the total demand, the nuclear energy produced it is basically the 10% (which is the minimum required).
# We can also see that the most used energy is the fossil fuel, probably because due to its availability eventhough it has a big environmental impact, but as long as the environmental treshold is not surpass, the most optimal way to produce energy is to use the fossil.
#
# There are other energies such as the solar that they are not producing more of that type of energy due to the limited availability, because in terms of cost and environmental impact, it is a pretty good energy. Once again, if we look at the time period, the production of energy varies (increasing or decreasing)
#
# Overall, the heatmap provides an insightful and intuitive way to understand the distribution of energy production across regions and time periods for the different energy sources considered in your model.

# %%
# Create a grouped bar plot
plt.figure(figsize=(14, 8))

bar_width = 0.12
bar_positions = np.arange(len(regions))

for i, energy_source in enumerate(['Wind', 'Solar', 'Fossil', 'Nuclear', 'Hydro', 'Geothermal']):
    plt.bar(bar_positions + i * bar_width, energy_production_all_df.groupby('Region')[energy_source].mean(),
            width=bar_width, label=energy_source)

plt.xlabel("Region")
plt.ylabel("Average Energy Production")
plt.title("Average Energy Production by Region and Source Across All Time Periods")
plt.xticks(bar_positions + 2 * bar_width, regions)
plt.legend()
plt.show()

# %% [markdown]
# From this bar graph we obtain similar conclusions to the previous graphs, however we can appreciate that it explains the average energy production for all the energies at each region, in this way we can see how any energy varies depending on the necessities such as demand, the availability of each type of energy, cost or environmetal impact in any specific region, we can see that the demand between regions varies but does not have any significant differences.
#
# The main differences relies more on the energies that are produced (the cost of it, environmetal impact, availability, etc...), it is for this reason that depending on the region some of them have a huge production of fossil fuels such as region 14 meanwhile other regions have more balanced energy production systems like region 6, are different approaches in order to fulfill certain constraints and minizmizing the cost to produce energy, it is quite interesting to notice that in our data set are several possibilities that makes this type of results possible, where in some regions prefers to use mainly 2-3 energies but taking into consideration the constraints established meanwhile others due to the model considers a better idea to produce energy from different origins.
#
# Another important insight is to notice that for almost all the regions, the two most favourite energies where at first, fossil fuel and second the geothermal, this makes sense due to the high availability of fossil energy and the low environmetal impact of the geothermal. Meanwhile, the nuclear energy we can see that in the most of the regions the production of this type of energy is the same because regions just want to satisfy the constraint of producing at least 10% of the total demand with nuclear power.

# %% [markdown]
# ## 2.10) Interpret the results
#
# Some of the most striking points could be that for the column for the energy wind, we can see that almost for any time period is always the same, this is a indicative that the wind energy is pretty good for the model due to its cost and environmental impact and it is for these reasons that the model always tries to use it as a first option until it reaches the availability for that power at that certain region and time period.
#
# Futhermore, we can see that for the nuclear energy, always have a similar result eventhough its availability is quite higher, probably the model is just using the least amount of nuclear energy as possible to ensure the constraint related to the minimum nuclear power produced.
#
# Another interesting point is related to the fossil energy, which we can see it tends to be the most produced energy, probably due to its high availability that ensures the demand is satisfied.
#
# Another energies that we can extract some conclusions could be the solar energy, which due to its low availability, cannot be used too much or the geothermal energy, which is interesting that the production of this energy is high but sometimes in specific regions and time periods, the production falls to cero, probably because the cost of this energy is quite variable, for some regions are cheap and for other quite high so it is not worth it to use it.
#
# Talking about the objective value obtained, which was *5548058.136663086*, we cannot get any useful interpretation because it is necessary to compare with other models or apply benchmarks in order to know to what extend the model was able to minimize the objective function while fulfilling the constraints.
#
# Thanks to the graphs plotted we saw that our first insights were true, for instance, the first option of the model was to use the cheapest energies such as wind or solar, and as the last option, the ones with the highest cost such as fossil fuels but those energies ensure the demand constraint.
#
# From this insights we can see that the model tried to minimize the cost produced but due to the established constraints, had to use solutions that differs from what would be the most optimal model to minimize the objective function. We can clearly see that the model tried to use as the first option the most cheaper energies which those energies at the same time were the ones with the lowest environmetal impact but due to some limitations which mainly was the availability factor, the model had to chose other not-so-optimal energies that could worse the result.

# %% [markdown]
# # 3) Sensitivities associated with each constraint
#
# Sensitivity refers to the ability to assess how the optimal solution of a model changes with variations in the model parameters, such as cost coefficients, environmetal limits, or availability. In other words, it involves understanding how robust the optimal solution is in response to changes data used in the problem. Sensitivity can be analyzed through sensitivity analysis by using duals, which involves evaluating how the optimal solution or the values of decision variables change when model parameters are modified.
#
# ## 3.1) Computing the sensitivity
#
# The sensitivities associated with each constraint, provide insights into how the optimal objective function value would be affected depending on the change of parameters and constraints.
#
# Positive dual values indicate that an increase in a constraint related to a parameter (for instance: demand or availability) will lead to an increase in the objective function, and then in the objective value. Negative dual values suggest that an increase in the parameter will lead to a decrease in the objective value.
#
# By using duals we can compute the sensitivity associated to each constraint:

# %%
# Creating a dual
model.dual= Suffix(direction=Suffix.IMPORT)

solver.solve(model)

model.dual.display()
# Out:
# dual : Direction=Suffix.IMPORT, Datatype=Suffix.FLOAT
#     Key                                      : Value
#          availability_constraint[fossil,1,1] :               0.0
#          availability_constraint[fossil,1,2] :               0.0
#          availability_constraint[fossil,1,3] :               0.0
#          availability_constraint[fossil,1,4] :               0.0
#         availability_constraint[fossil,10,1] :              -2.0
#         availability_constraint[fossil,10,2] :               0.0
#         availability_constraint[fossil,10,3] :               0.0
#         availability_constraint[fossil,10,4] :               0.0
#         availability_constraint[fossil,11,1] :               0.0
#         availability_constraint[fossil,11,2] :               0.0
#         availability_constraint[fossil,11,3] :               0.0
#         availability_constraint[fossil,11,4] :               0.0
#         availability_constraint[fossil,12,1] :               0.0
#         availability_constraint[fossil,12,2] :               0.0
#         availability_constraint[fossil,12,3] :               0.0
#         availability_constraint[fossil,12,4] :               0.0
#         availability_constraint[fossil,13,1] :              -3.0
#         availability_constraint[fossil,13,2] :               0.0
#         availability_constraint[fossil,13,3] :               0.0
#         availability_constraint[fossil,13,4] :               0.0
#         availability_constraint[fossil,14,1] :              -2.0
#         availability_constraint[fossil,14,2] :               0.0
#         availability_constraint[fossil,14,3] :               0.0
#         availability_constraint[fossil,14,4] :               0.0
#         availability_constraint[fossil,15,1] :               0.0
#         availability_constraint[fossil,15,2] :               0.0
#         availability_constraint[fossil,15,3] :               0.0
#         availability_constraint[fossil,15,4] :               0.0
#         availability_constraint[fossil,16,1] :              -4.0
#         availability_constraint[fossil,16,2] :              -4.0
#         availability_constraint[fossil,16,3] :               0.0
#         availability_constraint[fossil,16,4] :               0.0
#         availability_constraint[fossil,17,1] :               0.0
#         availability_constraint[fossil,17,2] :               0.0
#         availability_constraint[fossil,17,3] :               0.0
#         availability_constraint[fossil,17,4] :               0.0
#         availability_constraint[fossil,18,1] :              -2.0
#         availability_constraint[fossil,18,2] :              -2.0
#         availability_constraint[fossil,18,3] :               0.0
#         availability_constraint[fossil,18,4] :               0.0
#         availability_constraint[fossil,19,1] :              -7.0
#         availability_constraint[fossil,19,2] :               0.0
#         availability_constraint[fossil,19,3] :               0.0
#         availability_constraint[fossil,19,4] :               0.0
#          availability_constraint[fossil,2,1] :              -5.0
#          availability_constraint[fossil,2,2] :               0.0
#          availability_constraint[fossil,2,3] :               0.0
#          availability_constraint[fossil,2,4] :               0.0
#         availability_constraint[fossil,20,1] :               0.0
#         availability_constraint[fossil,20,2] :               0.0
#         availability_constraint[fossil,20,3] :               0.0
#         availability_constraint[fossil,20,4] :               0.0
#         availability_constraint[fossil,21,1] :               0.0
#         availability_constraint[fossil,21,2] :               0.0
#         availability_constraint[fossil,21,3] :               0.0
#         availability_constraint[fossil,21,4] :               0.0
#         availability_constraint[fossil,22,1] :             -29.0
#         availability_constraint[fossil,22,2] :             -29.0
#         availability_constraint[fossil,22,3] :               0.0
#         availability_constraint[fossil,22,4] :               0.0
#         availability_constraint[fossil,23,1] :               0.0
#         availability_constraint[fossil,23,2] :               0.0
#         availability_constraint[fossil,23,3] :               0.0
#         availability_constraint[fossil,23,4] :               0.0
#         availability_constraint[fossil,24,1] :               0.0
#         availability_constraint[fossil,24,2] :               0.0
#         availability_constraint[fossil,24,3] :               0.0
#         availability_constraint[fossil,24,4] :               0.0
#         availability_constraint[fossil,25,1] :              -7.0
#         availability_constraint[fossil,25,2] :               0.0
#         availability_constraint[fossil,25,3] :               0.0
#         availability_constraint[fossil,25,4] :               0.0
#          availability_constraint[fossil,3,1] :              -6.0
#          availability_constraint[fossil,3,2] :               0.0
#          availability_constraint[fossil,3,3] :               0.0
#          availability_constraint[fossil,3,4] :               0.0
#          availability_constraint[fossil,4,1] :               0.0
#          availability_constraint[fossil,4,2] :             -10.0
#          availability_constraint[fossil,4,3] :               0.0
#          availability_constraint[fossil,4,4] :               0.0
#          availability_constraint[fossil,5,1] :              -5.0
#          availability_constraint[fossil,5,2] :              -5.0
#          availability_constraint[fossil,5,3] :               0.0
#          availability_constraint[fossil,5,4] :               0.0
#          availability_constraint[fossil,6,1] :               0.0
#          availability_constraint[fossil,6,2] :               0.0
#          availability_constraint[fossil,6,3] :               0.0
#          availability_constraint[fossil,6,4] :               0.0
#          availability_constraint[fossil,7,1] :              -5.0
#          availability_constraint[fossil,7,2] :               0.0
#          availability_constraint[fossil,7,3] :               0.0
#          availability_constraint[fossil,7,4] :              -2.0
#          availability_constraint[fossil,8,1] :               0.0
#          availability_constraint[fossil,8,2] :               0.0
#          availability_constraint[fossil,8,3] :               0.0
#          availability_constraint[fossil,8,4] :               0.0
#          availability_constraint[fossil,9,1] :               0.0
#          availability_constraint[fossil,9,2] :               0.0
#          availability_constraint[fossil,9,3] :               0.0
#          availability_constraint[fossil,9,4] :               0.0
#      availability_constraint[geothermal,1,1] :              -9.0
#      availability_constraint[geothermal,1,2] :              -9.0
#      availability_constraint[geothermal,1,3] :              -9.0
#      availability_constraint[geothermal,1,4] :              -9.0
#     availability_constraint[geothermal,10,1] :               0.0
#     availability_constraint[geothermal,10,2] :               0.0
#     availability_constraint[geothermal,10,3] :               0.0
#     availability_constraint[geothermal,10,4] :               0.0
#     availability_constraint[geothermal,11,1] :             -12.0
#     availability_constraint[geothermal,11,2] :             -12.0
#     availability_constraint[geothermal,11,3] :             -12.0
#     availability_constraint[geothermal,11,4] :             -12.0
#     availability_constraint[geothermal,12,1] :              -4.0
#     availability_constraint[geothermal,12,2] :              -4.0
#     availability_constraint[geothermal,12,3] :              -4.0
#     availability_constraint[geothermal,12,4] :              -4.0
#     availability_constraint[geothermal,13,1] :               0.0
#     availability_constraint[geothermal,13,2] :               0.0
#     availability_constraint[geothermal,13,3] :               0.0
#     availability_constraint[geothermal,13,4] :               0.0
#     availability_constraint[geothermal,14,1] :              -2.0
#     availability_constraint[geothermal,14,2] :               0.0
#     availability_constraint[geothermal,14,3] :               0.0
#     availability_constraint[geothermal,14,4] :               0.0
#     availability_constraint[geothermal,15,1] :             -11.0
#     availability_constraint[geothermal,15,2] :             -11.0
#     availability_constraint[geothermal,15,3] :              -4.0
#     availability_constraint[geothermal,15,4] :             -11.0
#     availability_constraint[geothermal,16,1] :              -9.0
#     availability_constraint[geothermal,16,2] :              -9.0
#     availability_constraint[geothermal,16,3] :              -9.0
#     availability_constraint[geothermal,16,4] :              -5.0
#     availability_constraint[geothermal,17,1] :              -2.0
#     availability_constraint[geothermal,17,2] :              -2.0
#     availability_constraint[geothermal,17,3] :              -2.0
#     availability_constraint[geothermal,17,4] :              -2.0
#     availability_constraint[geothermal,18,1] :               0.0
#     availability_constraint[geothermal,18,2] :               0.0
#     availability_constraint[geothermal,18,3] :               0.0
#     availability_constraint[geothermal,18,4] :               0.0
#     availability_constraint[geothermal,19,1] :              -6.0
#     availability_constraint[geothermal,19,2] :               0.0
#     availability_constraint[geothermal,19,3] :               0.0
#     availability_constraint[geothermal,19,4] :               0.0
#      availability_constraint[geothermal,2,1] :             -11.0
#      availability_constraint[geothermal,2,2] :              -6.0
#      availability_constraint[geothermal,2,3] :              -6.0
#      availability_constraint[geothermal,2,4] :              -6.0
#     availability_constraint[geothermal,20,1] :              -6.0
#     availability_constraint[geothermal,20,2] :              -6.0
#     availability_constraint[geothermal,20,3] :              -6.0
#     availability_constraint[geothermal,20,4] :              -6.0
#     availability_constraint[geothermal,21,1] :             -11.0
#     availability_constraint[geothermal,21,2] :             -11.0
#     availability_constraint[geothermal,21,3] :             -11.0
#     availability_constraint[geothermal,21,4] :             -11.0
#     availability_constraint[geothermal,22,1] :             -20.0
#     availability_constraint[geothermal,22,2] :             -20.0
#     availability_constraint[geothermal,22,3] :               0.0
#     availability_constraint[geothermal,22,4] :               0.0
#     availability_constraint[geothermal,23,1] :              -1.0
#     availability_constraint[geothermal,23,2] :              -1.0
#     availability_constraint[geothermal,23,3] :              -1.0
#     availability_constraint[geothermal,23,4] :              -1.0
#     availability_constraint[geothermal,24,1] :               0.0
#     availability_constraint[geothermal,24,2] :               0.0
#     availability_constraint[geothermal,24,3] :               0.0
#     availability_constraint[geothermal,24,4] :               0.0
#     availability_constraint[geothermal,25,1] :               0.0
#     availability_constraint[geothermal,25,2] :               0.0
#     availability_constraint[geothermal,25,3] :               0.0
#     availability_constraint[geothermal,25,4] :               0.0
#      availability_constraint[geothermal,3,1] :              -4.0
#      availability_constraint[geothermal,3,2] :               0.0
#      availability_constraint[geothermal,3,3] :               0.0
#      availability_constraint[geothermal,3,4] :               0.0
#      availability_constraint[geothermal,4,1] :               0.0
#      availability_constraint[geothermal,4,2] :               0.0
#      availability_constraint[geothermal,4,3] :               0.0
#      availability_constraint[geothermal,4,4] :               0.0
#      availability_constraint[geothermal,5,1] :               0.0
#      availability_constraint[geothermal,5,2] :               0.0
#      availability_constraint[geothermal,5,3] :               0.0
#      availability_constraint[geothermal,5,4] :               0.0
#      availability_constraint[geothermal,6,1] :             -12.0
#      availability_constraint[geothermal,6,2] :             -12.0
#      availability_constraint[geothermal,6,3] :             -12.0
#      availability_constraint[geothermal,6,4] :             -12.0
#      availability_constraint[geothermal,7,1] :              -3.0
#      availability_constraint[geothermal,7,2] :               0.0
#      availability_constraint[geothermal,7,3] :               0.0
#      availability_constraint[geothermal,7,4] :               0.0
#      availability_constraint[geothermal,8,1] :               0.0
#      availability_constraint[geothermal,8,2] :               0.0
#      availability_constraint[geothermal,8,3] :               0.0
#      availability_constraint[geothermal,8,4] :               0.0
#      availability_constraint[geothermal,9,1] :              -5.0
#      availability_constraint[geothermal,9,2] :              -5.0
#      availability_constraint[geothermal,9,3] :              -5.0
#      availability_constraint[geothermal,9,4] :              -5.0
#           availability_constraint[hydro,1,1] :             -10.0
#           availability_constraint[hydro,1,2] :             -10.0
#           availability_constraint[hydro,1,3] :             -10.0
#           availability_constraint[hydro,1,4] :             -10.0
#          availability_constraint[hydro,10,1] :              -6.0
#          availability_constraint[hydro,10,2] :              -6.0
#          availability_constraint[hydro,10,3] :              -6.0
#          availability_constraint[hydro,10,4] :              -6.0
#          availability_constraint[hydro,11,1] :             -11.0
#          availability_constraint[hydro,11,2] :             -11.0
#          availability_constraint[hydro,11,3] :             -11.0
#          availability_constraint[hydro,11,4] :             -11.0
#          availability_constraint[hydro,12,1] :              -6.0
#          availability_constraint[hydro,12,2] :              -6.0
#          availability_constraint[hydro,12,3] :              -6.0
#          availability_constraint[hydro,12,4] :              -6.0
#          availability_constraint[hydro,13,1] :              -9.0
#          availability_constraint[hydro,13,2] :              -9.0
#          availability_constraint[hydro,13,3] :              -6.0
#          availability_constraint[hydro,13,4] :              -9.0
#          availability_constraint[hydro,14,1] :              -9.0
#          availability_constraint[hydro,14,2] :              -7.0
#          availability_constraint[hydro,14,3] :              -7.0
#          availability_constraint[hydro,14,4] :              -7.0
#          availability_constraint[hydro,15,1] :              -7.0
#          availability_constraint[hydro,15,2] :              -7.0
#          availability_constraint[hydro,15,3] :               0.0
#          availability_constraint[hydro,15,4] :              -7.0
#          availability_constraint[hydro,16,1] :               0.0
#          availability_constraint[hydro,16,2] :               0.0
#          availability_constraint[hydro,16,3] :               0.0
#          availability_constraint[hydro,16,4] :               0.0
#          availability_constraint[hydro,17,1] :              -3.0
#          availability_constraint[hydro,17,2] :              -3.0
#          availability_constraint[hydro,17,3] :              -3.0
#          availability_constraint[hydro,17,4] :              -3.0
#          availability_constraint[hydro,18,1] :             -10.0
#          availability_constraint[hydro,18,2] :             -10.0
#          availability_constraint[hydro,18,3] :              -8.0
#          availability_constraint[hydro,18,4] :             -10.0
#          availability_constraint[hydro,19,1] :               0.0
#          availability_constraint[hydro,19,2] :               0.0
#          availability_constraint[hydro,19,3] :               0.0
#          availability_constraint[hydro,19,4] :               0.0
#           availability_constraint[hydro,2,1] :              -7.0
#           availability_constraint[hydro,2,2] :              -2.0
#           availability_constraint[hydro,2,3] :              -2.0
#           availability_constraint[hydro,2,4] :              -2.0
#          availability_constraint[hydro,20,1] :               0.0
#          availability_constraint[hydro,20,2] :               0.0
#          availability_constraint[hydro,20,3] :               0.0
#          availability_constraint[hydro,20,4] :               0.0
#          availability_constraint[hydro,21,1] :             -10.0
#          availability_constraint[hydro,21,2] :             -10.0
#          availability_constraint[hydro,21,3] :             -10.0
#          availability_constraint[hydro,21,4] :             -10.0
#          availability_constraint[hydro,22,1] :             -29.0
#          availability_constraint[hydro,22,2] :             -29.0
#          availability_constraint[hydro,22,3] :               0.0
#          availability_constraint[hydro,22,4] :               0.0
#          availability_constraint[hydro,23,1] :              -3.0
#          availability_constraint[hydro,23,2] :              -3.0
#          availability_constraint[hydro,23,3] :              -3.0
#          availability_constraint[hydro,23,4] :              -3.0
#          availability_constraint[hydro,24,1] :               0.0
#          availability_constraint[hydro,24,2] :               0.0
#          availability_constraint[hydro,24,3] :               0.0
#          availability_constraint[hydro,24,4] :               0.0
#          availability_constraint[hydro,25,1] :              -6.0
#          availability_constraint[hydro,25,2] :               0.0
#          availability_constraint[hydro,25,3] :               0.0
#          availability_constraint[hydro,25,4] :               0.0
#           availability_constraint[hydro,3,1] :               0.0
#           availability_constraint[hydro,3,2] :               0.0
#           availability_constraint[hydro,3,3] :               0.0
#           availability_constraint[hydro,3,4] :               0.0
#           availability_constraint[hydro,4,1] :             -11.0
#           availability_constraint[hydro,4,2] :             -11.0
#           availability_constraint[hydro,4,3] :             -11.0
#           availability_constraint[hydro,4,4] :             -11.0
#           availability_constraint[hydro,5,1] :               0.0
#           availability_constraint[hydro,5,2] :               0.0
#           availability_constraint[hydro,5,3] :               0.0
#           availability_constraint[hydro,5,4] :               0.0
#           availability_constraint[hydro,6,1] :             -11.0
#           availability_constraint[hydro,6,2] :             -11.0
#           availability_constraint[hydro,6,3] :             -11.0
#           availability_constraint[hydro,6,4] :             -11.0
#           availability_constraint[hydro,7,1] :              -6.0
#           availability_constraint[hydro,7,2] :              -1.0
#           availability_constraint[hydro,7,3] :              -1.0
#           availability_constraint[hydro,7,4] :              -3.0
#           availability_constraint[hydro,8,1] :              -1.0
#           availability_constraint[hydro,8,2] :              -1.0
#           availability_constraint[hydro,8,3] :              -1.0
#           availability_constraint[hydro,8,4] :              -1.0
#           availability_constraint[hydro,9,1] :              -5.0
#           availability_constraint[hydro,9,2] :              -5.0
#           availability_constraint[hydro,9,3] :              -5.0
#           availability_constraint[hydro,9,4] :              -5.0
#         availability_constraint[nuclear,1,1] :               0.0
#         availability_constraint[nuclear,1,2] :               0.0
#         availability_constraint[nuclear,1,3] :               0.0
#         availability_constraint[nuclear,1,4] :               0.0
#        availability_constraint[nuclear,10,1] :               0.0
#        availability_constraint[nuclear,10,2] :               0.0
#        availability_constraint[nuclear,10,3] :               0.0
#        availability_constraint[nuclear,10,4] :               0.0
#        availability_constraint[nuclear,11,1] :               0.0
#        availability_constraint[nuclear,11,2] :               0.0
#        availability_constraint[nuclear,11,3] :               0.0
#        availability_constraint[nuclear,11,4] :               0.0
#        availability_constraint[nuclear,12,1] :               0.0
#        availability_constraint[nuclear,12,2] :               0.0
#        availability_constraint[nuclear,12,3] :               0.0
#        availability_constraint[nuclear,12,4] :               0.0
#        availability_constraint[nuclear,13,1] :               0.0
#        availability_constraint[nuclear,13,2] :               0.0
#        availability_constraint[nuclear,13,3] :               0.0
#        availability_constraint[nuclear,13,4] :               0.0
#        availability_constraint[nuclear,14,1] :               0.0
#        availability_constraint[nuclear,14,2] :               0.0
#        availability_constraint[nuclear,14,3] :               0.0
#        availability_constraint[nuclear,14,4] :               0.0
#        availability_constraint[nuclear,15,1] :               0.0
#        availability_constraint[nuclear,15,2] :               0.0
#        availability_constraint[nuclear,15,3] :               0.0
#        availability_constraint[nuclear,15,4] :               0.0
#        availability_constraint[nuclear,16,1] :               0.0
#        availability_constraint[nuclear,16,2] :               0.0
#        availability_constraint[nuclear,16,3] :               0.0
#        availability_constraint[nuclear,16,4] :               0.0
#        availability_constraint[nuclear,17,1] :               0.0
#        availability_constraint[nuclear,17,2] :               0.0
#        availability_constraint[nuclear,17,3] :               0.0
#        availability_constraint[nuclear,17,4] :               0.0
#        availability_constraint[nuclear,18,1] :               0.0
#        availability_constraint[nuclear,18,2] :               0.0
#        availability_constraint[nuclear,18,3] :               0.0
#        availability_constraint[nuclear,18,4] :               0.0
#        availability_constraint[nuclear,19,1] :               0.0
#        availability_constraint[nuclear,19,2] :               0.0
#        availability_constraint[nuclear,19,3] :               0.0
#        availability_constraint[nuclear,19,4] :               0.0
#         availability_constraint[nuclear,2,1] :               0.0
#         availability_constraint[nuclear,2,2] :               0.0
#         availability_constraint[nuclear,2,3] :               0.0
#         availability_constraint[nuclear,2,4] :               0.0
#        availability_constraint[nuclear,20,1] :               0.0
#        availability_constraint[nuclear,20,2] :               0.0
#        availability_constraint[nuclear,20,3] :               0.0
#        availability_constraint[nuclear,20,4] :               0.0
#        availability_constraint[nuclear,21,1] :               0.0
#        availability_constraint[nuclear,21,2] :               0.0
#        availability_constraint[nuclear,21,3] :               0.0
#        availability_constraint[nuclear,21,4] :               0.0
#        availability_constraint[nuclear,22,1] :               0.0
#        availability_constraint[nuclear,22,2] :               0.0
#        availability_constraint[nuclear,22,3] :               0.0
#        availability_constraint[nuclear,22,4] :               0.0
#        availability_constraint[nuclear,23,1] :               0.0
#        availability_constraint[nuclear,23,2] :               0.0
#        availability_constraint[nuclear,23,3] :               0.0
#        availability_constraint[nuclear,23,4] :               0.0
#        availability_constraint[nuclear,24,1] :               0.0
#        availability_constraint[nuclear,24,2] :               0.0
#        availability_constraint[nuclear,24,3] :               0.0
#        availability_constraint[nuclear,24,4] :               0.0
#        availability_constraint[nuclear,25,1] :               0.0
#        availability_constraint[nuclear,25,2] :               0.0
#        availability_constraint[nuclear,25,3] :               0.0
#        availability_constraint[nuclear,25,4] :               0.0
#         availability_constraint[nuclear,3,1] :               0.0
#         availability_constraint[nuclear,3,2] :               0.0
#         availability_constraint[nuclear,3,3] :               0.0
#         availability_constraint[nuclear,3,4] :               0.0
#         availability_constraint[nuclear,4,1] :               0.0
#         availability_constraint[nuclear,4,2] :               0.0
#         availability_constraint[nuclear,4,3] :               0.0
#         availability_constraint[nuclear,4,4] :               0.0
#         availability_constraint[nuclear,5,1] :               0.0
#         availability_constraint[nuclear,5,2] :               0.0
#         availability_constraint[nuclear,5,3] :               0.0
#         availability_constraint[nuclear,5,4] :               0.0
#         availability_constraint[nuclear,6,1] :               0.0
#         availability_constraint[nuclear,6,2] :               0.0
#         availability_constraint[nuclear,6,3] :               0.0
#         availability_constraint[nuclear,6,4] :               0.0
#         availability_constraint[nuclear,7,1] :               0.0
#         availability_constraint[nuclear,7,2] :               0.0
#         availability_constraint[nuclear,7,3] :               0.0
#         availability_constraint[nuclear,7,4] :               0.0
#         availability_constraint[nuclear,8,1] :               0.0
#         availability_constraint[nuclear,8,2] :               0.0
#         availability_constraint[nuclear,8,3] :               0.0
#         availability_constraint[nuclear,8,4] :               0.0
#         availability_constraint[nuclear,9,1] :               0.0
#         availability_constraint[nuclear,9,2] :               0.0
#         availability_constraint[nuclear,9,3] :               0.0
#         availability_constraint[nuclear,9,4] :               0.0
#           availability_constraint[solar,1,1] :             -13.0
#           availability_constraint[solar,1,2] :             -13.0
#           availability_constraint[solar,1,3] :             -13.0
#           availability_constraint[solar,1,4] :             -13.0
#          availability_constraint[solar,10,1] :             -20.0
#          availability_constraint[solar,10,2] :             -20.0
#          availability_constraint[solar,10,3] :             -20.0
#          availability_constraint[solar,10,4] :             -20.0
#          availability_constraint[solar,11,1] :             -21.0
#          availability_constraint[solar,11,2] :             -21.0
#          availability_constraint[solar,11,3] :             -21.0
#          availability_constraint[solar,11,4] :             -21.0
#          availability_constraint[solar,12,1] :             -25.0
#          availability_constraint[solar,12,2] :             -25.0
#          availability_constraint[solar,12,3] :             -25.0
#          availability_constraint[solar,12,4] :             -25.0
#          availability_constraint[solar,13,1] :             -14.0
#          availability_constraint[solar,13,2] :             -14.0
#          availability_constraint[solar,13,3] :             -11.0
#          availability_constraint[solar,13,4] :             -14.0
#          availability_constraint[solar,14,1] :             -29.0
#          availability_constraint[solar,14,2] :             -27.0
#          availability_constraint[solar,14,3] :             -27.0
#          availability_constraint[solar,14,4] :             -27.0
#          availability_constraint[solar,15,1] :             -18.0
#          availability_constraint[solar,15,2] :             -18.0
#          availability_constraint[solar,15,3] :             -11.0
#          availability_constraint[solar,15,4] :             -18.0
#          availability_constraint[solar,16,1] :             -13.0
#          availability_constraint[solar,16,2] :             -13.0
#          availability_constraint[solar,16,3] :             -13.0
#          availability_constraint[solar,16,4] :              -9.0
#          availability_constraint[solar,17,1] :             -18.0
#          availability_constraint[solar,17,2] :             -18.0
#          availability_constraint[solar,17,3] :             -18.0
#          availability_constraint[solar,17,4] :             -18.0
#          availability_constraint[solar,18,1] :             -20.0
#          availability_constraint[solar,18,2] :             -20.0
#          availability_constraint[solar,18,3] :             -18.0
#          availability_constraint[solar,18,4] :             -20.0
#          availability_constraint[solar,19,1] :             -10.0
#          availability_constraint[solar,19,2] :              -4.0
#          availability_constraint[solar,19,3] :              -4.0
#          availability_constraint[solar,19,4] :              -4.0
#           availability_constraint[solar,2,1] :             -26.0
#           availability_constraint[solar,2,2] :             -21.0
#           availability_constraint[solar,2,3] :             -21.0
#           availability_constraint[solar,2,4] :             -21.0
#          availability_constraint[solar,20,1] :              -8.0
#          availability_constraint[solar,20,2] :              -8.0
#          availability_constraint[solar,20,3] :              -8.0
#          availability_constraint[solar,20,4] :              -8.0
#          availability_constraint[solar,21,1] :             -20.0
#          availability_constraint[solar,21,2] :             -20.0
#          availability_constraint[solar,21,3] :             -20.0
#          availability_constraint[solar,21,4] :             -20.0
#          availability_constraint[solar,22,1] :             -30.0
#          availability_constraint[solar,22,2] :             -30.0
#          availability_constraint[solar,22,3] :              -1.0
#          availability_constraint[solar,22,4] :              -1.0
#          availability_constraint[solar,23,1] :             -22.0
#          availability_constraint[solar,23,2] :             -22.0
#          availability_constraint[solar,23,3] :             -22.0
#          availability_constraint[solar,23,4] :             -22.0
#          availability_constraint[solar,24,1] :              -8.0
#          availability_constraint[solar,24,2] :              -8.0
#          availability_constraint[solar,24,3] :              -8.0
#          availability_constraint[solar,24,4] :              -8.0
#          availability_constraint[solar,25,1] :             -23.0
#          availability_constraint[solar,25,2] :             -17.0
#          availability_constraint[solar,25,3] :             -17.0
#          availability_constraint[solar,25,4] :             -17.0
#           availability_constraint[solar,3,1] :             -13.0
#           availability_constraint[solar,3,2] :              -9.0
#           availability_constraint[solar,3,3] :              -9.0
#           availability_constraint[solar,3,4] :              -9.0
#           availability_constraint[solar,4,1] :             -22.0
#           availability_constraint[solar,4,2] :             -22.0
#           availability_constraint[solar,4,3] :             -22.0
#           availability_constraint[solar,4,4] :             -22.0
#           availability_constraint[solar,5,1] :             -12.0
#           availability_constraint[solar,5,2] :             -12.0
#           availability_constraint[solar,5,3] :             -12.0
#           availability_constraint[solar,5,4] :             -12.0
#           availability_constraint[solar,6,1] :             -15.0
#           availability_constraint[solar,6,2] :             -15.0
#           availability_constraint[solar,6,3] :             -15.0
#           availability_constraint[solar,6,4] :             -15.0
#           availability_constraint[solar,7,1] :             -25.0
#           availability_constraint[solar,7,2] :             -20.0
#           availability_constraint[solar,7,3] :             -20.0
#           availability_constraint[solar,7,4] :             -22.0
#           availability_constraint[solar,8,1] :             -22.0
#           availability_constraint[solar,8,2] :             -22.0
#           availability_constraint[solar,8,3] :             -22.0
#           availability_constraint[solar,8,4] :             -22.0
#           availability_constraint[solar,9,1] :             -19.0
#           availability_constraint[solar,9,2] :             -19.0
#           availability_constraint[solar,9,3] :             -19.0
#           availability_constraint[solar,9,4] :             -19.0
#            availability_constraint[wind,1,1] :               0.0
#            availability_constraint[wind,1,2] :               0.0
#            availability_constraint[wind,1,3] :               0.0
#            availability_constraint[wind,1,4] :               0.0
#           availability_constraint[wind,10,1] :               0.0
#           availability_constraint[wind,10,2] :               0.0
#           availability_constraint[wind,10,3] :               0.0
#           availability_constraint[wind,10,4] :               0.0
#           availability_constraint[wind,11,1] :               0.0
#           availability_constraint[wind,11,2] :               0.0
#           availability_constraint[wind,11,3] :               0.0
#           availability_constraint[wind,11,4] :               0.0
#           availability_constraint[wind,12,1] :               0.0
#           availability_constraint[wind,12,2] :               0.0
#           availability_constraint[wind,12,3] :               0.0
#           availability_constraint[wind,12,4] :               0.0
#           availability_constraint[wind,13,1] :             -20.0
#           availability_constraint[wind,13,2] :             -20.0
#           availability_constraint[wind,13,3] :             -17.0
#           availability_constraint[wind,13,4] :             -20.0
#           availability_constraint[wind,14,1] :               0.0
#           availability_constraint[wind,14,2] :               0.0
#           availability_constraint[wind,14,3] :               0.0
#           availability_constraint[wind,14,4] :               0.0
#           availability_constraint[wind,15,1] :             -13.0
#           availability_constraint[wind,15,2] :             -13.0
#           availability_constraint[wind,15,3] :              -6.0
#           availability_constraint[wind,15,4] :             -13.0
#           availability_constraint[wind,16,1] :               0.0
#           availability_constraint[wind,16,2] :               0.0
#           availability_constraint[wind,16,3] :               0.0
#           availability_constraint[wind,16,4] :               0.0
#           availability_constraint[wind,17,1] :               0.0
#           availability_constraint[wind,17,2] :               0.0
#           availability_constraint[wind,17,3] :               0.0
#           availability_constraint[wind,17,4] :               0.0
#           availability_constraint[wind,18,1] :               0.0
#           availability_constraint[wind,18,2] :               0.0
#           availability_constraint[wind,18,3] :               0.0
#           availability_constraint[wind,18,4] :               0.0
#           availability_constraint[wind,19,1] :             -12.0
#           availability_constraint[wind,19,2] :               0.0
#           availability_constraint[wind,19,3] :               0.0
#           availability_constraint[wind,19,4] :              -6.0
#            availability_constraint[wind,2,1] :               0.0
#            availability_constraint[wind,2,2] :               0.0
#            availability_constraint[wind,2,3] :               0.0
#            availability_constraint[wind,2,4] :               0.0
#           availability_constraint[wind,20,1] :               0.0
#           availability_constraint[wind,20,2] :             -11.0
#           availability_constraint[wind,20,3] :             -11.0
#           availability_constraint[wind,20,4] :               0.0
#           availability_constraint[wind,21,1] :               0.0
#           availability_constraint[wind,21,2] :               0.0
#           availability_constraint[wind,21,3] :               0.0
#           availability_constraint[wind,21,4] :               0.0
#           availability_constraint[wind,22,1] :             -37.0
#           availability_constraint[wind,22,2] :               0.0
#           availability_constraint[wind,22,3] :              -8.0
#           availability_constraint[wind,22,4] :               0.0
#           availability_constraint[wind,23,1] :               0.0
#           availability_constraint[wind,23,2] :             -13.0
#           availability_constraint[wind,23,3] :               0.0
#           availability_constraint[wind,23,4] :               0.0
#           availability_constraint[wind,24,1] :             -11.0
#           availability_constraint[wind,24,2] :             -11.0
#           availability_constraint[wind,24,3] :             -11.0
#           availability_constraint[wind,24,4] :             -11.0
#           availability_constraint[wind,25,1] :             -19.0
#           availability_constraint[wind,25,2] :             -13.0
#           availability_constraint[wind,25,3] :             -13.0
#           availability_constraint[wind,25,4] :             -13.0
#            availability_constraint[wind,3,1] :               0.0
#            availability_constraint[wind,3,2] :               0.0
#            availability_constraint[wind,3,3] :               0.0
#            availability_constraint[wind,3,4] :               0.0
#            availability_constraint[wind,4,1] :               0.0
#            availability_constraint[wind,4,2] :               0.0
#            availability_constraint[wind,4,3] :               0.0
#            availability_constraint[wind,4,4] :               0.0
#            availability_constraint[wind,5,1] :               0.0
#            availability_constraint[wind,5,2] :               0.0
#            availability_constraint[wind,5,3] :               0.0
#            availability_constraint[wind,5,4] :               0.0
#            availability_constraint[wind,6,1] :             -22.0
#            availability_constraint[wind,6,2] :             -22.0
#            availability_constraint[wind,6,3] :             -22.0
#            availability_constraint[wind,6,4] :             -22.0
#            availability_constraint[wind,7,1] :             -20.0
#            availability_constraint[wind,7,2] :             -15.0
#            availability_constraint[wind,7,3] :             -15.0
#            availability_constraint[wind,7,4] :               0.0
#            availability_constraint[wind,8,1] :             -14.0
#            availability_constraint[wind,8,2] :             -14.0
#            availability_constraint[wind,8,3] :             -14.0
#            availability_constraint[wind,8,4] :             -14.0
#            availability_constraint[wind,9,1] :               0.0
#            availability_constraint[wind,9,2] :               0.0
#            availability_constraint[wind,9,3] :               0.0
#            availability_constraint[wind,9,4] :               0.0
#                       demand_constraint[1,1] :              37.0
#                       demand_constraint[1,2] :              37.0
#                       demand_constraint[1,3] :              37.0
#                       demand_constraint[1,4] :              37.0
#                      demand_constraint[10,1] :              36.0
#                      demand_constraint[10,2] :              34.0
#                      demand_constraint[10,3] :              34.0
#                      demand_constraint[10,4] :              34.0
#                      demand_constraint[11,1] :              36.0
#                      demand_constraint[11,2] :              36.0
#                      demand_constraint[11,3] :              36.0
#                      demand_constraint[11,4] :              36.0
#                      demand_constraint[12,1] :              38.0
#                      demand_constraint[12,2] :              38.0
#                      demand_constraint[12,3] :              38.0
#                      demand_constraint[12,4] :              38.0
#                      demand_constraint[13,1] :              35.0
#                      demand_constraint[13,2] :              32.0
#                      demand_constraint[13,3] :              32.0
#                      demand_constraint[13,4] :              32.0
#                      demand_constraint[14,1] :              40.0
#                      demand_constraint[14,2] :              38.0
#                      demand_constraint[14,3] :              38.0
#                      demand_constraint[14,4] :              38.0
#                      demand_constraint[15,1] :              33.0
#                      demand_constraint[15,2] :              33.0
#                      demand_constraint[15,3] :              26.0
#                      demand_constraint[15,4] :              33.0
#                      demand_constraint[16,1] :              31.0
#                      demand_constraint[16,2] :              31.0
#                      demand_constraint[16,3] :              27.0
#                      demand_constraint[16,4] :              27.0
#                      demand_constraint[17,1] :              36.0
#                      demand_constraint[17,2] :              36.0
#                      demand_constraint[17,3] :              36.0
#                      demand_constraint[17,4] :              36.0
#                      demand_constraint[18,1] :              35.0
#                      demand_constraint[18,2] :              35.0
#                      demand_constraint[18,3] :              33.0
#                      demand_constraint[18,4] :              33.0
#                      demand_constraint[19,1] :              33.0
#                      demand_constraint[19,2] :              26.0
#                      demand_constraint[19,3] :              26.0
#                      demand_constraint[19,4] :              26.0
#                       demand_constraint[2,1] :              40.0
#                       demand_constraint[2,2] :              35.0
#                       demand_constraint[2,3] :              35.0
#                       demand_constraint[2,4] :              35.0
#                      demand_constraint[20,1] :              31.0
#                      demand_constraint[20,2] :              31.0
#                      demand_constraint[20,3] :              31.0
#                      demand_constraint[20,4] :              31.0
#                      demand_constraint[21,1] :              35.0
#                      demand_constraint[21,2] :              35.0
#                      demand_constraint[21,3] :              35.0
#                      demand_constraint[21,4] :              35.0
#                      demand_constraint[22,1] :              54.0
#                      demand_constraint[22,2] :              54.0
#                      demand_constraint[22,3] :              25.0
#                      demand_constraint[22,4] :              25.0
#                      demand_constraint[23,1] :              36.0
#                      demand_constraint[23,2] :              36.0
#                      demand_constraint[23,3] :              36.0
#                      demand_constraint[23,4] :              36.0
#                      demand_constraint[24,1] :              27.0
#                      demand_constraint[24,2] :              27.0
#                      demand_constraint[24,3] :              27.0
#                      demand_constraint[24,4] :              27.0
#                      demand_constraint[25,1] :              36.0
#                      demand_constraint[25,2] :              29.0
#                      demand_constraint[25,3] :              29.0
#                      demand_constraint[25,4] :              29.0
#                       demand_constraint[3,1] :              34.0
#                       demand_constraint[3,2] :              28.0
#                       demand_constraint[3,3] :              28.0
#                       demand_constraint[3,4] :              28.0
#                       demand_constraint[4,1] :              29.0
#                       demand_constraint[4,2] :              39.0
#                       demand_constraint[4,3] :              29.0
#                       demand_constraint[4,4] :              29.0
#                       demand_constraint[5,1] :              31.0
#                       demand_constraint[5,2] :              31.0
#                       demand_constraint[5,3] :              26.0
#                       demand_constraint[5,4] :              26.0
#                       demand_constraint[6,1] :              38.0
#                       demand_constraint[6,2] :              38.0
#                       demand_constraint[6,3] :              38.0
#                       demand_constraint[6,4] :              38.0
#                       demand_constraint[7,1] :              40.0
#                       demand_constraint[7,2] :              35.0
#                       demand_constraint[7,3] :              35.0
#                       demand_constraint[7,4] :              37.0
#                       demand_constraint[8,1] :              34.0
#                       demand_constraint[8,2] :              34.0
#                       demand_constraint[8,3] :              34.0
#                       demand_constraint[8,4] :              34.0
#                       demand_constraint[9,1] :              30.0
#                       demand_constraint[9,2] :              30.0
#                       demand_constraint[9,3] :              30.0
#                       demand_constraint[9,4] :              30.0
#                environmental_constraint[1,1] :  -65.675354569385
#                environmental_constraint[1,2] :  -65.675354569385
#                environmental_constraint[1,3] :  -65.675354569385
#                environmental_constraint[1,4] :  -65.675354569385
#               environmental_constraint[10,1] : -92.8001849862692
#               environmental_constraint[10,2] : -92.8001849862692
#               environmental_constraint[10,3] : -92.8001849862692
#               environmental_constraint[10,4] : -92.8001849862692
#               environmental_constraint[11,1] : -82.0152977409272
#               environmental_constraint[11,2] : -82.0152977409272
#               environmental_constraint[11,3] : -82.0152977409272
#               environmental_constraint[11,4] : -82.0152977409272
#               environmental_constraint[12,1] : -89.1887234913031
#               environmental_constraint[12,2] : -89.1887234913031
#               environmental_constraint[12,3] : -89.1887234913031
#               environmental_constraint[12,4] : -89.1887234913031
#               environmental_constraint[13,1] :               0.0
#               environmental_constraint[13,2] :               0.0
#               environmental_constraint[13,3] :               0.0
#               environmental_constraint[13,4] :               0.0
#               environmental_constraint[14,1] : -79.9396988538795
#               environmental_constraint[14,2] : -69.9472364971445
#               environmental_constraint[14,3] : -69.9472364971445
#               environmental_constraint[14,4] : -69.9472364971445
#               environmental_constraint[15,1] :               0.0
#               environmental_constraint[15,2] :               0.0
#               environmental_constraint[15,3] :               0.0
#               environmental_constraint[15,4] :               0.0
#               environmental_constraint[16,1] : -73.1221132874616
#               environmental_constraint[16,2] : -73.1221132874616
#               environmental_constraint[16,3] : -73.1221132874616
#               environmental_constraint[16,4] : -50.6230015067041
#               environmental_constraint[17,1] : -109.325630058335
#               environmental_constraint[17,2] : -109.325630058335
#               environmental_constraint[17,3] : -109.325630058335
#               environmental_constraint[17,4] : -109.325630058335
# ...
#               environmental_constraint[21,3] : -76.0006125292939
#               environmental_constraint[21,4] : -76.0006125292939
#               environmental_constraint[22,1] :               0.0
#               environmental_constraint[22,2] : -241.839769837097
#               environmental_constraint[22,3] :               0.0
#               environmental_constraint[22,4] : -52.2896799647777
#               environmental_constraint[23,1] : -84.1768575037602
#               environmental_constraint[23,2] :               0.0
#               environmental_constraint[23,3] : -84.1768575037602
#               environmental_constraint[23,4] : -84.1768575037602
#               environmental_constraint[24,1] :               0.0
#               environmental_constraint[24,2] :               0.0
#               environmental_constraint[24,3] :               0.0
#               environmental_constraint[24,4] :               0.0
#               environmental_constraint[25,1] :               0.0
#               environmental_constraint[25,2] :               0.0
#               environmental_constraint[25,3] :               0.0
#               environmental_constraint[25,4] :               0.0
#                environmental_constraint[3,1] : -64.4725682446937
#                environmental_constraint[3,2] : -48.3544261835202
#                environmental_constraint[3,3] : -48.3544261835202
#                environmental_constraint[3,4] : -48.3544261835202
#                environmental_constraint[4,1] : -96.2505121839596
#                environmental_constraint[4,2] : -96.2505121839596
#                environmental_constraint[4,3] : -96.2505121839596
#                environmental_constraint[4,4] : -96.2505121839596
#                environmental_constraint[5,1] : -42.5639733857348
#                environmental_constraint[5,2] : -42.5639733857348
#                environmental_constraint[5,3] : -42.5639733857348
#                environmental_constraint[5,4] : -42.5639733857348
#                environmental_constraint[6,1] :               0.0
#                environmental_constraint[6,2] :               0.0
#                environmental_constraint[6,3] :               0.0
#                environmental_constraint[6,4] :               0.0
#                environmental_constraint[7,1] :               0.0
#                environmental_constraint[7,2] :               0.0
#                environmental_constraint[7,3] :               0.0
#                environmental_constraint[7,4] : -124.549307819616
#                environmental_constraint[8,1] :               0.0
#                environmental_constraint[8,2] :               0.0
#                environmental_constraint[8,3] :               0.0
#                environmental_constraint[8,4] :               0.0
#                environmental_constraint[9,1] : -55.9074155754968
#                environmental_constraint[9,2] : -55.9074155754968
#                environmental_constraint[9,3] : -55.9074155754968
#                environmental_constraint[9,4] : -55.9074155754968
#                  min_nuclear_constraint[1,1] :              11.0
#                  min_nuclear_constraint[1,2] :              11.0
#                  min_nuclear_constraint[1,3] :              11.0
#                  min_nuclear_constraint[1,4] :              11.0
#                 min_nuclear_constraint[10,1] :              22.0
#                 min_nuclear_constraint[10,2] :              24.0
#                 min_nuclear_constraint[10,3] :              24.0
#                 min_nuclear_constraint[10,4] :              24.0
#                 min_nuclear_constraint[11,1] :               6.0
#                 min_nuclear_constraint[11,2] :               6.0
#                 min_nuclear_constraint[11,3] :               6.0
#                 min_nuclear_constraint[11,4] :               6.0
#                 min_nuclear_constraint[12,1] :              10.0
#                 min_nuclear_constraint[12,2] :              10.0
#                 min_nuclear_constraint[12,3] :              10.0
#                 min_nuclear_constraint[12,4] :              10.0
#                 min_nuclear_constraint[13,1] :              22.0
#                 min_nuclear_constraint[13,2] :              25.0
#                 min_nuclear_constraint[13,3] :              25.0
#                 min_nuclear_constraint[13,4] :              25.0
#                 min_nuclear_constraint[14,1] :               0.0
#                 min_nuclear_constraint[14,2] :               2.0
#                 min_nuclear_constraint[14,3] :               2.0
#                 min_nuclear_constraint[14,4] :               2.0
#                 min_nuclear_constraint[15,1] :              17.0
#                 min_nuclear_constraint[15,2] :              17.0
#                 min_nuclear_constraint[15,3] :              24.0
#                 min_nuclear_constraint[15,4] :              17.0
#                 min_nuclear_constraint[16,1] :               9.0
#                 min_nuclear_constraint[16,2] :               9.0
#                 min_nuclear_constraint[16,3] :              13.0
#                 min_nuclear_constraint[16,4] :              13.0
#                 min_nuclear_constraint[17,1] :              22.0
#                 min_nuclear_constraint[17,2] :              22.0
#                 min_nuclear_constraint[17,3] :              22.0
#                 min_nuclear_constraint[17,4] :              22.0
#                 min_nuclear_constraint[18,1] :              10.0
#                 min_nuclear_constraint[18,2] :              10.0
#                 min_nuclear_constraint[18,3] :              12.0
#                 min_nuclear_constraint[18,4] :              12.0
#                 min_nuclear_constraint[19,1] :              11.0
#                 min_nuclear_constraint[19,2] :              18.0
#                 min_nuclear_constraint[19,3] :              18.0
#                 min_nuclear_constraint[19,4] :              18.0
#                  min_nuclear_constraint[2,1] :               0.0
#                  min_nuclear_constraint[2,2] :               5.0
#                  min_nuclear_constraint[2,3] :               5.0
#                  min_nuclear_constraint[2,4] :               5.0
#                 min_nuclear_constraint[20,1] :              26.0
#                 min_nuclear_constraint[20,2] :              26.0
#                 min_nuclear_constraint[20,3] :              26.0
#                 min_nuclear_constraint[20,4] :              26.0
#                 min_nuclear_constraint[21,1] :              17.0
#                 min_nuclear_constraint[21,2] :              17.0
#                 min_nuclear_constraint[21,3] :              17.0
#                 min_nuclear_constraint[21,4] :              17.0
#                 min_nuclear_constraint[22,1] :               0.0
#                 min_nuclear_constraint[22,2] :               0.0
#                 min_nuclear_constraint[22,3] :              29.0
#                 min_nuclear_constraint[22,4] :              29.0
#                 min_nuclear_constraint[23,1] :              23.0
#                 min_nuclear_constraint[23,2] :              23.0
#                 min_nuclear_constraint[23,3] :              23.0
#                 min_nuclear_constraint[23,4] :              23.0
#                 min_nuclear_constraint[24,1] :              28.0
#                 min_nuclear_constraint[24,2] :              28.0
#                 min_nuclear_constraint[24,3] :              28.0
#                 min_nuclear_constraint[24,4] :              28.0
#                 min_nuclear_constraint[25,1] :               8.0
#                 min_nuclear_constraint[25,2] :              15.0
#                 min_nuclear_constraint[25,3] :              15.0
#                 min_nuclear_constraint[25,4] :              15.0
#                  min_nuclear_constraint[3,1] :              17.0
#                  min_nuclear_constraint[3,2] :              23.0
#                  min_nuclear_constraint[3,3] :              23.0
#                  min_nuclear_constraint[3,4] :              23.0
#                  min_nuclear_constraint[4,1] :              14.0
#                  min_nuclear_constraint[4,2] :               4.0
#                  min_nuclear_constraint[4,3] :              14.0
#                  min_nuclear_constraint[4,4] :              14.0
#                  min_nuclear_constraint[5,1] :              11.0
#                  min_nuclear_constraint[5,2] :              11.0
#                  min_nuclear_constraint[5,3] :              16.0
#                  min_nuclear_constraint[5,4] :              16.0
#                  min_nuclear_constraint[6,1] :               7.0
#                  min_nuclear_constraint[6,2] :               7.0
#                  min_nuclear_constraint[6,3] :               7.0
#                  min_nuclear_constraint[6,4] :               7.0
#                  min_nuclear_constraint[7,1] :               0.0
#                  min_nuclear_constraint[7,2] :               5.0
#                  min_nuclear_constraint[7,3] :               5.0
#                  min_nuclear_constraint[7,4] :               3.0
#                  min_nuclear_constraint[8,1] :              22.0
#                  min_nuclear_constraint[8,2] :              22.0
#                  min_nuclear_constraint[8,3] :              22.0
#                  min_nuclear_constraint[8,4] :              22.0
#                  min_nuclear_constraint[9,1] :              12.0
#                  min_nuclear_constraint[9,2] :              12.0
#                  min_nuclear_constraint[9,3] :              12.0
#                  min_nuclear_constraint[9,4] :              12.0
#                min_renewable_constraint[1,1] :               0.0
#                min_renewable_constraint[1,2] :               0.0
#                min_renewable_constraint[1,3] :               0.0
#                min_renewable_constraint[1,4] :               0.0
#               min_renewable_constraint[10,1] :               0.0
#               min_renewable_constraint[10,2] :               2.0
#               min_renewable_constraint[10,3] :               2.0
#               min_renewable_constraint[10,4] :               2.0
#               min_renewable_constraint[11,1] :               0.0
#               min_renewable_constraint[11,2] :               0.0
#               min_renewable_constraint[11,3] :               0.0
#               min_renewable_constraint[11,4] :               0.0
#               min_renewable_constraint[12,1] :               0.0
#               min_renewable_constraint[12,2] :               0.0
#               min_renewable_constraint[12,3] :               0.0
#               min_renewable_constraint[12,4] :               0.0
#               min_renewable_constraint[13,1] :               0.0
#               min_renewable_constraint[13,2] :               3.0
#               min_renewable_constraint[13,3] :               0.0
#               min_renewable_constraint[13,4] :               3.0
#               min_renewable_constraint[14,1] :               0.0
#               min_renewable_constraint[14,2] :               0.0
#               min_renewable_constraint[14,3] :               0.0
#               min_renewable_constraint[14,4] :               0.0
#               min_renewable_constraint[15,1] :               0.0
#               min_renewable_constraint[15,2] :               0.0
#               min_renewable_constraint[15,3] :               0.0
#               min_renewable_constraint[15,4] :               0.0
#               min_renewable_constraint[16,1] :               0.0
#               min_renewable_constraint[16,2] :               0.0
#               min_renewable_constraint[16,3] :               4.0
#               min_renewable_constraint[16,4] :               0.0
#               min_renewable_constraint[17,1] :               0.0
#               min_renewable_constraint[17,2] :               0.0
#               min_renewable_constraint[17,3] :               0.0
#               min_renewable_constraint[17,4] :               0.0
#               min_renewable_constraint[18,1] :               0.0
#               min_renewable_constraint[18,2] :               0.0
#               min_renewable_constraint[18,3] :               0.0
#               min_renewable_constraint[18,4] :               2.0
#               min_renewable_constraint[19,1] :               0.0
#               min_renewable_constraint[19,2] :               1.0
#               min_renewable_constraint[19,3] :               1.0
#               min_renewable_constraint[19,4] :               1.0
#                min_renewable_constraint[2,1] :               0.0
#                min_renewable_constraint[2,2] :               0.0
#                min_renewable_constraint[2,3] :               0.0
#                min_renewable_constraint[2,4] :               0.0
#               min_renewable_constraint[20,1] :               0.0
#               min_renewable_constraint[20,2] :               0.0
#               min_renewable_constraint[20,3] :               0.0
#               min_renewable_constraint[20,4] :               0.0
#               min_renewable_constraint[21,1] :               0.0
#               min_renewable_constraint[21,2] :               0.0
#               min_renewable_constraint[21,3] :               0.0
#               min_renewable_constraint[21,4] :               0.0
#               min_renewable_constraint[22,1] :               0.0
#               min_renewable_constraint[22,2] :               0.0
#               min_renewable_constraint[22,3] :               0.0
#               min_renewable_constraint[22,4] :               0.0
#               min_renewable_constraint[23,1] :               0.0
#               min_renewable_constraint[23,2] :               0.0
#               min_renewable_constraint[23,3] :               0.0
#               min_renewable_constraint[23,4] :               0.0
#               min_renewable_constraint[24,1] :               0.0
#               min_renewable_constraint[24,2] :               0.0
#               min_renewable_constraint[24,3] :               0.0
#               min_renewable_constraint[24,4] :               0.0
#               min_renewable_constraint[25,1] :               0.0
#               min_renewable_constraint[25,2] :               1.0
#               min_renewable_constraint[25,3] :               1.0
#               min_renewable_constraint[25,4] :               1.0
#                min_renewable_constraint[3,1] :               0.0
#                min_renewable_constraint[3,2] :               2.0
#                min_renewable_constraint[3,3] :               2.0
#                min_renewable_constraint[3,4] :               2.0
#                min_renewable_constraint[4,1] :              10.0
#                min_renewable_constraint[4,2] :               0.0
#                min_renewable_constraint[4,3] :              10.0
#                min_renewable_constraint[4,4] :              10.0
#                min_renewable_constraint[5,1] :               0.0
#                min_renewable_constraint[5,2] :               0.0
#                min_renewable_constraint[5,3] :               5.0
#                min_renewable_constraint[5,4] :               5.0
#                min_renewable_constraint[6,1] :               0.0
#                min_renewable_constraint[6,2] :               0.0
#                min_renewable_constraint[6,3] :               0.0
#                min_renewable_constraint[6,4] :               0.0
#                min_renewable_constraint[7,1] :               0.0
#                min_renewable_constraint[7,2] :               0.0
#                min_renewable_constraint[7,3] :               0.0
#                min_renewable_constraint[7,4] :               0.0
#                min_renewable_constraint[8,1] :               0.0
#                min_renewable_constraint[8,2] :               0.0
#                min_renewable_constraint[8,3] :               0.0
#                min_renewable_constraint[8,4] :               0.0
#                min_renewable_constraint[9,1] :               0.0
#                min_renewable_constraint[9,2] :               0.0
#                min_renewable_constraint[9,3] :               0.0
#                min_renewable_constraint[9,4] :               0.0

# %% [markdown]
# A more visually appealing way to present the results obtain from the dual.

# %%
# Displaying dual values
print("\nDual Values:")
for r in model.r:
    for t in model.t:
        print(f"\nRegion {r}, Time {t}:")
        print("   Demand Constraint Sensitivity:", model.dual[model.demand_constraint[r, t]])
        
        # Use the availability_constraint for each energy source
        for e in model.e:
            print(f"   {e.capitalize()} Availability Constraint Sensitivity:", model.dual[model.availability_constraint[e, r, t]])
        
        print("   Minimum Nuclear Production Constraint Sensitivity:", model.dual[model.min_nuclear_constraint[r, t]])
        print("   Minimum Renewable Production Constraint Sensitivity:", model.dual[model.min_renewable_constraint[r, t]])
        print("   Environmental Constraint Sensitivity:", model.dual[model.environmental_constraint[r, t]])
# Out:
# Dual Values:
#
# Region 1, Time 1:
#    Demand Constraint Sensitivity: 37.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -13.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -10.0
#    Geothermal Availability Constraint Sensitivity: -9.0
#    Minimum Nuclear Production Constraint Sensitivity: 11.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -65.675354569385
#
# Region 1, Time 2:
#    Demand Constraint Sensitivity: 37.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -13.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -10.0
#    Geothermal Availability Constraint Sensitivity: -9.0
#    Minimum Nuclear Production Constraint Sensitivity: 11.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -65.675354569385
#
# Region 1, Time 3:
#    Demand Constraint Sensitivity: 37.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -13.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -10.0
#    Geothermal Availability Constraint Sensitivity: -9.0
#    Minimum Nuclear Production Constraint Sensitivity: 11.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -65.675354569385
#
# Region 1, Time 4:
#    Demand Constraint Sensitivity: 37.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -13.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -10.0
#    Geothermal Availability Constraint Sensitivity: -9.0
#    Minimum Nuclear Production Constraint Sensitivity: 11.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -65.675354569385
#
# Region 2, Time 1:
#    Demand Constraint Sensitivity: 40.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -26.0
#    Fossil Availability Constraint Sensitivity: -5.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -7.0
#    Geothermal Availability Constraint Sensitivity: -11.0
#    Minimum Nuclear Production Constraint Sensitivity: 0.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -97.2530161546381
#
# Region 2, Time 2:
#    Demand Constraint Sensitivity: 35.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -21.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -2.0
#    Geothermal Availability Constraint Sensitivity: -6.0
#    Minimum Nuclear Production Constraint Sensitivity: 5.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -76.9919711224218
#
# Region 2, Time 3:
#    Demand Constraint Sensitivity: 35.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -21.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -2.0
#    Geothermal Availability Constraint Sensitivity: -6.0
#    Minimum Nuclear Production Constraint Sensitivity: 5.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -76.9919711224218
#
# Region 2, Time 4:
#    Demand Constraint Sensitivity: 35.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -21.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -2.0
#    Geothermal Availability Constraint Sensitivity: -6.0
#    Minimum Nuclear Production Constraint Sensitivity: 5.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -76.9919711224218
#
# Region 3, Time 1:
#    Demand Constraint Sensitivity: 34.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -13.0
#    Fossil Availability Constraint Sensitivity: -6.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: -4.0
#    Minimum Nuclear Production Constraint Sensitivity: 17.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -64.4725682446937
#
# Region 3, Time 2:
#    Demand Constraint Sensitivity: 28.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -9.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 23.0
#    Minimum Renewable Production Constraint Sensitivity: 2.0
#    Environmental Constraint Sensitivity: -48.3544261835202
#
# Region 3, Time 3:
#    Demand Constraint Sensitivity: 28.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -9.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 23.0
#    Minimum Renewable Production Constraint Sensitivity: 2.0
#    Environmental Constraint Sensitivity: -48.3544261835202
#
# Region 3, Time 4:
#    Demand Constraint Sensitivity: 28.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -9.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 23.0
#    Minimum Renewable Production Constraint Sensitivity: 2.0
#    Environmental Constraint Sensitivity: -48.3544261835202
#
# Region 4, Time 1:
#    Demand Constraint Sensitivity: 29.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -22.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -11.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 14.0
#    Minimum Renewable Production Constraint Sensitivity: 10.0
#    Environmental Constraint Sensitivity: -96.2505121839596
#
# Region 4, Time 2:
#    Demand Constraint Sensitivity: 39.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -22.0
#    Fossil Availability Constraint Sensitivity: -10.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -11.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 4.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -96.2505121839596
#
# Region 4, Time 3:
#    Demand Constraint Sensitivity: 29.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -22.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -11.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 14.0
#    Minimum Renewable Production Constraint Sensitivity: 10.0
#    Environmental Constraint Sensitivity: -96.2505121839596
#
# Region 4, Time 4:
#    Demand Constraint Sensitivity: 29.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -22.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -11.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 14.0
#    Minimum Renewable Production Constraint Sensitivity: 10.0
#    Environmental Constraint Sensitivity: -96.2505121839596
#
# Region 5, Time 1:
#    Demand Constraint Sensitivity: 31.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -12.0
#    Fossil Availability Constraint Sensitivity: -5.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 11.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -42.5639733857348
#
# Region 5, Time 2:
#    Demand Constraint Sensitivity: 31.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -12.0
#    Fossil Availability Constraint Sensitivity: -5.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 11.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -42.5639733857348
#
# Region 5, Time 3:
#    Demand Constraint Sensitivity: 26.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -12.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 16.0
#    Minimum Renewable Production Constraint Sensitivity: 5.0
#    Environmental Constraint Sensitivity: -42.5639733857348
#
# Region 5, Time 4:
#    Demand Constraint Sensitivity: 26.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -12.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 16.0
#    Minimum Renewable Production Constraint Sensitivity: 5.0
#    Environmental Constraint Sensitivity: -42.5639733857348
#
# Region 6, Time 1:
#    Demand Constraint Sensitivity: 38.0
#    Wind Availability Constraint Sensitivity: -22.0
#    Solar Availability Constraint Sensitivity: -15.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -11.0
#    Geothermal Availability Constraint Sensitivity: -12.0
#    Minimum Nuclear Production Constraint Sensitivity: 7.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 6, Time 2:
#    Demand Constraint Sensitivity: 38.0
#    Wind Availability Constraint Sensitivity: -22.0
#    Solar Availability Constraint Sensitivity: -15.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -11.0
#    Geothermal Availability Constraint Sensitivity: -12.0
#    Minimum Nuclear Production Constraint Sensitivity: 7.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 6, Time 3:
#    Demand Constraint Sensitivity: 38.0
#    Wind Availability Constraint Sensitivity: -22.0
#    Solar Availability Constraint Sensitivity: -15.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -11.0
#    Geothermal Availability Constraint Sensitivity: -12.0
#    Minimum Nuclear Production Constraint Sensitivity: 7.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 6, Time 4:
#    Demand Constraint Sensitivity: 38.0
#    Wind Availability Constraint Sensitivity: -22.0
#    Solar Availability Constraint Sensitivity: -15.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -11.0
#    Geothermal Availability Constraint Sensitivity: -12.0
#    Minimum Nuclear Production Constraint Sensitivity: 7.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 7, Time 1:
#    Demand Constraint Sensitivity: 40.0
#    Wind Availability Constraint Sensitivity: -20.0
#    Solar Availability Constraint Sensitivity: -25.0
#    Fossil Availability Constraint Sensitivity: -5.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -6.0
#    Geothermal Availability Constraint Sensitivity: -3.0
#    Minimum Nuclear Production Constraint Sensitivity: 0.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 7, Time 2:
#    Demand Constraint Sensitivity: 35.0
#    Wind Availability Constraint Sensitivity: -15.0
#    Solar Availability Constraint Sensitivity: -20.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -1.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 5.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 7, Time 3:
#    Demand Constraint Sensitivity: 35.0
#    Wind Availability Constraint Sensitivity: -15.0
#    Solar Availability Constraint Sensitivity: -20.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -1.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 5.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 7, Time 4:
#    Demand Constraint Sensitivity: 37.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -22.0
#    Fossil Availability Constraint Sensitivity: -2.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -3.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 3.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -124.549307819616
#
# Region 8, Time 1:
#    Demand Constraint Sensitivity: 34.0
#    Wind Availability Constraint Sensitivity: -14.0
#    Solar Availability Constraint Sensitivity: -22.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -1.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 22.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 8, Time 2:
#    Demand Constraint Sensitivity: 34.0
#    Wind Availability Constraint Sensitivity: -14.0
#    Solar Availability Constraint Sensitivity: -22.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -1.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 22.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 8, Time 3:
#    Demand Constraint Sensitivity: 34.0
#    Wind Availability Constraint Sensitivity: -14.0
#    Solar Availability Constraint Sensitivity: -22.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -1.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 22.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 8, Time 4:
#    Demand Constraint Sensitivity: 34.0
#    Wind Availability Constraint Sensitivity: -14.0
#    Solar Availability Constraint Sensitivity: -22.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -1.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 22.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 9, Time 1:
#    Demand Constraint Sensitivity: 30.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -19.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -5.0
#    Geothermal Availability Constraint Sensitivity: -5.0
#    Minimum Nuclear Production Constraint Sensitivity: 12.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -55.9074155754968
#
# Region 9, Time 2:
#    Demand Constraint Sensitivity: 30.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -19.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -5.0
#    Geothermal Availability Constraint Sensitivity: -5.0
#    Minimum Nuclear Production Constraint Sensitivity: 12.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -55.9074155754968
#
# Region 9, Time 3:
#    Demand Constraint Sensitivity: 30.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -19.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -5.0
#    Geothermal Availability Constraint Sensitivity: -5.0
#    Minimum Nuclear Production Constraint Sensitivity: 12.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -55.9074155754968
#
# Region 9, Time 4:
#    Demand Constraint Sensitivity: 30.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -19.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -5.0
#    Geothermal Availability Constraint Sensitivity: -5.0
#    Minimum Nuclear Production Constraint Sensitivity: 12.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -55.9074155754968
#
# Region 10, Time 1:
#    Demand Constraint Sensitivity: 36.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -20.0
#    Fossil Availability Constraint Sensitivity: -2.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -6.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 22.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -92.8001849862692
#
# Region 10, Time 2:
#    Demand Constraint Sensitivity: 34.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -20.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -6.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 24.0
#    Minimum Renewable Production Constraint Sensitivity: 2.0
#    Environmental Constraint Sensitivity: -92.8001849862692
#
# Region 10, Time 3:
#    Demand Constraint Sensitivity: 34.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -20.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -6.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 24.0
#    Minimum Renewable Production Constraint Sensitivity: 2.0
#    Environmental Constraint Sensitivity: -92.8001849862692
#
# Region 10, Time 4:
#    Demand Constraint Sensitivity: 34.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -20.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -6.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 24.0
#    Minimum Renewable Production Constraint Sensitivity: 2.0
#    Environmental Constraint Sensitivity: -92.8001849862692
#
# Region 11, Time 1:
#    Demand Constraint Sensitivity: 36.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -21.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -11.0
#    Geothermal Availability Constraint Sensitivity: -12.0
#    Minimum Nuclear Production Constraint Sensitivity: 6.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -82.0152977409272
#
# Region 11, Time 2:
#    Demand Constraint Sensitivity: 36.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -21.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -11.0
#    Geothermal Availability Constraint Sensitivity: -12.0
#    Minimum Nuclear Production Constraint Sensitivity: 6.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -82.0152977409272
#
# Region 11, Time 3:
#    Demand Constraint Sensitivity: 36.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -21.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -11.0
#    Geothermal Availability Constraint Sensitivity: -12.0
#    Minimum Nuclear Production Constraint Sensitivity: 6.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -82.0152977409272
#
# Region 11, Time 4:
#    Demand Constraint Sensitivity: 36.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -21.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -11.0
#    Geothermal Availability Constraint Sensitivity: -12.0
#    Minimum Nuclear Production Constraint Sensitivity: 6.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -82.0152977409272
#
# Region 12, Time 1:
#    Demand Constraint Sensitivity: 38.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -25.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -6.0
#    Geothermal Availability Constraint Sensitivity: -4.0
#    Minimum Nuclear Production Constraint Sensitivity: 10.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -89.1887234913031
#
# Region 12, Time 2:
#    Demand Constraint Sensitivity: 38.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -25.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -6.0
#    Geothermal Availability Constraint Sensitivity: -4.0
#    Minimum Nuclear Production Constraint Sensitivity: 10.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -89.1887234913031
#
# Region 12, Time 3:
#    Demand Constraint Sensitivity: 38.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -25.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -6.0
#    Geothermal Availability Constraint Sensitivity: -4.0
#    Minimum Nuclear Production Constraint Sensitivity: 10.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -89.1887234913031
#
# Region 12, Time 4:
#    Demand Constraint Sensitivity: 38.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -25.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -6.0
#    Geothermal Availability Constraint Sensitivity: -4.0
#    Minimum Nuclear Production Constraint Sensitivity: 10.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -89.1887234913031
#
# Region 13, Time 1:
#    Demand Constraint Sensitivity: 35.0
#    Wind Availability Constraint Sensitivity: -20.0
#    Solar Availability Constraint Sensitivity: -14.0
#    Fossil Availability Constraint Sensitivity: -3.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -9.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 22.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 13, Time 2:
#    Demand Constraint Sensitivity: 32.0
#    Wind Availability Constraint Sensitivity: -20.0
#    Solar Availability Constraint Sensitivity: -14.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -9.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 25.0
#    Minimum Renewable Production Constraint Sensitivity: 3.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 13, Time 3:
#    Demand Constraint Sensitivity: 32.0
#    Wind Availability Constraint Sensitivity: -17.0
#    Solar Availability Constraint Sensitivity: -11.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -6.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 25.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 13, Time 4:
#    Demand Constraint Sensitivity: 32.0
#    Wind Availability Constraint Sensitivity: -20.0
#    Solar Availability Constraint Sensitivity: -14.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -9.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 25.0
#    Minimum Renewable Production Constraint Sensitivity: 3.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 14, Time 1:
#    Demand Constraint Sensitivity: 40.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -29.0
#    Fossil Availability Constraint Sensitivity: -2.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -9.0
#    Geothermal Availability Constraint Sensitivity: -2.0
#    Minimum Nuclear Production Constraint Sensitivity: 0.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -79.9396988538795
#
# Region 14, Time 2:
#    Demand Constraint Sensitivity: 38.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -27.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -7.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 2.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -69.9472364971445
#
# Region 14, Time 3:
#    Demand Constraint Sensitivity: 38.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -27.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -7.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 2.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -69.9472364971445
#
# Region 14, Time 4:
#    Demand Constraint Sensitivity: 38.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -27.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -7.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 2.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -69.9472364971445
#
# Region 15, Time 1:
#    Demand Constraint Sensitivity: 33.0
#    Wind Availability Constraint Sensitivity: -13.0
#    Solar Availability Constraint Sensitivity: -18.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -7.0
#    Geothermal Availability Constraint Sensitivity: -11.0
#    Minimum Nuclear Production Constraint Sensitivity: 17.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 15, Time 2:
#    Demand Constraint Sensitivity: 33.0
#    Wind Availability Constraint Sensitivity: -13.0
#    Solar Availability Constraint Sensitivity: -18.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -7.0
#    Geothermal Availability Constraint Sensitivity: -11.0
#    Minimum Nuclear Production Constraint Sensitivity: 17.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 15, Time 3:
#    Demand Constraint Sensitivity: 26.0
#    Wind Availability Constraint Sensitivity: -6.0
#    Solar Availability Constraint Sensitivity: -11.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: -4.0
#    Minimum Nuclear Production Constraint Sensitivity: 24.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 15, Time 4:
#    Demand Constraint Sensitivity: 33.0
#    Wind Availability Constraint Sensitivity: -13.0
#    Solar Availability Constraint Sensitivity: -18.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -7.0
#    Geothermal Availability Constraint Sensitivity: -11.0
#    Minimum Nuclear Production Constraint Sensitivity: 17.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 16, Time 1:
#    Demand Constraint Sensitivity: 31.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -13.0
#    Fossil Availability Constraint Sensitivity: -4.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: -9.0
#    Minimum Nuclear Production Constraint Sensitivity: 9.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -73.1221132874616
#
# Region 16, Time 2:
#    Demand Constraint Sensitivity: 31.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -13.0
#    Fossil Availability Constraint Sensitivity: -4.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: -9.0
#    Minimum Nuclear Production Constraint Sensitivity: 9.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -73.1221132874616
#
# Region 16, Time 3:
#    Demand Constraint Sensitivity: 27.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -13.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: -9.0
#    Minimum Nuclear Production Constraint Sensitivity: 13.0
#    Minimum Renewable Production Constraint Sensitivity: 4.0
#    Environmental Constraint Sensitivity: -73.1221132874616
#
# Region 16, Time 4:
#    Demand Constraint Sensitivity: 27.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -9.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: -5.0
#    Minimum Nuclear Production Constraint Sensitivity: 13.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -50.6230015067041
#
# Region 17, Time 1:
#    Demand Constraint Sensitivity: 36.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -18.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -3.0
#    Geothermal Availability Constraint Sensitivity: -2.0
#    Minimum Nuclear Production Constraint Sensitivity: 22.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -109.325630058335
#
# Region 17, Time 2:
#    Demand Constraint Sensitivity: 36.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -18.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -3.0
#    Geothermal Availability Constraint Sensitivity: -2.0
#    Minimum Nuclear Production Constraint Sensitivity: 22.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -109.325630058335
#
# Region 17, Time 3:
#    Demand Constraint Sensitivity: 36.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -18.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -3.0
#    Geothermal Availability Constraint Sensitivity: -2.0
#    Minimum Nuclear Production Constraint Sensitivity: 22.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -109.325630058335
#
# Region 17, Time 4:
#    Demand Constraint Sensitivity: 36.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -18.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -3.0
#    Geothermal Availability Constraint Sensitivity: -2.0
#    Minimum Nuclear Production Constraint Sensitivity: 22.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -109.325630058335
#
# Region 18, Time 1:
#    Demand Constraint Sensitivity: 35.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -20.0
#    Fossil Availability Constraint Sensitivity: -2.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -10.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 10.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -63.8606970551089
#
# Region 18, Time 2:
#    Demand Constraint Sensitivity: 35.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -20.0
#    Fossil Availability Constraint Sensitivity: -2.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -10.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 10.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -63.8606970551089
#
# Region 18, Time 3:
#    Demand Constraint Sensitivity: 33.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -18.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -8.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 12.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -54.035974431246
#
# Region 18, Time 4:
#    Demand Constraint Sensitivity: 33.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -20.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -10.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 12.0
#    Minimum Renewable Production Constraint Sensitivity: 2.0
#    Environmental Constraint Sensitivity: -63.8606970551089
#
# Region 19, Time 1:
#    Demand Constraint Sensitivity: 33.0
#    Wind Availability Constraint Sensitivity: -12.0
#    Solar Availability Constraint Sensitivity: -10.0
#    Fossil Availability Constraint Sensitivity: -7.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: -6.0
#    Minimum Nuclear Production Constraint Sensitivity: 11.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 19, Time 2:
#    Demand Constraint Sensitivity: 26.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -4.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 18.0
#    Minimum Renewable Production Constraint Sensitivity: 1.0
#    Environmental Constraint Sensitivity: -42.3615459226678
#
# Region 19, Time 3:
#    Demand Constraint Sensitivity: 26.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -4.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 18.0
#    Minimum Renewable Production Constraint Sensitivity: 1.0
#    Environmental Constraint Sensitivity: -42.3615459226678
#
# Region 19, Time 4:
#    Demand Constraint Sensitivity: 26.0
#    Wind Availability Constraint Sensitivity: -6.0
#    Solar Availability Constraint Sensitivity: -4.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 18.0
#    Minimum Renewable Production Constraint Sensitivity: 1.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 20, Time 1:
#    Demand Constraint Sensitivity: 31.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -8.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: -6.0
#    Minimum Nuclear Production Constraint Sensitivity: 26.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -67.3076185010047
#
# Region 20, Time 2:
#    Demand Constraint Sensitivity: 31.0
#    Wind Availability Constraint Sensitivity: -11.0
#    Solar Availability Constraint Sensitivity: -8.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: -6.0
#    Minimum Nuclear Production Constraint Sensitivity: 26.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 20, Time 3:
#    Demand Constraint Sensitivity: 31.0
#    Wind Availability Constraint Sensitivity: -11.0
#    Solar Availability Constraint Sensitivity: -8.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: -6.0
#    Minimum Nuclear Production Constraint Sensitivity: 26.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 20, Time 4:
#    Demand Constraint Sensitivity: 31.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -8.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: -6.0
#    Minimum Nuclear Production Constraint Sensitivity: 26.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -67.3076185010047
#
# Region 21, Time 1:
#    Demand Constraint Sensitivity: 35.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -20.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -10.0
#    Geothermal Availability Constraint Sensitivity: -11.0
#    Minimum Nuclear Production Constraint Sensitivity: 17.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -76.0006125292939
#
# Region 21, Time 2:
#    Demand Constraint Sensitivity: 35.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -20.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -10.0
#    Geothermal Availability Constraint Sensitivity: -11.0
#    Minimum Nuclear Production Constraint Sensitivity: 17.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -76.0006125292939
#
# Region 21, Time 3:
#    Demand Constraint Sensitivity: 35.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -20.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -10.0
#    Geothermal Availability Constraint Sensitivity: -11.0
#    Minimum Nuclear Production Constraint Sensitivity: 17.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -76.0006125292939
#
# Region 21, Time 4:
#    Demand Constraint Sensitivity: 35.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -20.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -10.0
#    Geothermal Availability Constraint Sensitivity: -11.0
#    Minimum Nuclear Production Constraint Sensitivity: 17.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -76.0006125292939
#
# Region 22, Time 1:
#    Demand Constraint Sensitivity: 54.0
#    Wind Availability Constraint Sensitivity: -37.0
#    Solar Availability Constraint Sensitivity: -30.0
#    Fossil Availability Constraint Sensitivity: -29.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -29.0
#    Geothermal Availability Constraint Sensitivity: -20.0
#    Minimum Nuclear Production Constraint Sensitivity: 0.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 22, Time 2:
#    Demand Constraint Sensitivity: 54.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -30.0
#    Fossil Availability Constraint Sensitivity: -29.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -29.0
#    Geothermal Availability Constraint Sensitivity: -20.0
#    Minimum Nuclear Production Constraint Sensitivity: 0.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -241.839769837097
#
# Region 22, Time 3:
#    Demand Constraint Sensitivity: 25.0
#    Wind Availability Constraint Sensitivity: -8.0
#    Solar Availability Constraint Sensitivity: -1.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 29.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 22, Time 4:
#    Demand Constraint Sensitivity: 25.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -1.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 29.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -52.2896799647777
#
# Region 23, Time 1:
#    Demand Constraint Sensitivity: 36.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -22.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -3.0
#    Geothermal Availability Constraint Sensitivity: -1.0
#    Minimum Nuclear Production Constraint Sensitivity: 23.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -84.1768575037602
#
# Region 23, Time 2:
#    Demand Constraint Sensitivity: 36.0
#    Wind Availability Constraint Sensitivity: -13.0
#    Solar Availability Constraint Sensitivity: -22.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -3.0
#    Geothermal Availability Constraint Sensitivity: -1.0
#    Minimum Nuclear Production Constraint Sensitivity: 23.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 23, Time 3:
#    Demand Constraint Sensitivity: 36.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -22.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -3.0
#    Geothermal Availability Constraint Sensitivity: -1.0
#    Minimum Nuclear Production Constraint Sensitivity: 23.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -84.1768575037602
#
# Region 23, Time 4:
#    Demand Constraint Sensitivity: 36.0
#    Wind Availability Constraint Sensitivity: 0.0
#    Solar Availability Constraint Sensitivity: -22.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -3.0
#    Geothermal Availability Constraint Sensitivity: -1.0
#    Minimum Nuclear Production Constraint Sensitivity: 23.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: -84.1768575037602
#
# Region 24, Time 1:
#    Demand Constraint Sensitivity: 27.0
#    Wind Availability Constraint Sensitivity: -11.0
#    Solar Availability Constraint Sensitivity: -8.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 28.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 24, Time 2:
#    Demand Constraint Sensitivity: 27.0
#    Wind Availability Constraint Sensitivity: -11.0
#    Solar Availability Constraint Sensitivity: -8.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 28.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 24, Time 3:
#    Demand Constraint Sensitivity: 27.0
#    Wind Availability Constraint Sensitivity: -11.0
#    Solar Availability Constraint Sensitivity: -8.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 28.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 24, Time 4:
#    Demand Constraint Sensitivity: 27.0
#    Wind Availability Constraint Sensitivity: -11.0
#    Solar Availability Constraint Sensitivity: -8.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 28.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 25, Time 1:
#    Demand Constraint Sensitivity: 36.0
#    Wind Availability Constraint Sensitivity: -19.0
#    Solar Availability Constraint Sensitivity: -23.0
#    Fossil Availability Constraint Sensitivity: -7.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: -6.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 8.0
#    Minimum Renewable Production Constraint Sensitivity: 0.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 25, Time 2:
#    Demand Constraint Sensitivity: 29.0
#    Wind Availability Constraint Sensitivity: -13.0
#    Solar Availability Constraint Sensitivity: -17.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 15.0
#    Minimum Renewable Production Constraint Sensitivity: 1.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 25, Time 3:
#    Demand Constraint Sensitivity: 29.0
#    Wind Availability Constraint Sensitivity: -13.0
#    Solar Availability Constraint Sensitivity: -17.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 15.0
#    Minimum Renewable Production Constraint Sensitivity: 1.0
#    Environmental Constraint Sensitivity: 0.0
#
# Region 25, Time 4:
#    Demand Constraint Sensitivity: 29.0
#    Wind Availability Constraint Sensitivity: -13.0
#    Solar Availability Constraint Sensitivity: -17.0
#    Fossil Availability Constraint Sensitivity: 0.0
#    Nuclear Availability Constraint Sensitivity: 0.0
#    Hydro Availability Constraint Sensitivity: 0.0
#    Geothermal Availability Constraint Sensitivity: 0.0
#    Minimum Nuclear Production Constraint Sensitivity: 15.0
#    Minimum Renewable Production Constraint Sensitivity: 1.0
#    Environmental Constraint Sensitivity: 0.0

# %% [markdown]
# ## 3.2) Interpretation of the results
#
# We can interpret each of the sensitivities associated to each constraint in order to understand which impact does that constraint has at the moment of solving the model, as it can be expected, those constraints are related to parameters which are the ones with the true impact, the mix of constraints and parameters gives us the sensitivity in each constraint established.
#
# If we start talking demand constraint, we can see that the sensitivity for this constraint is around 25 and 55, this implies that there is a linear relationship between an increase in the demand constraint and an increase in the objective function. So, if there is a increase in the demand parameter by one unit, it would imply an increase in the objective function between 25 and 55 (the value would be according in this case, depending on the region and time period sensitivities). So we could say the model has a moderate sensitivity to an increase in the parameter demand.
#
# Continuing with the sensitivity for the minimum nuclear energy production constraint, the values that it takes are around 0 and 30, so we can see that for some decision variables, this constraint does not have any impact meanwhile in other ones it has a moderate impact. This implies that for instance, a decision variable which sensitivity with this constraint is 0, implies that an increase in the required minimum nuclear energy production will have no impact on the objective function, meanwhile for others with a positive number in this sensitivity, would imply an increase of the objective function, as it can be expected, this means that the model would obtain a worse result because the optimal solution without constraints would be to chose the most cheap energies as possible. This makes sense because in the visual representation we saw that the model solution was to produce in most of the cases only the 10% of the total demand as nuclear power to satisfy the constraint, so this makes sense that if we increase the requirement for nuclear energy production (for instace, from a 10% to a 20%), the objective function will increase, but we are interested in decreasing it.
#
# Refering to the sensitivity of the minimum production of renewable energies, we can see that almost every decision about this constraint is zero, so this indicates that with the current data, a change in this constraint will not make any significant difference, this does not means that this constraint is useless, it means that with the current data set and the characteristics of the problem, a change on the minimum requirement for renewable energies will not have any impact, but maybe if we change the data or the parameters, this could completely change. Probably in our case this constraint has zero sensitivity because the model even without this constraint is already using a high percentage of renewable energies to minimize the objective function, because we can see that some renewable energies are quite cheap.
#
# Talking about the enviromental limit constraint, we can see that its sensitivity its quite higher compared to any other constraint sensitivity, where some of this sensitivity constraint are zero but the majority are between -50 and -190, this obviusly implies that if we increase the environmetal limit (as we can see its the limit established in that constraint) the objective function would decrease in a very significant way, in this case, a reduction between -50 and -190 depending on the case, so we can extract from this information that this constraint has a huge impact on the model, however, as we mentioned during this assigment, we were interested in limiting the enviromental impact in order to see how the model tries to find the most optimal solution.
#
# Finally, the sensitivity for the availability constraint depending on the energy has zero value like the nuclear energy or negative values, for instance for the solar or wind energies. This is a clear indicative that there is a linear relation between the availability of each energy and the impact on decreasing the objective function. For some energies we can see that there is a significant sensitivity because the model would be able to decrease the objective function if we increase its availability, this makes sense taking into consideration that energies such as the solar has a low availability compared to other energies. Meanwhile energies that have a high availability such as fossil fuels, a change in the availability with respect to that energy would not imply a significant change in the objective function.
#
# To sum up, the sensitivity is a good indicator on to what extend a certain constraint associated with certain parameters is having a significant impact on the final model or not, in our case, some constraints such as the environmetal limit constraint which depends on the enviromental limit, has a big impact on the model, where if we increase the enviromental limit, the model would be able to decrease the objective function because they can be more relaxed about which energy has a higher or lower environmetal impact. But there are others such as the demand constraint that in the case we increase the demand parameter, would imply an increase in the demand and for that reason, an increase in the energy production required that would end up in increasing the objective function, almost the same as the availability for certain energies. There are other constraints that in the context of the current data set and situation, does not have a significant impact, but maybe in a different situation they would have, for instance, if we decreased the availability for the fossil, the availability for this energy imply a increase in the objective function.

# %% [markdown]
# # 4) Discrete modelling

# %% [markdown]
# ## 4.1) Introduction

# %% [markdown]
# In response to the ever-growing concerns about environmental sustainability and the need for efficient energy planning, the government of a forward-thinking country has embarked on a journey to revolutionize its energy sector. Recognizing the intricate balance between minimizing environmental impact, meeting energy demands, and ensuring operational feasibility, the government initially formulated a continuous optimization model. This initial model, with its emphasis on minimizing costs and adhering to strict environmental constraints, laid a robust foundation for sustainable energy planning.
#
# Building upon the success of the continuous model, the government has now taken a bold step forward by introducing a discrete optimization model. This evolution is motivated by a desire to infuse more nuanced decision-making into the energy production landscape. The introduction of binary variables and a penalty parameter represents a paradigm shift, allowing decision-makers to navigate a complex interplay of cost efficiency, environmental impact, and strategic energy source selection.
#
# The discrete model inherits the environmental constraints from its continuous predecessor, ensuring that the environmental impact remains a critical consideration. However, what sets this model apart is the incorporation of binary decision variables, such as the constraints enforcing mutual exclusivity which the main reason is to effectively use the limited amount of space in each region. Futhermore, goverment wants to limit the sources of production of energy, for this reason they are specifying a minimum and maximum sources where energy can be produced, that must be between 3 and 5, this involves a challenge, particularly the maximum of possible sources of production because in the continuous section, most of the times optimal solution was to use every source of energy.
# These additions enable the government to impose logical and operational constraints, reflecting real-world scenarios and necessities where energy production decisions are multifaceted and contingent on various factors that suppose a challenge at the practice.
#
# Furthermore, by relaxing the environmental limit in tandem with the number of energies used—limited to a maximum of five—the government seeks a balanced approach. The new model aims to strike a harmonious chord between minimizing costs, meeting energy demands, and responding to environmental imperatives. This evolution in the optimization model signifies a commitment to adaptability and responsiveness to the dynamic challenges faced by the energy sector, ultimately fostering a more resilient and sustainable future.

# %%
#Treshold for the enviromental impact limit in the whole country
total_env_limit = 2000
# Treshold for the environmental impact limit per region
environmental_limit = total_env_limit/25 #  total environmetal limit for the whole country divided by each region

# %% [markdown]
# ## 4.2) Define new model

# %% [markdown]
# ### 4.2.1) Reuse the continuous model

# %% [markdown]
# Before starting defining our new model, let's take only the things that we want to reuse from the previous one. <br>

# %%
########  Create Pyomo model  ########
model = ConcreteModel()


########  Initialize SETS  ########

regions = list(range(1, num_regions + 1))
time_periods = list(range(1, num_time_periods + 1))
energies = ["wind", "solar","fossil", "nuclear","hydro","geothermal"]

model.e = Set(initialize = energies, doc = 'energies')
model.r = Set(initialize = regions, doc = 'regions')
model.t = Set(initialize = time_periods, doc = 'time')



########  Declare PARAMETERS  ########
model.d  = Param(model.r, model.t, within=PositiveReals,
                 initialize=lambda model, r, t: sample_dataset[0]["demand"][r - 1, t - 1], mutable=True)

model.A = Param(model.e, model.r, model.t, within=NonNegativeReals,
                initialize=lambda model, e, r, t: sample_dataset[1][e][r - 1, t - 1], mutable=True)

model.E = Param(model.e, model.r, within=NonNegativeReals,
                initialize=lambda model, e
                , r: sample_dataset[2][e][r - 1], mutable=True)

model.C = Param(model.e, model.r, within=NonNegativeReals,
                initialize=lambda model, e, r: sample_dataset[3][e][r - 1], mutable=True)

# %% [markdown]
# For this discrete case, we are going to add a new parameter which is going to be a penalization parameter for using an energy, $P_{e}$. The goverment of the country has noticed due to several studies that some energies has a brigther future than others, for this reason, they are interested in adding a penalization for using a certain energy depending on how profitable and efficient they will be in the future, among other factors.
#
# For instance, the fossil energy prediction is awful, the planet is running out of fossil fuel reserves and probably in the near future, this type of energy will practically dissapear. On the other hand, several studies has confirmed that energies like the nuclear energy will have a promising future, the technological advances in order to obtain essential materials to produce this energy such as uranium are advancing and making this task much easier than years ago, also it produces a huge amount of energy and the enviromental impact should not be too high because the potential environmetal risk is in the case this radiactive materials gets into air. For this reasons, the goverment considered that nuclear energy is quite promising due to its potential massive production without requiring many space (nuclear centrals) and developing thanks to science advances.
#
# Other energies such as solar or wind energies are good energies but will face some problems in the future because they need a huge space to allocate all that wind turbines and solar pannels respectively, this is a significant problem taken into consideration the current and future need for space to construct. Furthermore this type of energies depends on the climatological factors, so they do not guarantee always a efficient production of energy.
#
# Talking about the hydro and geothermal energies, they share some important problems such as the dependency of geographical areas, because these type of energies cannot be produced in any place. Furthermore the risk of safety of infrastructures, such as dams in hydroelectric projects or geothermal facilities, can be a concern where ther can be potential risks of structural failure that could have serious consequences, but it is true that this possibility thanks to the advance of technology are practically imposible.
#
# For all these reasons, the goverment has established the following penalty paremeters for using certain energies:
#  Penalty = [1100, 50,2000, 10,430,750] where each element represents the penalization for the use of that respective energy. This penalty parameter was defined in the data set at the beginning.

# %%
model.P = Param(model.e, within=NonNegativeReals,
                initialize=lambda model, e: sample_dataset[4][e], mutable=True)

# %%
########  Define our CONTINUOUS DECISION VARIABLES  ########
model.X = Var(model.e, model.r, model.t, within=NonNegativeReals)

# %% [markdown]
# ### 4.2.2)  Define new variables

# %% [markdown]
# Now, we are going to define some binary variables:
#
# $Y_{e,r,t}$: which indicates whether energy *e* is chosen in region *r* at time *t*.

# %%
# New binary decision variables
model.Y = Var(model.e, model.r, model.t, within=Binary)

# %% [markdown]
# ##  4.3) Objective Function

# %% [markdown]
# The new objective function is a combination of two terms:
# - Original objective function: The original objective function encapsulates the inherent costs linked to energy production through continuous variables. This component quantifies the financial implications associated with the utilization of various energy sources.
# - A penalty expression: The penalty expression introduces a corrective measure to discourage the activation of binary variables in the optimization process. The magnitude of this penalty is contingent upon the product of the binary variable, denoted as model.$Y_{e,r,t}$, and the associated penalty parameter, denoted as $P_{e}$. The penalty term is appended to the overall objective to account for the binary decision variables.
#
# The overarching aim of the optimization process is to minimize this combined objective. By doing so, the optimization process endeavors to strike a harmonious equilibrium between minimizing the original cost incurred during energy production and imposing penalties for the activation of binary variables. This dual consideration reflects a nuanced approach that seeks to optimize the system while respecting the binary constraints imposed on the decision variables.

# %% [markdown]
# \begin{align}
# min \sum_{e\ \in \ energies}\sum_{r=1}^{25}\sum_{t=1}^4 ( C_{e,r}*X_{e,r,t}  +  P_{e}*Y_{e,r,t})
# \end{align}

# %%
# Objective function
model.obj = Objective(
    expr=sum(
        model.C[e,r] * model.X[e,r,t]
        for e in model.e for r in model.r for t in model.t
    ) 
    + sum((model.Y[e,r,t] * model.P[e]) for e in model.e for r in model.r for t in model.t ),
    sense=minimize,
)

# %% [markdown]
# ## 4.4) Constraints

# %% [markdown]
# ### 4.4.1) Old constraints
# In the incorporation of binary variables into the new optimization model, it is imperative to address existing constraints. The integration of binary decisions alters the system dynamics, necessitating a reassessment of previous constraints. Maintaining coherence ensures the preservation of essential relationships and prevents inadvertent oversights that may compromise the model's accuracy and reliability. Incorporating both old and new constraints is fundamental for a comprehensive and well-aligned optimization framework.

# %%
########  DEMAND CONSTRAINT  ########

# The production of energy must be at least equal or greater to the demand for a certain region and time period
def demand_constraint(model, r, t):
    # The production of all the energies must be at least equal to the demand for the region in that period of time
    value = sum(model.X[e, r, t] for e in model.e)
    return value >= model.d[r, t]

model.demand_constraint = Constraint(model.r, model.t, rule=demand_constraint)



########  AVAILABILITY CONSTRAINT  ########

# The production of energy must be less or equal to the availability of the energy at any region and time period
def availability_constraint(model,e,r,t):
    return model.X[e,r, t] <= model.A[e,r, t]

model.availability_constraint = Constraint(model.e, model.r, model.t, rule = availability_constraint)



########  ENVIRONMENTAL IMPACT CONSTRAINT  ########

# Ensure that the ecological impact from the production of energy does not surpass the limit established.
def environmental_constraint(model, r, t):
    # The summatory of the product between the environmental impact for each energy and the production of 
    # that energy must be at most equal to the environmental limit established by the government
    #value = sum([model.E[e, r] * model.X[e, r, t] for e in model.e])
    
    value = model.E["wind", r] * model.X["wind", r, t] 
    + model.E["solar", r] * model.X["solar", r, t]  
    + model.E["fossil", r] * model.X["fossil", r, t]
    + model.E["nuclear", r] * model.X["nuclear", r, t]  
    + model.E["hydro", r] * model.X["hydro", r, t]  
    + model.E["geothermal", r] * model.X["geothermal", r, t]
    return value <= environmental_limit

model.environmental_constraint = Constraint(model.r, model.t, rule=environmental_constraint)



########  MINIMUM RENEWABLE ENERGIES PRODUCTION CONSTRAINT  ########

def min_renewable_constraint(model,r,t):
    value =  model.X["wind",r, t] +  model.X["solar",r, t]  + model.X["hydro",r, t] + model.X["geothermal",r, t]
    return value >= 0.2 * model.d[r,t]

model.min_renewable_constraint = Constraint(model.r, model.t, rule = min_renewable_constraint)

# %% [markdown]
# ### 4.4.2) New constraints

# %% [markdown]
# **1) energy_selection_constraint:** <br> By using this constraint, you ensure that the continuous decision variable associated with each energy type, $X_{e,r,t}$  is activated only when the corresponding binary variable, $Y_{e,r,t}$  is set to 1 (indicating that the corresponding energy type is selected). In this case, $X_{e,r,t}$ is able to take any value since M is very large. <br>On the other hand, it is effectively deactivated (constrained to 0) when the binary variable is 0. Applying the "Big-M" method allows to linearize the relationship between binary and continuous variables in optimization problems. <br>
#
#
# <br>
# \begin{align}
# X_{e,r,t} ≤ M * Y_{e, r,t}  \qquad        {e\ \in \ energies},  {r\ \in \ regions},  {t\ \in \ time periods}
# \end{align}
# <br>

# %%
# Value M which we make sure it is going to be bigger than any variable.
M = 1000000000

def energy_selection_constraint(model,e, r, t):
    return model.X[e,r, t] <= M * model.Y[e, r, t]

# Apply the energy_constraint
model.energy_selection_constraint = Constraint(model.e, model.r, model.t, rule=energy_selection_constraint)

# %% [markdown]
# **2) max_energies_constraint:** <br>
#    The objective of this constraint is to limit, for each region *r* and at any time *t*, the usage of at most 5 types of energy as we saw in the continuous case that the energy was quite splitted and used in a diverse way. By summing the binary variables $Y_{e,r,t}$ for each energy source *e*, within a specific region and time period, the constraint ensures that the count does not exceed a specified threshold, in this case, 5. This constraint reflects a strategic choice to control and optimize the diversity of energy sources utilized, contributing to the model's adaptability and adherence to predefined limitations in the overall energy production system. <br>
#
#    \begin{align}
# \sum_{e\ \in \ energies}(Y_{e,r,t}) ≤ 5,  \qquad        {r\ \in \ regions}, {t\ \in \ time periods}
# \end{align}

# %%
def max_energies_constraint(model,r,t):
    # Select only one energy source for production in each region and time period
    return sum(model.Y[e, r, t] for e in model.e) <= 5

model.max_energies_constraint = Constraint(model.r, model.t, rule=max_energies_constraint)

# %% [markdown]
# An essential consideration in the implementation of the "max_energies_constraint" is the careful determination of the threshold based on the characteristics of the specific dataset being utilized. The significance of this lies in the fact that setting a threshold too restrictively, indicating a preference for fewer types of energies, must align with the actual availability of these energy sources. When the threshold is overly stringent, demanding the use of fewer energy types despite insufficient availability to meet the demand under the established constraints, it can result in an infeasible solution. Therefore, the selection of the threshold in the "max_energies_constraint" should be tailored to the dataset's unique properties, striking a balance that ensures both feasibility and adherence to the broader optimization goals.

# %% [markdown]
# **3) min_energies_constraint:** <br>
#     The objective of this constraint is to limit, for each region *r* and at any time *t*, the usage of at least 3 types of energy. <br>
#     Establishing a lower limit in the optimization model, is crucial for reflecting real-world scenarios where a minimum diversity in energy sources is essential. In practical energy systems, relying on a diverse set of energy sources enhances resilience, mitigates risk, and ensures a more sustainable and flexible infrastructure.

# %% [markdown]
#
#    \begin{align}
# \sum_{e\ \in \ energies}(Y_{e,r,t}) ≥ 3,  \qquad        {r\ \in \ regions}, {t\ \in \ time periods}
# \end{align}

# %%
def min_energies_constraint(model,r,t):
    # Select only one energy source for production in each region and time period
    return sum(model.Y[e, r, t] for e in model.e) >= 3

model.min_energies_constraint = Constraint(model.r, model.t, rule=min_energies_constraint)

# %% [markdown]
# **4) Mutual exclusivity constraint:** <br>
#
# The goverment has imposed another restriction related to some renewable energies, where they want to focus on only a few instead of producing from different sources that implies a big amount of space in order to be efficient, so they are mainly worried on the solar and wind energies. For this reason, they want that between those two energies, at maximum 1 of them can be produced for a certain region and period. In this way, they can ensure enough space to construct houses and factories and they can save that space to use either solar or wind energy. The model will need to chose between the high penalty of the wind energy or the low availability of the solar energy so we consider that could give us interesting results.

# %% [markdown]
#
# \begin{align}
# \sum_{ws\ \in \ WindSolar}(Y_{wg,r,t}) ≤ 1,  \qquad        {WindSolar\ =  ["Wind","Solar"]},\ {r\ \in \ regions}, {t\ \in \ time periods}
# \end{align}

# %%
# Mutual exclusivity between wind and solar
def mutual_exclusivity(model, r, t):
    return model.Y['wind', r, t] + model.Y['solar', r, t] <= 1

model.mutual_exclusivity_wind_solar_constraint = Constraint(model.r, model.t, rule=mutual_exclusivity)

# %% [markdown]
# **5) Minimum nuclear energy production:** <br>
#
# As in the first part, the goverment wants a minimum of nuclear energy production, but in this case, because we must have 5 or less sources of energy and at least 3, the goverment has decresed the percentage of the total demand to 7.5% only when the nuclear energy is chose between the 6 energies to be produced. In the case the nuclear energy is not choosen, there is not a minimum production requirement.
#
# \begin{align}
# X_{nuclear,r,t} ≥ 0.075 * d_{r,t},  \qquad \ only \ and \ only \ if \  Y_{nuclear,r,t} = 1    \\    {r\ \in \ regions}, {t\ \in \ time periods}
# \end{align}
# <br>

# %%
def min_nuclear_production(model, r, t):
    min_nuclear_percentage = 0.075 
    return sum(model.X['nuclear', r, t] for r in model.r for t in model.t) >= min_nuclear_percentage * sum(model.d[r, t] for r in model.r for t in model.t) * model.Y['nuclear', r, t]

model.min_nuclear_production_constraint = Constraint(model.r, model.t, rule=min_nuclear_production)

# %% [markdown]
# ## 4.5) Solve the model

# %%
# Solve the updated model
solver = SolverFactory('glpk')
solver.solve(model)

# Print objective value to compare with the previous part
print("Objective Value:", value(model.obj()))
# Display the results
model.display()
# Out:
# Objective Value: 5951725.212945889
# Model unknown
#
#   Variables:
#     X : Size=600, Index=X_index
#         Key                   : Lower : Value                : Upper : Fixed : Stale : Domain
#              ('fossil', 1, 1) :     0 :     911.032565775973 :  None : False : False : NonNegativeReals
#              ('fossil', 1, 2) :     0 :     917.546832317204 :  None : False : False : NonNegativeReals
#              ('fossil', 1, 3) :     0 :     462.192280402877 :  None : False : False : NonNegativeReals
#              ('fossil', 1, 4) :     0 :     867.866792094139 :  None : False : False : NonNegativeReals
#              ('fossil', 2, 1) :     0 :     738.204768643991 :  None : False : False : NonNegativeReals
#              ('fossil', 2, 2) :     0 :     873.668700328543 :  None : False : False : NonNegativeReals
#              ('fossil', 2, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#              ('fossil', 2, 4) :     0 :     622.775276088328 :  None : False : False : NonNegativeReals
#              ('fossil', 3, 1) :     0 :     885.438823938025 :  None : False : False : NonNegativeReals
#              ('fossil', 3, 2) :     0 :     918.828493075657 :  None : False : False : NonNegativeReals
#              ('fossil', 3, 3) :     0 :     810.300057945965 :  None : False : False : NonNegativeReals
#              ('fossil', 3, 4) :     0 :     872.028723804534 :  None : False : False : NonNegativeReals
#              ('fossil', 4, 1) :     0 :      987.04971348173 :  None : False : False : NonNegativeReals
#              ('fossil', 4, 2) :     0 :     746.417159472331 :  None : False : False : NonNegativeReals
#              ('fossil', 4, 3) :     0 :     742.458318795527 :  None : False : False : NonNegativeReals
#              ('fossil', 4, 4) :     0 :     856.175225849356 :  None : False : False : NonNegativeReals
#              ('fossil', 5, 1) :     0 :      714.32694779878 :  None : False : False : NonNegativeReals
#              ('fossil', 5, 2) :     0 :     805.180848115999 :  None : False : False : NonNegativeReals
#              ('fossil', 5, 3) :     0 :      843.28664440757 :  None : False : False : NonNegativeReals
#              ('fossil', 5, 4) :     0 :     830.381786865602 :  None : False : False : NonNegativeReals
#              ('fossil', 6, 1) :     0 :     818.989559957413 :  None : False : False : NonNegativeReals
#              ('fossil', 6, 2) :     0 :     984.399529463252 :  None : False : False : NonNegativeReals
#              ('fossil', 6, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#              ('fossil', 6, 4) :     0 :     749.453260530883 :  None : False : False : NonNegativeReals
#              ('fossil', 7, 1) :     0 :     741.022393254327 :  None : False : False : NonNegativeReals
#              ('fossil', 7, 2) :     0 :     974.611686139665 :  None : False : False : NonNegativeReals
#              ('fossil', 7, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#              ('fossil', 7, 4) :     0 :     727.027954786743 :  None : False : False : NonNegativeReals
#              ('fossil', 8, 1) :     0 :     763.634035450727 :  None : False : False : NonNegativeReals
#              ('fossil', 8, 2) :     0 :     882.353806399193 :  None : False : False : NonNegativeReals
#              ('fossil', 8, 3) :     0 :     867.766959739035 :  None : False : False : NonNegativeReals
#              ('fossil', 8, 4) :     0 :     809.739871916346 :  None : False : False : NonNegativeReals
#              ('fossil', 9, 1) :     0 :     734.884223189922 :  None : False : False : NonNegativeReals
#              ('fossil', 9, 2) :     0 :     852.896470170727 :  None : False : False : NonNegativeReals
#              ('fossil', 9, 3) :     0 :     465.059080776265 :  None : False : False : NonNegativeReals
#              ('fossil', 9, 4) :     0 :     839.304073896457 :  None : False : False : NonNegativeReals
#             ('fossil', 10, 1) :     0 :     806.789776263251 :  None : False : False : NonNegativeReals
#             ('fossil', 10, 2) :     0 :      1014.0567285333 :  None : False : False : NonNegativeReals
#             ('fossil', 10, 3) :     0 :     903.705364753477 :  None : False : False : NonNegativeReals
#             ('fossil', 10, 4) :     0 :      949.37234914126 :  None : False : False : NonNegativeReals
#             ('fossil', 11, 1) :     0 :     939.265416211716 :  None : False : False : NonNegativeReals
#             ('fossil', 11, 2) :     0 :     981.204111925171 :  None : False : False : NonNegativeReals
#             ('fossil', 11, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#             ('fossil', 11, 4) :     0 :     717.939218325353 :  None : False : False : NonNegativeReals
#             ('fossil', 12, 1) :     0 :     833.110419091635 :  None : False : False : NonNegativeReals
#             ('fossil', 12, 2) :     0 :     897.349789720488 :  None : False : False : NonNegativeReals
#             ('fossil', 12, 3) :     0 :     712.436749705327 :  None : False : False : NonNegativeReals
#             ('fossil', 12, 4) :     0 :     860.966579096792 :  None : False : False : NonNegativeReals
#             ('fossil', 13, 1) :     0 :     812.898711673201 :  None : False : False : NonNegativeReals
#             ('fossil', 13, 2) :     0 :     1044.37464726646 :  None : False : False : NonNegativeReals
#             ('fossil', 13, 3) :     0 :     901.483036438882 :  None : False : False : NonNegativeReals
#             ('fossil', 13, 4) :     0 :     920.404671916467 :  None : False : False : NonNegativeReals
#             ('fossil', 14, 1) :     0 :     840.354296729377 :  None : False : False : NonNegativeReals
#             ('fossil', 14, 2) :     0 :      881.28418177278 :  None : False : False : NonNegativeReals
#             ('fossil', 14, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#             ('fossil', 14, 4) :     0 :     732.677025810234 :  None : False : False : NonNegativeReals
#             ('fossil', 15, 1) :     0 :     763.312743145284 :  None : False : False : NonNegativeReals
#             ('fossil', 15, 2) :     0 :     758.840868524165 :  None : False : False : NonNegativeReals
#             ('fossil', 15, 3) :     0 :     329.265936441344 :  None : False : False : NonNegativeReals
#             ('fossil', 15, 4) :     0 :     540.106195514709 :  None : False : False : NonNegativeReals
#             ('fossil', 16, 1) :     0 :     852.637568880643 :  None : False : False : NonNegativeReals
#             ('fossil', 16, 2) :     0 :     803.855954268706 :  None : False : False : NonNegativeReals
#             ('fossil', 16, 3) :     0 :     837.747309052712 :  None : False : False : NonNegativeReals
#             ('fossil', 16, 4) :     0 :     993.328394820226 :  None : False : False : NonNegativeReals
#             ('fossil', 17, 1) :     0 :     928.074896377634 :  None : False : False : NonNegativeReals
#             ('fossil', 17, 2) :     0 :     863.047282949858 :  None : False : False : NonNegativeReals
#             ('fossil', 17, 3) :     0 :     482.837320982798 :  None : False : False : NonNegativeReals
#             ('fossil', 17, 4) :     0 :     617.937825634333 :  None : False : False : NonNegativeReals
#             ('fossil', 18, 1) :     0 :     977.272723979127 :  None : False : False : NonNegativeReals
#             ('fossil', 18, 2) :     0 :     792.875133379297 :  None : False : False : NonNegativeReals
#             ('fossil', 18, 3) :     0 :     966.853395887382 :  None : False : False : NonNegativeReals
#             ('fossil', 18, 4) :     0 :     987.957738329147 :  None : False : False : NonNegativeReals
#             ('fossil', 19, 1) :     0 :     823.547329645443 :  None : False : False : NonNegativeReals
#             ('fossil', 19, 2) :     0 :     1040.98119177248 :  None : False : False : NonNegativeReals
#             ('fossil', 19, 3) :     0 :     936.331674497631 :  None : False : False : NonNegativeReals
#             ('fossil', 19, 4) :     0 :     944.782876779029 :  None : False : False : NonNegativeReals
#             ('fossil', 20, 1) :     0 :     860.858923386166 :  None : False : False : NonNegativeReals
#             ('fossil', 20, 2) :     0 :     724.407221019806 :  None : False : False : NonNegativeReals
#             ('fossil', 20, 3) :     0 :     795.900064594711 :  None : False : False : NonNegativeReals
#             ('fossil', 20, 4) :     0 :     883.405482306104 :  None : False : False : NonNegativeReals
#             ('fossil', 21, 1) :     0 :     723.853404045993 :  None : False : False : NonNegativeReals
#             ('fossil', 21, 2) :     0 :     751.147963057258 :  None : False : False : NonNegativeReals
#             ('fossil', 21, 3) :     0 :     682.594444223871 :  None : False : False : NonNegativeReals
#             ('fossil', 21, 4) :     0 :     726.358351755877 :  None : False : False : NonNegativeReals
#             ('fossil', 22, 1) :     0 :     888.807839918245 :  None : False : False : NonNegativeReals
#             ('fossil', 22, 2) :     0 :     728.151470442922 :  None : False : False : NonNegativeReals
#             ('fossil', 22, 3) :     0 :     898.221357387958 :  None : False : False : NonNegativeReals
#             ('fossil', 22, 4) :     0 :     826.869718945954 :  None : False : False : NonNegativeReals
#             ('fossil', 23, 1) :     0 :     811.374774249595 :  None : False : False : NonNegativeReals
#             ('fossil', 23, 2) :     0 :     698.048224040116 :  None : False : False : NonNegativeReals
#             ('fossil', 23, 3) :     0 :     539.899343222529 :  None : False : False : NonNegativeReals
#             ('fossil', 23, 4) :     0 :     814.637701745283 :  None : False : False : NonNegativeReals
#             ('fossil', 24, 1) :     0 :      919.89852174306 :  None : False : False : NonNegativeReals
#             ('fossil', 24, 2) :     0 :      1038.6289656181 :  None : False : False : NonNegativeReals
#             ('fossil', 24, 3) :     0 :     798.496133322516 :  None : False : False : NonNegativeReals
#             ('fossil', 24, 4) :     0 :     786.238266187801 :  None : False : False : NonNegativeReals
#             ('fossil', 25, 1) :     0 :     727.131424073274 :  None : False : False : NonNegativeReals
#             ('fossil', 25, 2) :     0 :     1012.22642144994 :  None : False : False : NonNegativeReals
#             ('fossil', 25, 3) :     0 :     712.090756567737 :  None : False : False : NonNegativeReals
#             ('fossil', 25, 4) :     0 :     872.016309243611 :  None : False : False : NonNegativeReals
#          ('geothermal', 1, 1) :     0 :     531.880339830017 :  None : False : False : NonNegativeReals
#          ('geothermal', 1, 2) :     0 :     392.996302390614 :  None : False : False : NonNegativeReals
#          ('geothermal', 1, 3) :     0 :     523.416371221344 :  None : False : False : NonNegativeReals
#          ('geothermal', 1, 4) :     0 :     342.358449735908 :  None : False : False : NonNegativeReals
#          ('geothermal', 2, 1) :     0 :     467.647930394276 :  None : False : False : NonNegativeReals
#          ('geothermal', 2, 2) :     0 :     371.785280836698 :  None : False : False : NonNegativeReals
#          ('geothermal', 2, 3) :     0 :     527.658415806706 :  None : False : False : NonNegativeReals
#          ('geothermal', 2, 4) :     0 :     547.016591326751 :  None : False : False : NonNegativeReals
#          ('geothermal', 3, 1) :     0 :      331.60339442489 :  None : False : False : NonNegativeReals
#          ('geothermal', 3, 2) :     0 :     488.087527039028 :  None : False : False : NonNegativeReals
#          ('geothermal', 3, 3) :     0 :     434.102724382771 :  None : False : False : NonNegativeReals
#          ('geothermal', 3, 4) :     0 :     573.817356927496 :  None : False : False : NonNegativeReals
#          ('geothermal', 4, 1) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#          ('geothermal', 4, 2) :     0 :     216.925664401082 :  None : False : False : NonNegativeReals
#          ('geothermal', 4, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#          ('geothermal', 4, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#          ('geothermal', 5, 1) :     0 :     555.683492255821 :  None : False : False : NonNegativeReals
#          ('geothermal', 5, 2) :     0 :     572.280627476801 :  None : False : False : NonNegativeReals
#          ('geothermal', 5, 3) :     0 :     412.542361866763 :  None : False : False : NonNegativeReals
#          ('geothermal', 5, 4) :     0 :     383.851222997174 :  None : False : False : NonNegativeReals
#          ('geothermal', 6, 1) :     0 :     507.118840285386 :  None : False : False : NonNegativeReals
#          ('geothermal', 6, 2) :     0 :     303.892378644079 :  None : False : False : NonNegativeReals
#          ('geothermal', 6, 3) :     0 :     309.272836158708 :  None : False : False : NonNegativeReals
#          ('geothermal', 6, 4) :     0 :     315.700315492257 :  None : False : False : NonNegativeReals
#          ('geothermal', 7, 1) :     0 :     160.526542345574 :  None : False : False : NonNegativeReals
#          ('geothermal', 7, 2) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#          ('geothermal', 7, 3) :     0 :     378.180835796613 :  None : False : False : NonNegativeReals
#          ('geothermal', 7, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#          ('geothermal', 8, 1) :     0 :     586.875968719421 :  None : False : False : NonNegativeReals
#          ('geothermal', 8, 2) :     0 :      443.42147699279 :  None : False : False : NonNegativeReals
#          ('geothermal', 8, 3) :     0 :     565.347187970903 :  None : False : False : NonNegativeReals
#          ('geothermal', 8, 4) :     0 :     361.385137319145 :  None : False : False : NonNegativeReals
#          ('geothermal', 9, 1) :     0 :     506.426207412583 :  None : False : False : NonNegativeReals
#          ('geothermal', 9, 2) :     0 :     355.371403472664 :  None : False : False : NonNegativeReals
#          ('geothermal', 9, 3) :     0 :     470.901757871721 :  None : False : False : NonNegativeReals
#          ('geothermal', 9, 4) :     0 :     392.293284484095 :  None : False : False : NonNegativeReals
#         ('geothermal', 10, 1) :     0 :     555.881789528457 :  None : False : False : NonNegativeReals
#         ('geothermal', 10, 2) :     0 :     357.225680049175 :  None : False : False : NonNegativeReals
#         ('geothermal', 10, 3) :     0 :     205.891982599637 :  None : False : False : NonNegativeReals
#         ('geothermal', 10, 4) :     0 :     305.012964873785 :  None : False : False : NonNegativeReals
#         ('geothermal', 11, 1) :     0 :     407.585204096309 :  None : False : False : NonNegativeReals
#         ('geothermal', 11, 2) :     0 :     409.034957853876 :  None : False : False : NonNegativeReals
#         ('geothermal', 11, 3) :     0 :     541.039241661035 :  None : False : False : NonNegativeReals
#         ('geothermal', 11, 4) :     0 :     360.652315573616 :  None : False : False : NonNegativeReals
#         ('geothermal', 12, 1) :     0 :     578.808747315538 :  None : False : False : NonNegativeReals
#         ('geothermal', 12, 2) :     0 :     565.369706064565 :  None : False : False : NonNegativeReals
#         ('geothermal', 12, 3) :     0 :     407.117739752547 :  None : False : False : NonNegativeReals
#         ('geothermal', 12, 4) :     0 :     396.538819840039 :  None : False : False : NonNegativeReals
#         ('geothermal', 13, 1) :     0 :     338.101674290117 :  None : False : False : NonNegativeReals
#         ('geothermal', 13, 2) :     0 :     282.659296868813 :  None : False : False : NonNegativeReals
#         ('geothermal', 13, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#         ('geothermal', 13, 4) :     0 :     162.434687333198 :  None : False : False : NonNegativeReals
#         ('geothermal', 14, 1) :     0 :     3.74772748847977 :  None : False : False : NonNegativeReals
#         ('geothermal', 14, 2) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#         ('geothermal', 14, 3) :     0 :     407.421520903976 :  None : False : False : NonNegativeReals
#         ('geothermal', 14, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#         ('geothermal', 15, 1) :     0 :     568.690737260624 :  None : False : False : NonNegativeReals
#         ('geothermal', 15, 2) :     0 :     410.601837410709 :  None : False : False : NonNegativeReals
#         ('geothermal', 15, 3) :     0 :     561.429637411243 :  None : False : False : NonNegativeReals
#         ('geothermal', 15, 4) :     0 :      477.22516279257 :  None : False : False : NonNegativeReals
#         ('geothermal', 16, 1) :     0 :     531.018934827509 :  None : False : False : NonNegativeReals
#         ('geothermal', 16, 2) :     0 :     400.571491984538 :  None : False : False : NonNegativeReals
#         ('geothermal', 16, 3) :     0 :     340.259668878418 :  None : False : False : NonNegativeReals
#         ('geothermal', 16, 4) :     0 :      488.70198212104 :  None : False : False : NonNegativeReals
#         ('geothermal', 17, 1) :     0 :     365.525592428588 :  None : False : False : NonNegativeReals
#         ('geothermal', 17, 2) :     0 :     542.038387953776 :  None : False : False : NonNegativeReals
#         ('geothermal', 17, 3) :     0 :     436.306843769312 :  None : False : False : NonNegativeReals
#         ('geothermal', 17, 4) :     0 :     553.581419700431 :  None : False : False : NonNegativeReals
#         ('geothermal', 18, 1) :     0 :     306.706811597385 :  None : False : False : NonNegativeReals
#         ('geothermal', 18, 2) :     0 :     310.951895358207 :  None : False : False : NonNegativeReals
#         ('geothermal', 18, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#         ('geothermal', 18, 4) :     0 :     424.848873115736 :  None : False : False : NonNegativeReals
#         ('geothermal', 19, 1) :     0 :     519.844754583304 :  None : False : False : NonNegativeReals
#         ('geothermal', 19, 2) :     0 :     498.985499438229 :  None : False : False : NonNegativeReals
#         ('geothermal', 19, 3) :     0 :     308.996419034574 :  None : False : False : NonNegativeReals
#         ('geothermal', 19, 4) :     0 :     543.803658946032 :  None : False : False : NonNegativeReals
#         ('geothermal', 20, 1) :     0 :     518.664785746871 :  None : False : False : NonNegativeReals
#         ('geothermal', 20, 2) :     0 :      479.26046518768 :  None : False : False : NonNegativeReals
#         ('geothermal', 20, 3) :     0 :     495.797244711775 :  None : False : False : NonNegativeReals
#         ('geothermal', 20, 4) :     0 :     513.089404247834 :  None : False : False : NonNegativeReals
#         ('geothermal', 21, 1) :     0 :     496.038122958123 :  None : False : False : NonNegativeReals
#         ('geothermal', 21, 2) :     0 :      444.99333283501 :  None : False : False : NonNegativeReals
#         ('geothermal', 21, 3) :     0 :     432.112750482376 :  None : False : False : NonNegativeReals
#         ('geothermal', 21, 4) :     0 :     533.632834333241 :  None : False : False : NonNegativeReals
#         ('geothermal', 22, 1) :     0 :     300.959785374063 :  None : False : False : NonNegativeReals
#         ('geothermal', 22, 2) :     0 :     332.620623618228 :  None : False : False : NonNegativeReals
#         ('geothermal', 22, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#         ('geothermal', 22, 4) :     0 :     225.735912383381 :  None : False : False : NonNegativeReals
#         ('geothermal', 23, 1) :     0 :     337.545958815306 :  None : False : False : NonNegativeReals
#         ('geothermal', 23, 2) :     0 :       581.6366481569 :  None : False : False : NonNegativeReals
#         ('geothermal', 23, 3) :     0 :     532.352248332529 :  None : False : False : NonNegativeReals
#         ('geothermal', 23, 4) :     0 :     405.508829750144 :  None : False : False : NonNegativeReals
#         ('geothermal', 24, 1) :     0 :     419.378365330989 :  None : False : False : NonNegativeReals
#         ('geothermal', 24, 2) :     0 :     162.003014648442 :  None : False : False : NonNegativeReals
#         ('geothermal', 24, 3) :     0 :     110.629090500698 :  None : False : False : NonNegativeReals
#         ('geothermal', 24, 4) :     0 :     323.104621768217 :  None : False : False : NonNegativeReals
#         ('geothermal', 25, 1) :     0 :     352.273336725168 :  None : False : False : NonNegativeReals
#         ('geothermal', 25, 2) :     0 :     331.689166166953 :  None : False : False : NonNegativeReals
#         ('geothermal', 25, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#         ('geothermal', 25, 4) :     0 :     293.556976361473 :  None : False : False : NonNegativeReals
#               ('hydro', 1, 1) :     0 :     293.870559580723 :  None : False : False : NonNegativeReals
#               ('hydro', 1, 2) :     0 :     385.084216835823 :  None : False : False : NonNegativeReals
#               ('hydro', 1, 3) :     0 :     266.158330236902 :  None : False : False : NonNegativeReals
#               ('hydro', 1, 4) :     0 :      260.98840908617 :  None : False : False : NonNegativeReals
#               ('hydro', 2, 1) :     0 :     296.844500745686 :  None : False : False : NonNegativeReals
#               ('hydro', 2, 2) :     0 :     384.981337115544 :  None : False : False : NonNegativeReals
#               ('hydro', 2, 3) :     0 :     229.017853462646 :  None : False : False : NonNegativeReals
#               ('hydro', 2, 4) :     0 :     336.031412069461 :  None : False : False : NonNegativeReals
#               ('hydro', 3, 1) :     0 :     361.228722292331 :  None : False : False : NonNegativeReals
#               ('hydro', 3, 2) :     0 :     229.721138661847 :  None : False : False : NonNegativeReals
#               ('hydro', 3, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('hydro', 3, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('hydro', 4, 1) :     0 :     322.480266400655 :  None : False : False : NonNegativeReals
#               ('hydro', 4, 2) :     0 :     330.411391343695 :  None : False : False : NonNegativeReals
#               ('hydro', 4, 3) :     0 :     211.520643655438 :  None : False : False : NonNegativeReals
#               ('hydro', 4, 4) :     0 :     277.164490913764 :  None : False : False : NonNegativeReals
#               ('hydro', 5, 1) :     0 :     346.645805644214 :  None : False : False : NonNegativeReals
#               ('hydro', 5, 2) :     0 :     215.130300222516 :  None : False : False : NonNegativeReals
#               ('hydro', 5, 3) :     0 : 2.27373675443232e-13 :  None : False : False : NonNegativeReals
#               ('hydro', 5, 4) :     0 :     122.780420176547 :  None : False : False : NonNegativeReals
#               ('hydro', 6, 1) :     0 :     203.491340730905 :  None : False : False : NonNegativeReals
#               ('hydro', 6, 2) :     0 :     294.551878609074 :  None : False : False : NonNegativeReals
#               ('hydro', 6, 3) :     0 :     368.820530834343 :  None : False : False : NonNegativeReals
#               ('hydro', 6, 4) :     0 :     377.419618403193 :  None : False : False : NonNegativeReals
#               ('hydro', 7, 1) :     0 :     260.126206833112 :  None : False : False : NonNegativeReals
#               ('hydro', 7, 2) :     0 :     387.753200334779 :  None : False : False : NonNegativeReals
#               ('hydro', 7, 3) :     0 :      317.66483527493 :  None : False : False : NonNegativeReals
#               ('hydro', 7, 4) :     0 :     219.742953807974 :  None : False : False : NonNegativeReals
#               ('hydro', 8, 1) :     0 :     219.268505153205 :  None : False : False : NonNegativeReals
#               ('hydro', 8, 2) :     0 :     313.122209704638 :  None : False : False : NonNegativeReals
#               ('hydro', 8, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('hydro', 8, 4) :     0 :      227.82150584979 :  None : False : False : NonNegativeReals
#               ('hydro', 9, 1) :     0 :     274.494835896921 :  None : False : False : NonNegativeReals
#               ('hydro', 9, 2) :     0 :      397.68649204586 :  None : False : False : NonNegativeReals
#               ('hydro', 9, 3) :     0 :     380.562273915807 :  None : False : False : NonNegativeReals
#               ('hydro', 9, 4) :     0 :     270.194814220467 :  None : False : False : NonNegativeReals
#              ('hydro', 10, 1) :     0 :     297.686428817684 :  None : False : False : NonNegativeReals
#              ('hydro', 10, 2) :     0 :     321.194866214991 :  None : False : False : NonNegativeReals
#              ('hydro', 10, 3) :     0 :     201.426917679802 :  None : False : False : NonNegativeReals
#              ('hydro', 10, 4) :     0 :     212.535087783873 :  None : False : False : NonNegativeReals
#              ('hydro', 11, 1) :     0 :     331.344544923527 :  None : False : False : NonNegativeReals
#              ('hydro', 11, 2) :     0 :     231.824001236835 :  None : False : False : NonNegativeReals
#              ('hydro', 11, 3) :     0 :     382.012125737297 :  None : False : False : NonNegativeReals
#              ('hydro', 11, 4) :     0 :       279.0196798255 :  None : False : False : NonNegativeReals
#              ('hydro', 12, 1) :     0 :     293.881452642544 :  None : False : False : NonNegativeReals
#              ('hydro', 12, 2) :     0 :     321.932897780628 :  None : False : False : NonNegativeReals
#              ('hydro', 12, 3) :     0 :     364.263269094999 :  None : False : False : NonNegativeReals
#              ('hydro', 12, 4) :     0 :     296.225201565256 :  None : False : False : NonNegativeReals
#              ('hydro', 13, 1) :     0 :     249.377473045856 :  None : False : False : NonNegativeReals
#              ('hydro', 13, 2) :     0 :     280.469411275655 :  None : False : False : NonNegativeReals
#              ('hydro', 13, 3) :     0 :     240.905344686826 :  None : False : False : NonNegativeReals
#              ('hydro', 13, 4) :     0 :     354.127012439907 :  None : False : False : NonNegativeReals
#              ('hydro', 14, 1) :     0 :     223.790870029751 :  None : False : False : NonNegativeReals
#              ('hydro', 14, 2) :     0 :     396.895209310626 :  None : False : False : NonNegativeReals
#              ('hydro', 14, 3) :     0 :     251.313042200772 :  None : False : False : NonNegativeReals
#              ('hydro', 14, 4) :     0 :     279.208654686091 :  None : False : False : NonNegativeReals
#              ('hydro', 15, 1) :     0 :     328.090839501357 :  None : False : False : NonNegativeReals
#              ('hydro', 15, 2) :     0 :     320.990826187906 :  None : False : False : NonNegativeReals
#              ('hydro', 15, 3) :     0 :     381.410104096854 :  None : False : False : NonNegativeReals
#              ('hydro', 15, 4) :     0 :     391.680290767286 :  None : False : False : NonNegativeReals
#              ('hydro', 16, 1) :     0 :     310.307610092609 :  None : False : False : NonNegativeReals
#              ('hydro', 16, 2) :     0 :     274.977258980588 :  None : False : False : NonNegativeReals
#              ('hydro', 16, 3) :     0 :     123.609352621322 :  None : False : False : NonNegativeReals
#              ('hydro', 16, 4) :     0 :     119.149150457352 :  None : False : False : NonNegativeReals
#              ('hydro', 17, 1) :     0 :     220.090144348815 :  None : False : False : NonNegativeReals
#              ('hydro', 17, 2) :     0 :     210.937389332952 :  None : False : False : NonNegativeReals
#              ('hydro', 17, 3) :     0 :     383.018233892464 :  None : False : False : NonNegativeReals
#              ('hydro', 17, 4) :     0 :     307.170347946735 :  None : False : False : NonNegativeReals
#              ('hydro', 18, 1) :     0 :     241.080283067088 :  None : False : False : NonNegativeReals
#              ('hydro', 18, 2) :     0 :     313.379710094762 :  None : False : False : NonNegativeReals
#              ('hydro', 18, 3) :     0 :     391.381805072879 :  None : False : False : NonNegativeReals
#              ('hydro', 18, 4) :     0 :     249.656378940513 :  None : False : False : NonNegativeReals
#              ('hydro', 19, 1) :     0 :     322.807307736747 :  None : False : False : NonNegativeReals
#              ('hydro', 19, 2) :     0 :     82.1170985365292 :  None : False : False : NonNegativeReals
#              ('hydro', 19, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#              ('hydro', 19, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#              ('hydro', 20, 1) :     0 :     200.456898245449 :  None : False : False : NonNegativeReals
#              ('hydro', 20, 2) :     0 :     237.180794775608 :  None : False : False : NonNegativeReals
#              ('hydro', 20, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#              ('hydro', 20, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#              ('hydro', 21, 1) :     0 :     256.436158596683 :  None : False : False : NonNegativeReals
#              ('hydro', 21, 2) :     0 :     277.809735261654 :  None : False : False : NonNegativeReals
#              ('hydro', 21, 3) :     0 :     313.871931649171 :  None : False : False : NonNegativeReals
#              ('hydro', 21, 4) :     0 :     312.869285364198 :  None : False : False : NonNegativeReals
#              ('hydro', 22, 1) :     0 :     236.957289863086 :  None : False : False : NonNegativeReals
#              ('hydro', 22, 2) :     0 :     221.207050757927 :  None : False : False : NonNegativeReals
#              ('hydro', 22, 3) :     0 :     348.002784144301 :  None : False : False : NonNegativeReals
#              ('hydro', 22, 4) :     0 :     359.913867553868 :  None : False : False : NonNegativeReals
#              ('hydro', 23, 1) :     0 :     362.776804710191 :  None : False : False : NonNegativeReals
#              ('hydro', 23, 2) :     0 :     397.214890161299 :  None : False : False : NonNegativeReals
#              ('hydro', 23, 3) :     0 :     354.955588736603 :  None : False : False : NonNegativeReals
#              ('hydro', 23, 4) :     0 :     356.252921993805 :  None : False : False : NonNegativeReals
#              ('hydro', 24, 1) :     0 :     375.774375375544 :  None : False : False : NonNegativeReals
#              ('hydro', 24, 2) :     0 :     372.575474983493 :  None : False : False : NonNegativeReals
#              ('hydro', 24, 3) :     0 :     281.962108399945 :  None : False : False : NonNegativeReals
#              ('hydro', 24, 4) :     0 :     260.799896601412 :  None : False : False : NonNegativeReals
#              ('hydro', 25, 1) :     0 :      396.11328885463 :  None : False : False : NonNegativeReals
#              ('hydro', 25, 2) :     0 :     368.178354710059 :  None : False : False : NonNegativeReals
#              ('hydro', 25, 3) :     0 :     355.914310507586 :  None : False : False : NonNegativeReals
#              ('hydro', 25, 4) :     0 :     335.105962218827 :  None : False : False : NonNegativeReals
#             ('nuclear', 1, 1) :     0 :     57.1908170068799 :  None : False : False : NonNegativeReals
#             ('nuclear', 1, 2) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#             ('nuclear', 1, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#             ('nuclear', 1, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#             ('nuclear', 2, 1) :     0 :     330.126079700587 :  None : False : False : NonNegativeReals
#             ('nuclear', 2, 2) :     0 :      67.387961203755 :  None : False : False : NonNegativeReals
#             ('nuclear', 2, 3) :     0 :     556.147010215188 :  None : False : False : NonNegativeReals
#             ('nuclear', 2, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#             ('nuclear', 3, 1) :     0 :     189.366218121286 :  None : False : False : NonNegativeReals
#             ('nuclear', 3, 2) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#             ('nuclear', 3, 3) :     0 :      19.234376447796 :  None : False : False : NonNegativeReals
#             ('nuclear', 3, 4) :     0 :     4.79107804450103 :  None : False : False : NonNegativeReals
#             ('nuclear', 4, 1) :     0 :     449.801402273959 :  None : False : False : NonNegativeReals
#             ('nuclear', 4, 2) :     0 :     332.577166939236 :  None : False : False : NonNegativeReals
#             ('nuclear', 4, 3) :     0 :     292.352419705379 :  None : False : False : NonNegativeReals
#             ('nuclear', 4, 4) :     0 :     366.862087732585 :  None : False : False : NonNegativeReals
#             ('nuclear', 5, 1) :     0 :     120.848089844901 :  None : False : False : NonNegativeReals
#             ('nuclear', 5, 2) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#             ('nuclear', 5, 3) :     0 :     22.9299682191609 :  None : False : False : NonNegativeReals
#             ('nuclear', 5, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#             ('nuclear', 6, 1) :     0 :     204.362388549611 :  None : False : False : NonNegativeReals
#             ('nuclear', 6, 2) :     0 :     24.8158889233442 :  None : False : False : NonNegativeReals
#             ('nuclear', 6, 3) :     0 :     571.730295480332 :  None : False : False : NonNegativeReals
#             ('nuclear', 6, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#             ('nuclear', 7, 1) :     0 :     616.481788285097 :  None : False : False : NonNegativeReals
#             ('nuclear', 7, 2) :     0 :     375.168129599879 :  None : False : False : NonNegativeReals
#             ('nuclear', 7, 3) :     0 :     574.423450296071 :  None : False : False : NonNegativeReals
#             ('nuclear', 7, 4) :     0 :     495.902800062973 :  None : False : False : NonNegativeReals
#             ('nuclear', 8, 1) :     0 :     192.551623302305 :  None : False : False : NonNegativeReals
#             ('nuclear', 8, 2) :     0 :     69.2096116794079 :  None : False : False : NonNegativeReals
#             ('nuclear', 8, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#             ('nuclear', 8, 4) :     0 :     104.769891916121 :  None : False : False : NonNegativeReals
#             ('nuclear', 9, 1) :     0 :     220.508667221092 :  None : False : False : NonNegativeReals
#             ('nuclear', 9, 2) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#             ('nuclear', 9, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#             ('nuclear', 9, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 10, 1) :     0 :     135.371711957337 :  None : False : False : NonNegativeReals
#            ('nuclear', 10, 2) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 10, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 10, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 11, 1) :     0 :       95.87763412227 :  None : False : False : NonNegativeReals
#            ('nuclear', 11, 2) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 11, 3) :     0 :     376.168250422629 :  None : False : False : NonNegativeReals
#            ('nuclear', 11, 4) :     0 :     113.713994589805 :  None : False : False : NonNegativeReals
#            ('nuclear', 12, 1) :     0 :     124.371250179111 :  None : False : False : NonNegativeReals
#            ('nuclear', 12, 2) :     0 :     16.4093372875761 :  None : False : False : NonNegativeReals
#            ('nuclear', 12, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 12, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 13, 1) :     0 :     351.084874912835 :  None : False : False : NonNegativeReals
#            ('nuclear', 13, 2) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 13, 3) :     0 :     38.5007092903759 :  None : False : False : NonNegativeReals
#            ('nuclear', 13, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 14, 1) :     0 :     680.675485532702 :  None : False : False : NonNegativeReals
#            ('nuclear', 14, 2) :     0 :     521.097108558066 :  None : False : False : NonNegativeReals
#            ('nuclear', 14, 3) :     0 :     745.136843213277 :  None : False : False : NonNegativeReals
#            ('nuclear', 14, 4) :     0 :     530.345695526686 :  None : False : False : NonNegativeReals
#            ('nuclear', 15, 1) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 15, 2) :     0 :     34.1374758918025 :  None : False : False : NonNegativeReals
#            ('nuclear', 15, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 15, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 16, 1) :     0 :      166.31545442516 :  None : False : False : NonNegativeReals
#            ('nuclear', 16, 2) :     0 :      265.51597490682 :  None : False : False : NonNegativeReals
#            ('nuclear', 16, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 16, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 17, 1) :     0 :     275.143895103428 :  None : False : False : NonNegativeReals
#            ('nuclear', 17, 2) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 17, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 17, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 18, 1) :     0 :     377.514449149194 :  None : False : False : NonNegativeReals
#            ('nuclear', 18, 2) :     0 :     365.537617610086 :  None : False : False : NonNegativeReals
#            ('nuclear', 18, 3) :     0 :      70.659615152864 :  None : False : False : NonNegativeReals
#            ('nuclear', 18, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 19, 1) :     0 :     104.783136603172 :  None : False : False : NonNegativeReals
#            ('nuclear', 19, 2) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 19, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 19, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 20, 1) :     0 :     159.217140833621 :  None : False : False : NonNegativeReals
#            ('nuclear', 20, 2) :     0 :     225.386717519762 :  None : False : False : NonNegativeReals
#            ('nuclear', 20, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 20, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 21, 1) :     0 :     394.413554037174 :  None : False : False : NonNegativeReals
#            ('nuclear', 21, 2) :     0 :     211.772202902867 :  None : False : False : NonNegativeReals
#            ('nuclear', 21, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 21, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 22, 1) :     0 :     394.332711489408 :  None : False : False : NonNegativeReals
#            ('nuclear', 22, 2) :     0 :     353.816482994032 :  None : False : False : NonNegativeReals
#            ('nuclear', 22, 3) :     0 :     41.7511080779155 :  None : False : False : NonNegativeReals
#            ('nuclear', 22, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 23, 1) :     0 :     234.278619784686 :  None : False : False : NonNegativeReals
#            ('nuclear', 23, 2) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 23, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 23, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 24, 1) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 24, 2) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 24, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 24, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 25, 1) :     0 :     260.682704699503 :  None : False : False : NonNegativeReals
#            ('nuclear', 25, 2) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#            ('nuclear', 25, 3) :     0 :     161.149032454383 :  None : False : False : NonNegativeReals
#            ('nuclear', 25, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 1, 1) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 1, 2) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 1, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 1, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 2, 1) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 2, 2) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 2, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 2, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 3, 1) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 3, 2) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 3, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 3, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 4, 1) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 4, 2) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 4, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 4, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 5, 1) :     0 :     297.495664456285 :  None : False : False : NonNegativeReals
#               ('solar', 5, 2) :     0 : 3.08002962473689e-14 :  None : False : False : NonNegativeReals
#               ('solar', 5, 3) :     0 :     265.241025506505 :  None : False : False : NonNegativeReals
#               ('solar', 5, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 6, 1) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 6, 2) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 6, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 6, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 7, 1) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 7, 2) :     0 :     263.466983925677 :  None : False : False : NonNegativeReals
#               ('solar', 7, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 7, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 8, 1) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 8, 2) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 8, 3) :     0 :     201.885852290063 :  None : False : False : NonNegativeReals
#               ('solar', 8, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 9, 1) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 9, 2) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#               ('solar', 9, 3) :     0 :     261.476887436208 :  None : False : False : NonNegativeReals
#               ('solar', 9, 4) :     0 :     262.207827398981 :  None : False : False : NonNegativeReals
#              ('solar', 10, 1) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#              ('solar', 10, 2) :     0 :     298.522725202533 :  None : False : False : NonNegativeReals
#              ('solar', 10, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#              ('solar', 10, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#              ('solar', 11, 1) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#              ('solar', 11, 2) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#              ('solar', 11, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#              ('solar', 11, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#              ('solar', 12, 1) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#              ('solar', 12, 2) :     0 :     220.938269146743 :  None : False : False : NonNegativeReals
#              ('solar', 12, 3) :     0 :     153.182241447127 :  None : False : False : NonNegativeReals
#              ('solar', 12, 4) :     0 :     276.269399497913 :  None : False : False : NonNegativeReals
#              ('solar', 13, 1) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#              ('solar', 13, 2) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#              ('solar', 13, 3) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#              ('solar', 13, 4) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#              ('solar', 14, 1) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#              ('solar', 14, 2) :     0 :     167.723500358528 :  None : False : False : NonNegativeReals
#              ('solar', 14, 3) :     0 :     188.128593681975 :  None : False : False : NonNegativeReals
#              ('solar', 14, 4) :     0 :     236.768623976989 :  None : False : False : NonNegativeReals
#              ('solar', 15, 1) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#              ('solar', 15, 2) :     0 :                  0.0 :  None : False : False : NonNegativeReals
#              ('solar', 15, 3) :     0 :     284.894322050558 :  None : False : False : NonNegativeReals
# ...
#         (12, 1) :  None :  5.0 :   5.0
#         (12, 2) :  None :  5.0 :   5.0
#         (12, 3) :  None :  4.0 :   5.0
#         (12, 4) :  None :  4.0 :   5.0
#         (13, 1) :  None :  5.0 :   5.0
#         (13, 2) :  None :  4.0 :   5.0
#         (13, 3) :  None :  4.0 :   5.0
#         (13, 4) :  None :  4.0 :   5.0
#         (14, 1) :  None :  5.0 :   5.0
#         (14, 2) :  None :  4.0 :   5.0
#         (14, 3) :  None :  4.0 :   5.0
#         (14, 4) :  None :  4.0 :   5.0
#         (15, 1) :  None :  4.0 :   5.0
#         (15, 2) :  None :  5.0 :   5.0
#         (15, 3) :  None :  4.0 :   5.0
#         (15, 4) :  None :  4.0 :   5.0
#         (16, 1) :  None :  5.0 :   5.0
#         (16, 2) :  None :  5.0 :   5.0
#         (16, 3) :  None :  4.0 :   5.0
#         (16, 4) :  None :  4.0 :   5.0
#         (17, 1) :  None :  5.0 :   5.0
#         (17, 2) :  None :  4.0 :   5.0
#         (17, 3) :  None :  4.0 :   5.0
#         (17, 4) :  None :  4.0 :   5.0
#         (18, 1) :  None :  5.0 :   5.0
#         (18, 2) :  None :  5.0 :   5.0
#         (18, 3) :  None :  4.0 :   5.0
#         (18, 4) :  None :  4.0 :   5.0
#         (19, 1) :  None :  5.0 :   5.0
#         (19, 2) :  None :  4.0 :   5.0
#         (19, 3) :  None :  3.0 :   5.0
#         (19, 4) :  None :  3.0 :   5.0
#         (20, 1) :  None :  5.0 :   5.0
#         (20, 2) :  None :  5.0 :   5.0
#         (20, 3) :  None :  3.0 :   5.0
#         (20, 4) :  None :  3.0 :   5.0
#         (21, 1) :  None :  5.0 :   5.0
#         (21, 2) :  None :  5.0 :   5.0
#         (21, 3) :  None :  4.0 :   5.0
#         (21, 4) :  None :  4.0 :   5.0
#         (22, 1) :  None :  5.0 :   5.0
#         (22, 2) :  None :  5.0 :   5.0
#         (22, 3) :  None :  4.0 :   5.0
#         (22, 4) :  None :  4.0 :   5.0
#         (23, 1) :  None :  5.0 :   5.0
#         (23, 2) :  None :  4.0 :   5.0
#         (23, 3) :  None :  4.0 :   5.0
#         (23, 4) :  None :  4.0 :   5.0
#         (24, 1) :  None :  4.0 :   5.0
#         (24, 2) :  None :  4.0 :   5.0
#         (24, 3) :  None :  4.0 :   5.0
#         (24, 4) :  None :  4.0 :   5.0
#         (25, 1) :  None :  5.0 :   5.0
#         (25, 2) :  None :  4.0 :   5.0
#         (25, 3) :  None :  4.0 :   5.0
#         (25, 4) :  None :  4.0 :   5.0
#     min_energies_constraint : Size=100
#         Key     : Lower : Body : Upper
#          (1, 1) :   3.0 :  5.0 :  None
#          (1, 2) :   3.0 :  4.0 :  None
#          (1, 3) :   3.0 :  4.0 :  None
#          (1, 4) :   3.0 :  4.0 :  None
#          (2, 1) :   3.0 :  5.0 :  None
#          (2, 2) :   3.0 :  5.0 :  None
#          (2, 3) :   3.0 :  4.0 :  None
#          (2, 4) :   3.0 :  4.0 :  None
#          (3, 1) :   3.0 :  5.0 :  None
#          (3, 2) :   3.0 :  4.0 :  None
#          (3, 3) :   3.0 :  4.0 :  None
#          (3, 4) :   3.0 :  4.0 :  None
#          (4, 1) :   3.0 :  4.0 :  None
#          (4, 2) :   3.0 :  5.0 :  None
#          (4, 3) :   3.0 :  4.0 :  None
#          (4, 4) :   3.0 :  4.0 :  None
#          (5, 1) :   3.0 :  5.0 :  None
#          (5, 2) :   3.0 :  4.0 :  None
#          (5, 3) :   3.0 :  4.0 :  None
#          (5, 4) :   3.0 :  4.0 :  None
#          (6, 1) :   3.0 :  5.0 :  None
#          (6, 2) :   3.0 :  5.0 :  None
#          (6, 3) :   3.0 :  4.0 :  None
#          (6, 4) :   3.0 :  4.0 :  None
#          (7, 1) :   3.0 :  5.0 :  None
#          (7, 2) :   3.0 :  4.0 :  None
#          (7, 3) :   3.0 :  4.0 :  None
#          (7, 4) :   3.0 :  4.0 :  None
#          (8, 1) :   3.0 :  5.0 :  None
#          (8, 2) :   3.0 :  5.0 :  None
#          (8, 3) :   3.0 :  3.0 :  None
#          (8, 4) :   3.0 :  5.0 :  None
#          (9, 1) :   3.0 :  5.0 :  None
#          (9, 2) :   3.0 :  4.0 :  None
#          (9, 3) :   3.0 :  4.0 :  None
#          (9, 4) :   3.0 :  4.0 :  None
#         (10, 1) :   3.0 :  5.0 :  None
#         (10, 2) :   3.0 :  4.0 :  None
#         (10, 3) :   3.0 :  4.0 :  None
#         (10, 4) :   3.0 :  4.0 :  None
#         (11, 1) :   3.0 :  5.0 :  None
#         (11, 2) :   3.0 :  4.0 :  None
#         (11, 3) :   3.0 :  4.0 :  None
#         (11, 4) :   3.0 :  5.0 :  None
#         (12, 1) :   3.0 :  5.0 :  None
#         (12, 2) :   3.0 :  5.0 :  None
#         (12, 3) :   3.0 :  4.0 :  None
#         (12, 4) :   3.0 :  4.0 :  None
#         (13, 1) :   3.0 :  5.0 :  None
#         (13, 2) :   3.0 :  4.0 :  None
#         (13, 3) :   3.0 :  4.0 :  None
#         (13, 4) :   3.0 :  4.0 :  None
#         (14, 1) :   3.0 :  5.0 :  None
#         (14, 2) :   3.0 :  4.0 :  None
#         (14, 3) :   3.0 :  4.0 :  None
#         (14, 4) :   3.0 :  4.0 :  None
#         (15, 1) :   3.0 :  4.0 :  None
#         (15, 2) :   3.0 :  5.0 :  None
#         (15, 3) :   3.0 :  4.0 :  None
#         (15, 4) :   3.0 :  4.0 :  None
#         (16, 1) :   3.0 :  5.0 :  None
#         (16, 2) :   3.0 :  5.0 :  None
#         (16, 3) :   3.0 :  4.0 :  None
#         (16, 4) :   3.0 :  4.0 :  None
#         (17, 1) :   3.0 :  5.0 :  None
#         (17, 2) :   3.0 :  4.0 :  None
#         (17, 3) :   3.0 :  4.0 :  None
#         (17, 4) :   3.0 :  4.0 :  None
#         (18, 1) :   3.0 :  5.0 :  None
#         (18, 2) :   3.0 :  5.0 :  None
#         (18, 3) :   3.0 :  4.0 :  None
#         (18, 4) :   3.0 :  4.0 :  None
#         (19, 1) :   3.0 :  5.0 :  None
#         (19, 2) :   3.0 :  4.0 :  None
#         (19, 3) :   3.0 :  3.0 :  None
#         (19, 4) :   3.0 :  3.0 :  None
#         (20, 1) :   3.0 :  5.0 :  None
#         (20, 2) :   3.0 :  5.0 :  None
#         (20, 3) :   3.0 :  3.0 :  None
#         (20, 4) :   3.0 :  3.0 :  None
#         (21, 1) :   3.0 :  5.0 :  None
#         (21, 2) :   3.0 :  5.0 :  None
#         (21, 3) :   3.0 :  4.0 :  None
#         (21, 4) :   3.0 :  4.0 :  None
#         (22, 1) :   3.0 :  5.0 :  None
#         (22, 2) :   3.0 :  5.0 :  None
#         (22, 3) :   3.0 :  4.0 :  None
#         (22, 4) :   3.0 :  4.0 :  None
#         (23, 1) :   3.0 :  5.0 :  None
#         (23, 2) :   3.0 :  4.0 :  None
#         (23, 3) :   3.0 :  4.0 :  None
#         (23, 4) :   3.0 :  4.0 :  None
#         (24, 1) :   3.0 :  4.0 :  None
#         (24, 2) :   3.0 :  4.0 :  None
#         (24, 3) :   3.0 :  4.0 :  None
#         (24, 4) :   3.0 :  4.0 :  None
#         (25, 1) :   3.0 :  5.0 :  None
#         (25, 2) :   3.0 :  4.0 :  None
#         (25, 3) :   3.0 :  4.0 :  None
#         (25, 4) :   3.0 :  4.0 :  None
#     mutual_exclusivity_wind_solar_constraint : Size=100
#         Key     : Lower : Body : Upper
#          (1, 1) :  None :  1.0 :   1.0
#          (1, 2) :  None :  1.0 :   1.0
#          (1, 3) :  None :  1.0 :   1.0
#          (1, 4) :  None :  1.0 :   1.0
#          (2, 1) :  None :  1.0 :   1.0
#          (2, 2) :  None :  1.0 :   1.0
#          (2, 3) :  None :  1.0 :   1.0
#          (2, 4) :  None :  1.0 :   1.0
#          (3, 1) :  None :  1.0 :   1.0
#          (3, 2) :  None :  1.0 :   1.0
#          (3, 3) :  None :  1.0 :   1.0
#          (3, 4) :  None :  1.0 :   1.0
#          (4, 1) :  None :  1.0 :   1.0
#          (4, 2) :  None :  1.0 :   1.0
#          (4, 3) :  None :  1.0 :   1.0
#          (4, 4) :  None :  1.0 :   1.0
#          (5, 1) :  None :  1.0 :   1.0
#          (5, 2) :  None :  1.0 :   1.0
#          (5, 3) :  None :  1.0 :   1.0
#          (5, 4) :  None :  1.0 :   1.0
#          (6, 1) :  None :  1.0 :   1.0
#          (6, 2) :  None :  1.0 :   1.0
#          (6, 3) :  None :  1.0 :   1.0
#          (6, 4) :  None :  1.0 :   1.0
#          (7, 1) :  None :  1.0 :   1.0
#          (7, 2) :  None :  1.0 :   1.0
#          (7, 3) :  None :  1.0 :   1.0
#          (7, 4) :  None :  1.0 :   1.0
#          (8, 1) :  None :  1.0 :   1.0
#          (8, 2) :  None :  1.0 :   1.0
#          (8, 3) :  None :  1.0 :   1.0
#          (8, 4) :  None :  1.0 :   1.0
#          (9, 1) :  None :  1.0 :   1.0
#          (9, 2) :  None :  1.0 :   1.0
#          (9, 3) :  None :  1.0 :   1.0
#          (9, 4) :  None :  1.0 :   1.0
#         (10, 1) :  None :  1.0 :   1.0
#         (10, 2) :  None :  1.0 :   1.0
#         (10, 3) :  None :  1.0 :   1.0
#         (10, 4) :  None :  1.0 :   1.0
#         (11, 1) :  None :  1.0 :   1.0
#         (11, 2) :  None :  1.0 :   1.0
#         (11, 3) :  None :  1.0 :   1.0
#         (11, 4) :  None :  1.0 :   1.0
#         (12, 1) :  None :  1.0 :   1.0
#         (12, 2) :  None :  1.0 :   1.0
#         (12, 3) :  None :  1.0 :   1.0
#         (12, 4) :  None :  1.0 :   1.0
#         (13, 1) :  None :  1.0 :   1.0
#         (13, 2) :  None :  1.0 :   1.0
#         (13, 3) :  None :  1.0 :   1.0
#         (13, 4) :  None :  1.0 :   1.0
#         (14, 1) :  None :  1.0 :   1.0
#         (14, 2) :  None :  1.0 :   1.0
#         (14, 3) :  None :  1.0 :   1.0
#         (14, 4) :  None :  1.0 :   1.0
#         (15, 1) :  None :  1.0 :   1.0
#         (15, 2) :  None :  1.0 :   1.0
#         (15, 3) :  None :  1.0 :   1.0
#         (15, 4) :  None :  1.0 :   1.0
#         (16, 1) :  None :  1.0 :   1.0
#         (16, 2) :  None :  1.0 :   1.0
#         (16, 3) :  None :  1.0 :   1.0
#         (16, 4) :  None :  1.0 :   1.0
#         (17, 1) :  None :  1.0 :   1.0
#         (17, 2) :  None :  1.0 :   1.0
#         (17, 3) :  None :  1.0 :   1.0
#         (17, 4) :  None :  1.0 :   1.0
#         (18, 1) :  None :  1.0 :   1.0
#         (18, 2) :  None :  1.0 :   1.0
#         (18, 3) :  None :  1.0 :   1.0
#         (18, 4) :  None :  1.0 :   1.0
#         (19, 1) :  None :  1.0 :   1.0
#         (19, 2) :  None :  1.0 :   1.0
#         (19, 3) :  None :  1.0 :   1.0
#         (19, 4) :  None :  1.0 :   1.0
#         (20, 1) :  None :  1.0 :   1.0
#         (20, 2) :  None :  1.0 :   1.0
#         (20, 3) :  None :  1.0 :   1.0
#         (20, 4) :  None :  1.0 :   1.0
#         (21, 1) :  None :  1.0 :   1.0
#         (21, 2) :  None :  1.0 :   1.0
#         (21, 3) :  None :  1.0 :   1.0
#         (21, 4) :  None :  1.0 :   1.0
#         (22, 1) :  None :  1.0 :   1.0
#         (22, 2) :  None :  1.0 :   1.0
#         (22, 3) :  None :  1.0 :   1.0
#         (22, 4) :  None :  1.0 :   1.0
#         (23, 1) :  None :  1.0 :   1.0
#         (23, 2) :  None :  1.0 :   1.0
#         (23, 3) :  None :  1.0 :   1.0
#         (23, 4) :  None :  1.0 :   1.0
#         (24, 1) :  None :  1.0 :   1.0
#         (24, 2) :  None :  1.0 :   1.0
#         (24, 3) :  None :  1.0 :   1.0
#         (24, 4) :  None :  1.0 :   1.0
#         (25, 1) :  None :  1.0 :   1.0
#         (25, 2) :  None :  1.0 :   1.0
#         (25, 3) :  None :  1.0 :   1.0
#         (25, 4) :  None :  1.0 :   1.0
#     min_nuclear_production_constraint : Size=100
#         Key     : Lower : Body                   : Upper
#          (1, 1) :  None : 5.4569682106375694e-12 :   0.0
#          (1, 2) :  None :    -14084.699999999993 :   0.0
#          (1, 3) :  None :    -14084.699999999993 :   0.0
#          (1, 4) :  None :    -14084.699999999993 :   0.0
#          (2, 1) :  None : 5.4569682106375694e-12 :   0.0
#          (2, 2) :  None : 5.4569682106375694e-12 :   0.0
#          (2, 3) :  None : 5.4569682106375694e-12 :   0.0
#          (2, 4) :  None :    -14084.699999999993 :   0.0
#          (3, 1) :  None : 5.4569682106375694e-12 :   0.0
#          (3, 2) :  None :    -14084.699999999993 :   0.0
#          (3, 3) :  None : 5.4569682106375694e-12 :   0.0
#          (3, 4) :  None : 5.4569682106375694e-12 :   0.0
#          (4, 1) :  None : 5.4569682106375694e-12 :   0.0
#          (4, 2) :  None : 5.4569682106375694e-12 :   0.0
#          (4, 3) :  None : 5.4569682106375694e-12 :   0.0
#          (4, 4) :  None : 5.4569682106375694e-12 :   0.0
#          (5, 1) :  None : 5.4569682106375694e-12 :   0.0
#          (5, 2) :  None :    -14084.699999999993 :   0.0
#          (5, 3) :  None : 5.4569682106375694e-12 :   0.0
#          (5, 4) :  None :    -14084.699999999993 :   0.0
#          (6, 1) :  None : 5.4569682106375694e-12 :   0.0
#          (6, 2) :  None : 5.4569682106375694e-12 :   0.0
#          (6, 3) :  None : 5.4569682106375694e-12 :   0.0
#          (6, 4) :  None :    -14084.699999999993 :   0.0
#          (7, 1) :  None : 5.4569682106375694e-12 :   0.0
#          (7, 2) :  None : 5.4569682106375694e-12 :   0.0
#          (7, 3) :  None : 5.4569682106375694e-12 :   0.0
#          (7, 4) :  None : 5.4569682106375694e-12 :   0.0
#          (8, 1) :  None : 5.4569682106375694e-12 :   0.0
#          (8, 2) :  None : 5.4569682106375694e-12 :   0.0
#          (8, 3) :  None :    -14084.699999999993 :   0.0
#          (8, 4) :  None : 5.4569682106375694e-12 :   0.0
#          (9, 1) :  None : 5.4569682106375694e-12 :   0.0
#          (9, 2) :  None :    -14084.699999999993 :   0.0
#          (9, 3) :  None :    -14084.699999999993 :   0.0
#          (9, 4) :  None :    -14084.699999999993 :   0.0
#         (10, 1) :  None : 5.4569682106375694e-12 :   0.0
#         (10, 2) :  None :    -14084.699999999993 :   0.0
#         (10, 3) :  None :    -14084.699999999993 :   0.0
#         (10, 4) :  None :    -14084.699999999993 :   0.0
#         (11, 1) :  None : 5.4569682106375694e-12 :   0.0
#         (11, 2) :  None :    -14084.699999999993 :   0.0
#         (11, 3) :  None : 5.4569682106375694e-12 :   0.0
#         (11, 4) :  None : 5.4569682106375694e-12 :   0.0
#         (12, 1) :  None : 5.4569682106375694e-12 :   0.0
#         (12, 2) :  None : 5.4569682106375694e-12 :   0.0
#         (12, 3) :  None :    -14084.699999999993 :   0.0
#         (12, 4) :  None :    -14084.699999999993 :   0.0
#         (13, 1) :  None : 5.4569682106375694e-12 :   0.0
#         (13, 2) :  None :    -14084.699999999993 :   0.0
#         (13, 3) :  None : 5.4569682106375694e-12 :   0.0
#         (13, 4) :  None :    -14084.699999999993 :   0.0
#         (14, 1) :  None : 5.4569682106375694e-12 :   0.0
#         (14, 2) :  None : 5.4569682106375694e-12 :   0.0
#         (14, 3) :  None : 5.4569682106375694e-12 :   0.0
#         (14, 4) :  None : 5.4569682106375694e-12 :   0.0
#         (15, 1) :  None :    -14084.699999999993 :   0.0
#         (15, 2) :  None : 5.4569682106375694e-12 :   0.0
#         (15, 3) :  None :    -14084.699999999993 :   0.0
#         (15, 4) :  None :    -14084.699999999993 :   0.0
#         (16, 1) :  None : 5.4569682106375694e-12 :   0.0
#         (16, 2) :  None : 5.4569682106375694e-12 :   0.0
#         (16, 3) :  None :    -14084.699999999993 :   0.0
#         (16, 4) :  None :    -14084.699999999993 :   0.0
#         (17, 1) :  None : 5.4569682106375694e-12 :   0.0
#         (17, 2) :  None :    -14084.699999999993 :   0.0
#         (17, 3) :  None :    -14084.699999999993 :   0.0
#         (17, 4) :  None :    -14084.699999999993 :   0.0
#         (18, 1) :  None : 5.4569682106375694e-12 :   0.0
#         (18, 2) :  None : 5.4569682106375694e-12 :   0.0
#         (18, 3) :  None : 5.4569682106375694e-12 :   0.0
#         (18, 4) :  None :    -14084.699999999993 :   0.0
#         (19, 1) :  None : 5.4569682106375694e-12 :   0.0
#         (19, 2) :  None :    -14084.699999999993 :   0.0
#         (19, 3) :  None :    -14084.699999999993 :   0.0
#         (19, 4) :  None :    -14084.699999999993 :   0.0
#         (20, 1) :  None : 5.4569682106375694e-12 :   0.0
#         (20, 2) :  None : 5.4569682106375694e-12 :   0.0
#         (20, 3) :  None :    -14084.699999999993 :   0.0
#         (20, 4) :  None :    -14084.699999999993 :   0.0
#         (21, 1) :  None : 5.4569682106375694e-12 :   0.0
#         (21, 2) :  None : 5.4569682106375694e-12 :   0.0
#         (21, 3) :  None :    -14084.699999999993 :   0.0
#         (21, 4) :  None :    -14084.699999999993 :   0.0
#         (22, 1) :  None : 5.4569682106375694e-12 :   0.0
#         (22, 2) :  None : 5.4569682106375694e-12 :   0.0
#         (22, 3) :  None : 5.4569682106375694e-12 :   0.0
#         (22, 4) :  None :    -14084.699999999993 :   0.0
#         (23, 1) :  None : 5.4569682106375694e-12 :   0.0
#         (23, 2) :  None :    -14084.699999999993 :   0.0
#         (23, 3) :  None :    -14084.699999999993 :   0.0
#         (23, 4) :  None :    -14084.699999999993 :   0.0
#         (24, 1) :  None :    -14084.699999999993 :   0.0
#         (24, 2) :  None :    -14084.699999999993 :   0.0
#         (24, 3) :  None :    -14084.699999999993 :   0.0
#         (24, 4) :  None :    -14084.699999999993 :   0.0
#         (25, 1) :  None : 5.4569682106375694e-12 :   0.0
#         (25, 2) :  None :    -14084.699999999993 :   0.0
#         (25, 3) :  None : 5.4569682106375694e-12 :   0.0
#         (25, 4) :  None :    -14084.699999999993 :   0.0

# %%
# Display results
print("Objective Value:", round(value(model.obj()), 3))
print("\nDecision Variables:")
for i in model.r:
    for j in model.t:
        print(
            f"Region {i}, Time Period {j}: "
            f"Wind={value(model.Y['wind', i, j])}, "
            f"Solar={value(model.Y['solar', i, j])}, "
            f"Fossil={value(model.Y['fossil', i, j])}, "
            f"Nuclear={value(model.Y['nuclear', i, j])}, "
            f"Hydro={value(model.Y['hydro', i, j])}, "
            f"Geothermal={value(model.Y['geothermal', i, j])}"
        )
# Out:
# Objective Value: 5951725.213
#
# Decision Variables:
# Region 1, Time Period 1: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 1, Time Period 2: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 1, Time Period 3: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 1, Time Period 4: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 2, Time Period 1: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 2, Time Period 2: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 2, Time Period 3: Wind=1.0, Solar=0.0, Fossil=0.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 2, Time Period 4: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 3, Time Period 1: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 3, Time Period 2: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 3, Time Period 3: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=0.0, Geothermal=1.0
# Region 3, Time Period 4: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=0.0, Geothermal=1.0
# Region 4, Time Period 1: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=0.0
# Region 4, Time Period 2: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 4, Time Period 3: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=0.0
# Region 4, Time Period 4: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=0.0
# Region 5, Time Period 1: Wind=0.0, Solar=1.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 5, Time Period 2: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 5, Time Period 3: Wind=0.0, Solar=1.0, Fossil=1.0, Nuclear=1.0, Hydro=0.0, Geothermal=1.0
# Region 5, Time Period 4: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 6, Time Period 1: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 6, Time Period 2: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 6, Time Period 3: Wind=1.0, Solar=0.0, Fossil=0.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 6, Time Period 4: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 7, Time Period 1: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 7, Time Period 2: Wind=0.0, Solar=1.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=0.0
# Region 7, Time Period 3: Wind=1.0, Solar=0.0, Fossil=0.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 7, Time Period 4: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=0.0
# Region 8, Time Period 1: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 8, Time Period 2: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 8, Time Period 3: Wind=0.0, Solar=1.0, Fossil=1.0, Nuclear=0.0, Hydro=0.0, Geothermal=1.0
# Region 8, Time Period 4: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 9, Time Period 1: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 9, Time Period 2: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 9, Time Period 3: Wind=0.0, Solar=1.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 9, Time Period 4: Wind=0.0, Solar=1.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 10, Time Period 1: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 10, Time Period 2: Wind=0.0, Solar=1.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 10, Time Period 3: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 10, Time Period 4: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 11, Time Period 1: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 11, Time Period 2: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 11, Time Period 3: Wind=1.0, Solar=0.0, Fossil=0.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 11, Time Period 4: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 12, Time Period 1: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 12, Time Period 2: Wind=0.0, Solar=1.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 12, Time Period 3: Wind=0.0, Solar=1.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 12, Time Period 4: Wind=0.0, Solar=1.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 13, Time Period 1: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 13, Time Period 2: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 13, Time Period 3: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=0.0
# Region 13, Time Period 4: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 14, Time Period 1: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 14, Time Period 2: Wind=0.0, Solar=1.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=0.0
# Region 14, Time Period 3: Wind=0.0, Solar=1.0, Fossil=0.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 14, Time Period 4: Wind=0.0, Solar=1.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=0.0
# Region 15, Time Period 1: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 15, Time Period 2: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 15, Time Period 3: Wind=0.0, Solar=1.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 15, Time Period 4: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 16, Time Period 1: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 16, Time Period 2: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 16, Time Period 3: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 16, Time Period 4: Wind=0.0, Solar=1.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 17, Time Period 1: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 17, Time Period 2: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 17, Time Period 3: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 17, Time Period 4: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 18, Time Period 1: Wind=0.0, Solar=1.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 18, Time Period 2: Wind=0.0, Solar=1.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 18, Time Period 3: Wind=0.0, Solar=1.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=0.0
# Region 18, Time Period 4: Wind=0.0, Solar=1.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 19, Time Period 1: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 19, Time Period 2: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 19, Time Period 3: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=0.0, Geothermal=1.0
# Region 19, Time Period 4: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=0.0, Geothermal=1.0
# Region 20, Time Period 1: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 20, Time Period 2: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 20, Time Period 3: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=0.0, Geothermal=1.0
# Region 20, Time Period 4: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=0.0, Geothermal=1.0
# Region 21, Time Period 1: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 21, Time Period 2: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 21, Time Period 3: Wind=0.0, Solar=1.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 21, Time Period 4: Wind=0.0, Solar=1.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 22, Time Period 1: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 22, Time Period 2: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 22, Time Period 3: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=0.0
# Region 22, Time Period 4: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 23, Time Period 1: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 23, Time Period 2: Wind=0.0, Solar=1.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 23, Time Period 3: Wind=0.0, Solar=1.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 23, Time Period 4: Wind=0.0, Solar=1.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 24, Time Period 1: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 24, Time Period 2: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 24, Time Period 3: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 24, Time Period 4: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 25, Time Period 1: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=1.0
# Region 25, Time Period 2: Wind=0.0, Solar=1.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0
# Region 25, Time Period 3: Wind=1.0, Solar=0.0, Fossil=1.0, Nuclear=1.0, Hydro=1.0, Geothermal=0.0
# Region 25, Time Period 4: Wind=0.0, Solar=1.0, Fossil=1.0, Nuclear=0.0, Hydro=1.0, Geothermal=1.0

# %%
print("\nDecision Variables:")
for i in model.r:
    for j in model.t:
        print(
            f"Region {i}, Time Period {j}: "
            f"Wind={round(value(model.X['wind', i, j]), 3)}, "
            f"Solar={round(value(model.X['solar', i, j]), 3)}, "
            f"Fossil={round(value(model.X['fossil', i, j]), 3)}, "
            f"Nuclear={round(value(model.X['nuclear', i, j]), 3)}, "
            f"Hydro={round(value(model.X['hydro', i, j]), 3)}, "
            f"Geothermal={round(value(model.X['geothermal', i, j]), 3)}"
        )
# Out:
# Decision Variables:
# Region 1, Time Period 1: Wind=344.026, Solar=0.0, Fossil=911.033, Nuclear=57.191, Hydro=293.871, Geothermal=531.88
# Region 1, Time Period 2: Wind=308.373, Solar=0.0, Fossil=917.547, Nuclear=0.0, Hydro=385.084, Geothermal=392.996
# Region 1, Time Period 3: Wind=371.233, Solar=0.0, Fossil=462.192, Nuclear=0.0, Hydro=266.158, Geothermal=523.416
# Region 1, Time Period 4: Wind=342.786, Solar=0.0, Fossil=867.867, Nuclear=0.0, Hydro=260.988, Geothermal=342.358
# Region 2, Time Period 1: Wind=324.177, Solar=0.0, Fossil=738.205, Nuclear=330.126, Hydro=296.845, Geothermal=467.648
# Region 2, Time Period 2: Wind=324.177, Solar=0.0, Fossil=873.669, Nuclear=67.388, Hydro=384.981, Geothermal=371.785
# Region 2, Time Period 3: Wind=324.177, Solar=0.0, Fossil=0.0, Nuclear=556.147, Hydro=229.018, Geothermal=527.658
# Region 2, Time Period 4: Wind=324.177, Solar=0.0, Fossil=622.775, Nuclear=0.0, Hydro=336.031, Geothermal=547.017
# Region 3, Time Period 1: Wind=322.363, Solar=0.0, Fossil=885.439, Nuclear=189.366, Hydro=361.229, Geothermal=331.603
# Region 3, Time Period 2: Wind=322.363, Solar=0.0, Fossil=918.828, Nuclear=0.0, Hydro=229.721, Geothermal=488.088
# Region 3, Time Period 3: Wind=322.363, Solar=0.0, Fossil=810.3, Nuclear=19.234, Hydro=0.0, Geothermal=434.103
# Region 3, Time Period 4: Wind=322.363, Solar=0.0, Fossil=872.029, Nuclear=4.791, Hydro=0.0, Geothermal=573.817
# Region 4, Time Period 1: Wind=366.669, Solar=0.0, Fossil=987.05, Nuclear=449.801, Hydro=322.48, Geothermal=0.0
# Region 4, Time Period 2: Wind=366.669, Solar=0.0, Fossil=746.417, Nuclear=332.577, Hydro=330.411, Geothermal=216.926
# Region 4, Time Period 3: Wind=366.669, Solar=0.0, Fossil=742.458, Nuclear=292.352, Hydro=211.521, Geothermal=0.0
# Region 4, Time Period 4: Wind=302.798, Solar=0.0, Fossil=856.175, Nuclear=366.862, Hydro=277.164, Geothermal=0.0
# Region 5, Time Period 1: Wind=0.0, Solar=297.496, Fossil=714.327, Nuclear=120.848, Hydro=346.646, Geothermal=555.683
# Region 5, Time Period 2: Wind=315.408, Solar=0.0, Fossil=805.181, Nuclear=0.0, Hydro=215.13, Geothermal=572.281
# Region 5, Time Period 3: Wind=0.0, Solar=265.241, Fossil=843.287, Nuclear=22.93, Hydro=0.0, Geothermal=412.542
# Region 5, Time Period 4: Wind=388.987, Solar=0.0, Fossil=830.382, Nuclear=0.0, Hydro=122.78, Geothermal=383.851
# Region 6, Time Period 1: Wind=375.038, Solar=0.0, Fossil=818.99, Nuclear=204.362, Hydro=203.491, Geothermal=507.119
# Region 6, Time Period 2: Wind=369.34, Solar=0.0, Fossil=984.4, Nuclear=24.816, Hydro=294.552, Geothermal=303.892
# Region 6, Time Period 3: Wind=351.176, Solar=0.0, Fossil=0.0, Nuclear=571.73, Hydro=368.821, Geothermal=309.273
# Region 6, Time Period 4: Wind=346.427, Solar=0.0, Fossil=749.453, Nuclear=0.0, Hydro=377.42, Geothermal=315.7
# Region 7, Time Period 1: Wind=356.843, Solar=0.0, Fossil=741.022, Nuclear=616.482, Hydro=260.126, Geothermal=160.527
# Region 7, Time Period 2: Wind=0.0, Solar=263.467, Fossil=974.612, Nuclear=375.168, Hydro=387.753, Geothermal=0.0
# Region 7, Time Period 3: Wind=349.731, Solar=0.0, Fossil=0.0, Nuclear=574.423, Hydro=317.665, Geothermal=378.181
# Region 7, Time Period 4: Wind=368.326, Solar=0.0, Fossil=727.028, Nuclear=495.903, Hydro=219.743, Geothermal=0.0
# Region 8, Time Period 1: Wind=391.67, Solar=0.0, Fossil=763.634, Nuclear=192.552, Hydro=219.269, Geothermal=586.876
# Region 8, Time Period 2: Wind=310.893, Solar=0.0, Fossil=882.354, Nuclear=69.21, Hydro=313.122, Geothermal=443.421
# Region 8, Time Period 3: Wind=0.0, Solar=201.886, Fossil=867.767, Nuclear=0.0, Hydro=0.0, Geothermal=565.347
# Region 8, Time Period 4: Wind=323.284, Solar=0.0, Fossil=809.74, Nuclear=104.77, Hydro=227.822, Geothermal=361.385
# Region 9, Time Period 1: Wind=343.686, Solar=0.0, Fossil=734.884, Nuclear=220.509, Hydro=274.495, Geothermal=506.426
# Region 9, Time Period 2: Wind=344.046, Solar=0.0, Fossil=852.896, Nuclear=0.0, Hydro=397.686, Geothermal=355.371
# Region 9, Time Period 3: Wind=0.0, Solar=261.477, Fossil=465.059, Nuclear=0.0, Hydro=380.562, Geothermal=470.902
# Region 9, Time Period 4: Wind=0.0, Solar=262.208, Fossil=839.304, Nuclear=0.0, Hydro=270.195, Geothermal=392.293
# Region 10, Time Period 1: Wind=328.27, Solar=0.0, Fossil=806.79, Nuclear=135.372, Hydro=297.686, Geothermal=555.882
# Region 10, Time Period 2: Wind=0.0, Solar=298.523, Fossil=1014.057, Nuclear=0.0, Hydro=321.195, Geothermal=357.226
# Region 10, Time Period 3: Wind=300.976, Solar=0.0, Fossil=903.705, Nuclear=0.0, Hydro=201.427, Geothermal=205.892
# Region 10, Time Period 4: Wind=334.08, Solar=0.0, Fossil=949.372, Nuclear=0.0, Hydro=212.535, Geothermal=305.013
# Region 11, Time Period 1: Wind=368.927, Solar=0.0, Fossil=939.265, Nuclear=95.878, Hydro=331.345, Geothermal=407.585
# Region 11, Time Period 2: Wind=386.937, Solar=0.0, Fossil=981.204, Nuclear=0.0, Hydro=231.824, Geothermal=409.035
# Region 11, Time Period 3: Wind=326.78, Solar=0.0, Fossil=0.0, Nuclear=376.168, Hydro=382.012, Geothermal=541.039
# Region 11, Time Period 4: Wind=345.675, Solar=0.0, Fossil=717.939, Nuclear=113.714, Hydro=279.02, Geothermal=360.652
# Region 12, Time Period 1: Wind=326.828, Solar=0.0, Fossil=833.11, Nuclear=124.371, Hydro=293.881, Geothermal=578.809
# Region 12, Time Period 2: Wind=0.0, Solar=220.938, Fossil=897.35, Nuclear=16.409, Hydro=321.933, Geothermal=565.37
# Region 12, Time Period 3: Wind=0.0, Solar=153.182, Fossil=712.437, Nuclear=0.0, Hydro=364.263, Geothermal=407.118
# Region 12, Time Period 4: Wind=0.0, Solar=276.269, Fossil=860.967, Nuclear=0.0, Hydro=296.225, Geothermal=396.539
# Region 13, Time Period 1: Wind=317.537, Solar=0.0, Fossil=812.899, Nuclear=351.085, Hydro=249.377, Geothermal=338.102
# Region 13, Time Period 2: Wind=331.497, Solar=0.0, Fossil=1044.375, Nuclear=0.0, Hydro=280.469, Geothermal=282.659
# Region 13, Time Period 3: Wind=389.111, Solar=0.0, Fossil=901.483, Nuclear=38.501, Hydro=240.905, Geothermal=0.0
# Region 13, Time Period 4: Wind=318.034, Solar=0.0, Fossil=920.405, Nuclear=0.0, Hydro=354.127, Geothermal=162.435
# Region 14, Time Period 1: Wind=349.432, Solar=0.0, Fossil=840.354, Nuclear=680.675, Hydro=223.791, Geothermal=3.748
# Region 14, Time Period 2: Wind=0.0, Solar=167.724, Fossil=881.284, Nuclear=521.097, Hydro=396.895, Geothermal=0.0
# Region 14, Time Period 3: Wind=0.0, Solar=188.129, Fossil=0.0, Nuclear=745.137, Hydro=251.313, Geothermal=407.422
# Region 14, Time Period 4: Wind=0.0, Solar=236.769, Fossil=732.677, Nuclear=530.346, Hydro=279.209, Geothermal=0.0
# Region 15, Time Period 1: Wind=391.906, Solar=0.0, Fossil=763.313, Nuclear=0.0, Hydro=328.091, Geothermal=568.691
# Region 15, Time Period 2: Wind=399.429, Solar=0.0, Fossil=758.841, Nuclear=34.137, Hydro=320.991, Geothermal=410.602
# Region 15, Time Period 3: Wind=0.0, Solar=284.894, Fossil=329.266, Nuclear=0.0, Hydro=381.41, Geothermal=561.43
# Region 15, Time Period 4: Wind=330.988, Solar=0.0, Fossil=540.106, Nuclear=0.0, Hydro=391.68, Geothermal=477.225
# Region 16, Time Period 1: Wind=350.72, Solar=0.0, Fossil=852.638, Nuclear=166.315, Hydro=310.308, Geothermal=531.019
# Region 16, Time Period 2: Wind=328.079, Solar=0.0, Fossil=803.856, Nuclear=265.516, Hydro=274.977, Geothermal=400.571
# Region 16, Time Period 3: Wind=376.384, Solar=0.0, Fossil=837.747, Nuclear=0.0, Hydro=123.609, Geothermal=340.26
# Region 16, Time Period 4: Wind=0.0, Solar=273.82, Fossil=993.328, Nuclear=0.0, Hydro=119.149, Geothermal=488.702
# Region 17, Time Period 1: Wind=351.165, Solar=0.0, Fossil=928.075, Nuclear=275.144, Hydro=220.09, Geothermal=365.526
# Region 17, Time Period 2: Wind=390.977, Solar=0.0, Fossil=863.047, Nuclear=0.0, Hydro=210.937, Geothermal=542.038
# Region 17, Time Period 3: Wind=321.838, Solar=0.0, Fossil=482.837, Nuclear=0.0, Hydro=383.018, Geothermal=436.307
# Region 17, Time Period 4: Wind=336.31, Solar=0.0, Fossil=617.938, Nuclear=0.0, Hydro=307.17, Geothermal=553.581
# Region 18, Time Period 1: Wind=0.0, Solar=284.426, Fossil=977.273, Nuclear=377.514, Hydro=241.08, Geothermal=306.707
# Region 18, Time Period 2: Wind=0.0, Solar=268.256, Fossil=792.875, Nuclear=365.538, Hydro=313.38, Geothermal=310.952
# Region 18, Time Period 3: Wind=0.0, Solar=231.105, Fossil=966.853, Nuclear=70.66, Hydro=391.382, Geothermal=0.0
# Region 18, Time Period 4: Wind=0.0, Solar=192.537, Fossil=987.958, Nuclear=0.0, Hydro=249.656, Geothermal=424.849
# Region 19, Time Period 1: Wind=338.017, Solar=0.0, Fossil=823.547, Nuclear=104.783, Hydro=322.807, Geothermal=519.845
# Region 19, Time Period 2: Wind=354.916, Solar=0.0, Fossil=1040.981, Nuclear=0.0, Hydro=82.117, Geothermal=498.985
# Region 19, Time Period 3: Wind=355.672, Solar=0.0, Fossil=936.332, Nuclear=0.0, Hydro=0.0, Geothermal=308.996
# Region 19, Time Period 4: Wind=300.413, Solar=0.0, Fossil=944.783, Nuclear=0.0, Hydro=0.0, Geothermal=543.804
# Region 20, Time Period 1: Wind=363.802, Solar=0.0, Fossil=860.859, Nuclear=159.217, Hydro=200.457, Geothermal=518.665
# Region 20, Time Period 2: Wind=305.765, Solar=0.0, Fossil=724.407, Nuclear=225.387, Hydro=237.181, Geothermal=479.26
# Region 20, Time Period 3: Wind=304.303, Solar=0.0, Fossil=795.9, Nuclear=0.0, Hydro=0.0, Geothermal=495.797
# Region 20, Time Period 4: Wind=387.505, Solar=0.0, Fossil=883.405, Nuclear=0.0, Hydro=0.0, Geothermal=513.089
# Region 21, Time Period 1: Wind=329.259, Solar=0.0, Fossil=723.853, Nuclear=394.414, Hydro=256.436, Geothermal=496.038
# Region 21, Time Period 2: Wind=376.277, Solar=0.0, Fossil=751.148, Nuclear=211.772, Hydro=277.81, Geothermal=444.993
# Region 21, Time Period 3: Wind=0.0, Solar=240.421, Fossil=682.594, Nuclear=0.0, Hydro=313.872, Geothermal=432.113
# Region 21, Time Period 4: Wind=0.0, Solar=293.14, Fossil=726.358, Nuclear=0.0, Hydro=312.869, Geothermal=533.633
# Region 22, Time Period 1: Wind=302.942, Solar=0.0, Fossil=888.808, Nuclear=394.333, Hydro=236.957, Geothermal=300.96
# Region 22, Time Period 2: Wind=355.204, Solar=0.0, Fossil=728.151, Nuclear=353.816, Hydro=221.207, Geothermal=332.621
# Region 22, Time Period 3: Wind=324.025, Solar=0.0, Fossil=898.221, Nuclear=41.751, Hydro=348.003, Geothermal=0.0
# Region 22, Time Period 4: Wind=388.481, Solar=0.0, Fossil=826.87, Nuclear=0.0, Hydro=359.914, Geothermal=225.736
# Region 23, Time Period 1: Wind=346.024, Solar=0.0, Fossil=811.375, Nuclear=234.279, Hydro=362.777, Geothermal=337.546
# Region 23, Time Period 2: Wind=0.0, Solar=284.1, Fossil=698.048, Nuclear=0.0, Hydro=397.215, Geothermal=581.637
# Region 23, Time Period 3: Wind=0.0, Solar=160.793, Fossil=539.899, Nuclear=0.0, Hydro=354.956, Geothermal=532.352
# Region 23, Time Period 4: Wind=0.0, Solar=198.601, Fossil=814.638, Nuclear=0.0, Hydro=356.253, Geothermal=405.509
# Region 24, Time Period 1: Wind=355.949, Solar=0.0, Fossil=919.899, Nuclear=0.0, Hydro=375.774, Geothermal=419.378
# Region 24, Time Period 2: Wind=367.793, Solar=0.0, Fossil=1038.629, Nuclear=0.0, Hydro=372.575, Geothermal=162.003
# Region 24, Time Period 3: Wind=380.913, Solar=0.0, Fossil=798.496, Nuclear=0.0, Hydro=281.962, Geothermal=110.629
# Region 24, Time Period 4: Wind=386.857, Solar=0.0, Fossil=786.238, Nuclear=0.0, Hydro=260.8, Geothermal=323.105
# Region 25, Time Period 1: Wind=341.799, Solar=0.0, Fossil=727.131, Nuclear=260.683, Hydro=396.113, Geothermal=352.273
# Region 25, Time Period 2: Wind=0.0, Solar=235.906, Fossil=1012.226, Nuclear=0.0, Hydro=368.178, Geothermal=331.689
# Region 25, Time Period 3: Wind=347.846, Solar=0.0, Fossil=712.091, Nuclear=161.149, Hydro=355.914, Geothermal=0.0
# Region 25, Time Period 4: Wind=0.0, Solar=261.321, Fossil=872.016, Nuclear=0.0, Hydro=335.106, Geothermal=293.557

# %% [markdown]
# The incorporation of both continuous variables (X) and binary variables (Y) into the energy production model introduces a level of intricacy that significantly impacts its optimization dynamics. The presence of two parameters, namely the cost parameter and penalties associated with binary variables, amplifies the model's complexity. This complexity is further accentuated by the existence of multiple optimal solutions, creating a challenging landscape for the solver to navigate. Notably, the interplay between the cost parameter and penalties unveils a subtle contradiction, particularly evident in the case of nuclear energy. While the cost parameter tends to drive nuclear values towards zero due to its higher associated cost, the introduction of penalties for nuclear energy with the rest of the energies introduces a counterbalancing effect. This equilibrium poses a considerable challenge, potentially impeding the solver's ability to converge efficiently, highlighting the intricate nature of optimizing a multi-parameter energy production model. Furthermore, we can see other new added constraints like the exclusitivity constraint which ensures the selection between the solar and the wind energy, also having the first one a high penalty parameter compared to the solar one that has a low availability but also a low penalty parameter.

# %% [markdown]
# ## 4.5) Visual representation
#
# As we did before, lets compute asome grapsh in order to see the impact after including binary variables compared to the previous model that only uses continuous variables.

# %%
bar_width = 0.75
index = np.arange(len(time_periods))

# Initialize an array to store energy production for each energy source and time period
energy_by_source = np.zeros((len(model.e), len(time_periods)))

# Count the number of regions for normalization
num_regions = len(regions)

# Calculate energy production for each energy source and time period
for i, e in enumerate(model.e):
    for t in time_periods:
        for r in regions:
            energy_by_source[i, t - 1] += model.X[e, r, t]()

# Calculate average energy production for each energy source and time period
average_energy_by_source = energy_by_source / num_regions



# Plot the stacked bar graph 
colors = sns.color_palette('deep')
plt.figure(figsize=(10, 6))
bottom = np.zeros(len(time_periods))

for i, e in enumerate(model.e):
    plt.bar(index, average_energy_by_source[i, :], width=bar_width, label=e, bottom=bottom, color = colors[i])
    bottom += average_energy_by_source[i, :]

plt.xlabel("Time Period")
plt.ylabel("Average Energy Production")
plt.title("Average Energy Production by Source Across Time Periods")
plt.xticks(index, ['1 (Winter)', '2 (Spring)', '3 (Summer)', '4 (Autumn)'])
plt.legend()
plt.show()

# %% [markdown]
# An insightful analysis of the model's outcomes reveals a distinct pattern in the selection of nuclear energy, which tends to be less frequently chosen compared to other sources. The exploration of the "Average Energy Production by Source Across Time Periods" through a bar chart provides valuable insights. While nuclear energy maintains a generally lower profile, a notable surge is observed during winter periods. Intriguingly, nuclear energy surpasses solar during these colder months. This anomalous behavior suggests a strategic utilization of nuclear energy in response to heightened energy demands during winter. The hypothesis is substantiated by the reasoning that nuclear energy is selectively employed when necessary, aligning with increased energy requirements prompted by the combination of heating requirements, reduced natural lighting, and seasonal activities. This observation sheds light on the dynamic nature of energy source selection, emphasizing the model's capacity to capture nuanced patterns in response to varying demand scenarios across different time periods.
#
# From the graph that is quite useful in order to understand the differences between using this discrete variables and constraints compared to the previous section, aspects such as the exclusive production of energy between the solar and the wind energy where we can see that due to the low availability of the solar energy, in seasons like winter there is a necessity of using the wind energy, but in other reasons where the demand is not too high like summer or autumn, we can see that there is a higher competition at the moment of selection the wind or the solar energy that probably makes harder for the model to chose between those two.

# %%
# Plot two pie charts
fig, axs = plt.subplots(1, 2, figsize=(16, 8))

# First pie chart: Average Energy Production by Source
total_energy_by_source = np.sum(average_energy_by_source, axis=1)
axs[0].pie(total_energy_by_source, labels=model.e, autopct='%1.1f%%', colors=sns.color_palette('pastel'))
axs[0].axis('equal')
axs[0].set_title("Average Energy Production by Source")

# Second pie chart: Percentage of Times Each Energy Source was Chosen
total_regions_times = len(regions) * len(time_periods)
y_values = np.array([[model.Y[e, r, t]() for t in time_periods for r in regions] for e in model.e])
selected_times_by_source = np.sum(y_values, axis=1)
percentage_by_source = selected_times_by_source / total_regions_times * 100
axs[1].pie(percentage_by_source, labels=model.e, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('bright'))
axs[1].axis('equal')
axs[1].set_title("Percentage of Times Each Energy Source was Chosen")

plt.show()

# %% [markdown]
# We could also use a pie chart in order to understand the total impact of each energy. It is possible to see that the most common energy for production is the fossil with a 41%, this could be expected from the beginning due to its high availability, that in order to only fulfill the demand constraint, this energy must be highly produced. After the fossil fuel, we can see a balance between the geothermal, hydro and wind energies, which the three of them are around the 10-20% of the total production, probably the wind energy has a smaller percentage due to its high penalty parameter and not so high availability compared to the hydro and geothermal energies. Furthermore, from the nuclear we can see that compose the 7.5%, which makes absolute sense taking into consideration that is the minimum requirement imposed by the goverment. Finally, the solar energy which in this discrete case is the lowest one, eventhough it has a very low penalty parameter, the constraint that ensures a exclusivity between solar and wind energies made the solar energy to drop significantly.
#
# We also plotted another pie chart in order to understand how many times a source of energy was chosen, where we can see in this case it is distributed in a more balanced way, this is because in this case as it is a discrete case, for instance the percentage of choosing fossil and at the same time choosing hydro can be almost equal because those two energies are commonly used. However, we can notice that the tendency is to follow the same logical positions as in the other chart, where the fossil is the most commonly used, but in this case, it is more common to use hydro energy compared to the geothermal eventhough we can see in the first graph the production of geothermal is bigger compared to the production of hydro energy, this is probably due to the availability of each energy and the penalty parameter, where we think it is probable that the model prefers to assume the penalization of the hydro geothermal only when it is to produce a high amount of energy compared to the hydro which penalty parameter is lower, so it is better in order to minimize the objective function. After these energies we can see there is the wind energy which makes sense, and after the nuclear energy, which has a higher percentage of been selected than the solar, probably because the solar can only be used if we do not produce any wind energy (and viceversa).
#
# We can see important changes compared to the previous only-continuous model, which for this new case it shares with the other task some important points but also has significant differences due to the modification and addition of new constraints and the discrete variables.

# %% [markdown]
# ## 4.6) Interpretation of the results

# %% [markdown]
# The integration of both continuous (X) and binary (Y) variables in this energy production model introduces a versatile and realistic approach. Binary variables enable the inclusion of logical constraints like "max_energies_constraint" and "min_energies_constraint," shaping the solution space based on practical considerations. These constraints govern the selection and activation of energy sources, aligning with real-world decision-making scenarios. The objective function incorporates penalties (parameter P) to dynamically account for binary variable activation, addressing factors like higher costs or environmental impacts, it is important to mention that the penalty paremeters that we established also took into account the time to be executed, because when we tried extremely high penalty parameters for some energies and low for others (for instance, establishing 8000 of penalty parameter for the fossil energy, we saw that the the model did not even gets executed, probably because the balance between reducing costs and reducing the penalty parameters made imposible for the model to chose between those two options, reaching a practically infinite loop.
#
# The model strikes a balance between cost efficiency and strategic energy source selection, fostering a more realistic decision-making framework. We consider it is important to mention that for the discrete model, it took a significant higher amount of time compared to the continuous case, probably this is due to there is more constraints and the objective function now is splitted in two parts, the first one with the cost parameters and the continuous variables and the second part with the penalty parameters and the binary variables, probably this produces an increase in the time the model needs to analyze all the possible scenarios.
#
# The "energy_selection_constraint" refines the decision space, ensuring that only selected energy sources contribute to overall production for each region and time period. This constraint mirrors real-world decisions where energy production choices are contingent on specific energy sources' activation.
#
# Compared to a model solely relying on continuous variables (X), the integration of binary variables provides explicit consideration for constraints governing energy source selection and activation. Constraints like "max_energies_constraint" and "min_energies_constraint" offer practical means to align the model with operational constraints and preferences. Penalties for binary variable activation add sophistication, allowing for the consideration of factors such as environmental impact or operational considerations. In summary, the combined use of continuous and binary variables enhances the model's expressiveness, realism, and adaptability, providing a comprehensive tool for energy production planning and decision support.

# %% [markdown]
# # 5) Final conclusions
#
# In conclusion, the project encompassed the development and evaluation of a comprehensive energy production model, progressing from the initial continuous model to an extended version that incorporates discrete decision variables. The continuous model laid the groundwork by formulating the optimization problem with a focus on minimizing costs and adhering to environmental constraints. However, the addition of binary variables (Y), penalties, and new constraints in the discrete model introduced a new layer of complexity. The interplay between the cost parameter and penalties, particularly in the case of nuclear energy, revealed intricate trade-offs, making the optimization process more challenging where the model had to decide which path was the most optimal, if focusing on decreasing the penalty parameters from the discrete variables or to minimize the costs from the continuous variables.
#
# While the discrete model offers enhanced realism with logical and conditional constraints, the solver's struggle to converge suggests the need for further refinement. The incorporation of binary variables introduces a nuanced decision-making process, providing a more adaptable tool for energy production planning. However, achieving an optimal solution within a reasonable timeframe remains a challenge, emphasizing the intricate nature of balancing multiple parameters in energy optimization.
#
# During the whole assigment we have faced several issues that we tried to fix in different ways taking into consideration aspects such as the nature and the stability of the model. We were able to fix it by trying different methods and doing several researches about the topic.
#
# We were able to create a linear optimization problem that involves 600 decision variables for the continuous case and 1200 for the continuous and discrete case (600 for variable X and another 600 for variable Y). Futhermore, for the constraints for the first section we created a total of 5 only involving continuous variables.
# Meanwhile for the second section we were able to adapt such as the minimum nuclear energy production constraint or also create new constraints to contain discrete variables such as the minimum and maximum sources of energy production or the exclusivity constraint between the solar and wind energies, in total we created a had 4 constraints that were reused from the previous continuous section, adapt one from that section in order to involve discrete variables (the minimum nuclear energy production) and we also created another new 4 constraints for the discrete case, such as the maximum and minimum sources of energy production, the exclusivity one or the "energy_selection_constraint" which ensures that when the model wants to produce a certain amount of energy, the binary variable Y for that specific energy, region and time period is set to 1. So in total for the second part of the assigment we established 8 different constraints.
#
# We consider that in the assigment there is a clear evidence on how to create continuous models and a model that contains discrete and continouos variables. From the continuous problem to the one that included discrete variables, we reformulated a similar problem with some key points that made possible the introduction of discrete variables but maintaining the essence of the original problem.
